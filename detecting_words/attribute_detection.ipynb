# %% [markdown]
# # detecting attributes (e.g., stereotypes) on the basis on trained models

# %%
import gensim

# %%
mvolkskrant = gensim.models.Word2Vec.load('/Users/admin/Google Drive/2017_MigrantWorkers/data/trained_models/word2vec-volkskrant (print)-2006-01-01-2016-01-01')

# %%
mtelegraaf = gensim.models.Word2Vec.load('/Users/admin/Google Drive/2017_MigrantWorkers/data/trained_models/word2vec-telegraaf (print)-2006-01-01-2016-01-01')

# %%
mtelegraaf.wv.most_similar(positive='marokkaan', topn=100)
# Out:
# [('turk', 0.8325773477554321),
#  ('rotterdammer', 0.815995991230011),
#  ('vrachtwagenchauffeur', 0.812148928642273),
#  ('nigeriaan', 0.8118677139282227),
#  ('taxichauffeur', 0.8055457472801208),
#  ('utrechter', 0.7904987335205078),
#  ('hagenaar', 0.7870850563049316),
#  ('amsterdammer', 0.784953773021698),
#  ('tiener', 0.7812453508377075),
#  ('buschauffeur', 0.7759998440742493),
#  ('jongeman', 0.7753958702087402),
#  ('ghanees', 0.7692487239837646),
#  ('pool', 0.7684054970741272),
#  ('politieman', 0.765518069267273),
#  ('motorrijder', 0.764751136302948),
#  ('rijswijker', 0.7634246349334717),
#  ('gevangene', 0.7588741779327393),
#  ('pedofiel', 0.7572864294052124),
#  ('delftenaar', 0.7570133805274963),
#  ('schutter', 0.7523499131202698),
#  ('arnhemmer', 0.7511062622070312),
#  ('beul', 0.7492407560348511),
#  ('griek', 0.7480883598327637),
#  ('irakees', 0.7467281222343445),
#  ('priester', 0.7443755269050598),
#  ('bewaker', 0.7426998615264893),
#  ('knul', 0.7405222654342651),
#  ('inbreker', 0.7397903203964233),
#  ('algerijn', 0.7391157150268555),
#  ('bulgaar', 0.7388240098953247),
#  ('jihadist', 0.7385131120681763),
#  ('zwerver', 0.7367974519729614),
#  ('gedetineerde', 0.7340067625045776),
#  ('kleuter', 0.7317003011703491),
#  ('arrestant', 0.7308458685874939),
#  ('trucker', 0.7297319173812866),
#  ('antilliaan', 0.7282091379165649),
#  ('roemeen', 0.7281186580657959),
#  ('politieagent', 0.7266709804534912),
#  ('bouwvakker', 0.7251962423324585),
#  ('terrorist', 0.7203684449195862),
#  ('prostituee', 0.7203266024589539),
#  ('drugshandelaar', 0.7200878858566284),
#  ('schiedammer', 0.7200318574905396),
#  ('limburger', 0.7194298505783081),
#  ('haarlemmer', 0.7193041443824768),
#  ('fietser', 0.718553900718689),
#  ('snelheidsduivel', 0.7176101207733154),
#  ('dordtenaar', 0.7172045707702637),
#  ('egyptenaar', 0.7164492607116699),
#  ('asielzoeker', 0.7151629328727722),
#  ('brabander', 0.7128880023956299),
#  ('surinamer', 0.7110375165939331),
#  ('palestijn', 0.7105278372764587),
#  ('automobiliste', 0.7092740535736084),
#  ('tilburger', 0.708983302116394),
#  ('veteraan', 0.7073219418525696),
#  ('postbode', 0.7063971161842346),
#  ('almeerder', 0.7043583989143372),
#  ('bokser', 0.7038565874099731),
#  ('oplichter', 0.7034512162208557),
#  ('sluitpost', 0.7030977606773376),
#  ('nijmegenaar', 0.6989613771438599),
#  ('fietsster', 0.6951037645339966),
#  ('tukker', 0.6949700117111206),
#  ('drugsdealer', 0.6918342113494873),
#  ('avonturier', 0.6915093660354614),
#  ('machinist', 0.691473662853241),
#  ('linkspoot', 0.6912523508071899),
#  ('drent', 0.6911748647689819),
#  ('boekhouder', 0.6905591487884521),
#  ('overvaller', 0.6885996460914612),
#  ('handlanger', 0.6879140138626099),
#  ('straatrover', 0.687751829624176),
#  ('belg', 0.6867188215255737),
#  ('atleet', 0.6863129138946533),
#  ('braziliaan', 0.6851872205734253),
#  ('glazenwasser', 0.6849308013916016),
#  ('scooterrijder', 0.6846953630447388),
#  ('seriemoordenaar', 0.6842024922370911),
#  ('matroos', 0.6838735342025757),
#  ('zwollenaar', 0.6837363243103027),
#  ('zedendelinquent', 0.6835479736328125),
#  ('jongen', 0.6829922199249268),
#  ('veelvraat', 0.6826246976852417),
#  ('mexicaan', 0.6823422908782959),
#  ('monnik', 0.682144045829773),
#  ('agent', 0.6815249919891357),
#  ('diender', 0.6814583539962769),
#  ('maastrichtenaar', 0.6803550720214844),
#  ('hoofdverdachte', 0.6801605820655823),
#  ('friezin', 0.6799290180206299),
#  ('man', 0.679090678691864),
#  ('motoragent', 0.6786770820617676),
#  ('spion', 0.6774836778640747),
#  ('agente', 0.6766258478164673),
#  ('scheveninger', 0.6744898557662964),
#  ('jeugdinternational', 0.6740646362304688),
#  ('gangster', 0.673693060874939),
#  ('huurmoordenaar', 0.6729867458343506)]

# %%
mtelegraaf.wv.most_similar(positive='marokkanen', topn=100)
# Out:
# [('surinamers', 0.7812365293502808),
#  ('antillianen', 0.7787741422653198),
#  ('allochtonen', 0.7778072357177734),
#  ('turken', 0.7733108401298523),
#  ('buitenlanders', 0.7513625025749207),
#  ('moslims', 0.7493506669998169),
#  ('katholieken', 0.7136186361312866),
#  ('priesters', 0.705890953540802),
#  ('activisten', 0.7056492567062378),
#  ('arabieren', 0.7049311399459839),
#  ('irakezen', 0.7021148204803467),
#  ('imams', 0.6993268728256226),
#  ('veteranen', 0.6988787055015564),
#  ('christenen', 0.6944169998168945),
#  ('geestelijken', 0.6937277317047119),
#  ('politieagenten', 0.6879211664199829),
#  ('allochtone', 0.6854671239852905),
#  ('afghanen', 0.683391809463501),
#  ('prostituees', 0.6831817626953125),
#  ('gevangenen', 0.680885374546051),
#  ('middenstanders', 0.6796815395355225),
#  ('groepen', 0.6796316504478455),
#  ('aanhangers', 0.6777242422103882),
#  ('sympathisanten', 0.6775708198547363),
#  ('vreemdelingen', 0.675850510597229),
#  ('jihadisten', 0.6756240129470825),
#  ('joden', 0.6730024814605713),
#  ('gelovigen', 0.6726492643356323),
#  ('egyptenaren', 0.6711156368255615),
#  ('autochtonen', 0.6701482534408569),
#  ('vlamingen', 0.6699246168136597),
#  ('roemenen', 0.6686428785324097),
#  ('bejaarden', 0.668538510799408),
#  ('relschoppers', 0.664923906326294),
#  ('arbeiders', 0.6648951172828674),
#  ('senioren', 0.6615986227989197),
#  ('tieners', 0.6601510047912598),
#  ('homoseksuelen', 0.6566836833953857),
#  ('leraren', 0.6549863219261169),
#  ('illegalen', 0.6536412239074707),
#  ('jongeren', 0.6531134247779846),
#  ('leerkrachten', 0.6523746252059937),
#  ('albanezen', 0.650849461555481),
#  ('gedetineerden', 0.6503453254699707),
#  ('twintigers', 0.6500190496444702),
#  ('arrestanten', 0.649864137172699),
#  ('immigranten', 0.6493021845817566),
#  ('militanten', 0.6491392850875854),
#  ('zakenmensen', 0.6477583646774292),
#  ('gezinnen', 0.6448293924331665),
#  ('verpleegkundigen', 0.6446804404258728),
#  ('demonstranten', 0.6419682502746582),
#  ('verslaafden', 0.6398837566375732),
#  ('overlevenden', 0.6380885243415833),
#  ('bulgaren', 0.6377546191215515),
#  ('strijders', 0.6375688314437866),
#  ('leidinggevenden', 0.6373733878135681),
#  ('raadsleden', 0.6365834474563599),
#  ('zakenlieden', 0.6360388994216919),
#  ('vluchtelingen', 0.6359090805053711),
#  ('meisjes', 0.6350213289260864),
#  ('zwarten', 0.634985625743866),
#  ('expats', 0.6345913410186768),
#  ('groeperingen', 0.6341243982315063),
#  ('nederlanders', 0.6330090165138245),
#  ('hagenaars', 0.6311464905738831),
#  ('dierenartsen', 0.6304382085800171),
#  ('burgemeesters', 0.6296275854110718),
#  ('westerlingen', 0.6286438703536987),
#  ('asielzoekers', 0.6281400918960571),
#  ('taxichauffeurs', 0.6278508901596069),
#  ('slachtoffers', 0.6275638937950134),
#  ('palestijnen', 0.6265261769294739),
#  ('slachtoffertjes', 0.6263459920883179),
#  ('jagers', 0.6262812614440918),
#  ('plussers', 0.625877857208252),
#  ('hulpverleners', 0.6256939172744751),
#  ('koerden', 0.6250699758529663),
#  ('militairen', 0.624521017074585),
#  ('vrouwen', 0.6237995624542236),
#  ('journalisten', 0.6216011047363281),
#  ('zwervers', 0.6209582686424255),
#  ('vrachtwagenchauffeurs', 0.619534432888031),
#  ('parlementsleden', 0.6194115877151489),
#  ('raddraaiers', 0.6190389394760132),
#  ('families', 0.619004487991333),
#  ('marechaussees', 0.6186301112174988),
#  ('soldaten', 0.6180297136306763),
#  ('verenigingen', 0.6160529255867004),
#  ('schoolkinderen', 0.6155623197555542),
#  ('hooligans', 0.6152544021606445),
#  ('migranten', 0.6140921115875244),
#  ('zigeuners', 0.6122667193412781),
#  ('dokters', 0.6086076498031616),
#  ('politiemensen', 0.6083135604858398),
#  ('actievoerders', 0.6079198122024536),
#  ('brazilianen', 0.6074800491333008),
#  ('minderjarigen', 0.6074557900428772),
#  ('medici', 0.6069846153259277),
#  ('landgenoten', 0.6065391898155212)]

# %%
mtelegraaf.wv.most_similar(positive='marokkanen', topn=100)
# Out:
# [('surinamers', 0.7812365293502808),
#  ('antillianen', 0.7787741422653198),
#  ('allochtonen', 0.7778072357177734),
#  ('turken', 0.7733108401298523),
#  ('buitenlanders', 0.7513625025749207),
#  ('moslims', 0.7493506669998169),
#  ('katholieken', 0.7136186361312866),
#  ('priesters', 0.705890953540802),
#  ('activisten', 0.7056492567062378),
#  ('arabieren', 0.7049311399459839),
#  ('irakezen', 0.7021148204803467),
#  ('imams', 0.6993268728256226),
#  ('veteranen', 0.6988787055015564),
#  ('christenen', 0.6944169998168945),
#  ('geestelijken', 0.6937277317047119),
#  ('politieagenten', 0.6879211664199829),
#  ('allochtone', 0.6854671239852905),
#  ('afghanen', 0.683391809463501),
#  ('prostituees', 0.6831817626953125),
#  ('gevangenen', 0.680885374546051),
#  ('middenstanders', 0.6796815395355225),
#  ('groepen', 0.6796316504478455),
#  ('aanhangers', 0.6777242422103882),
#  ('sympathisanten', 0.6775708198547363),
#  ('vreemdelingen', 0.675850510597229),
#  ('jihadisten', 0.6756240129470825),
#  ('joden', 0.6730024814605713),
#  ('gelovigen', 0.6726492643356323),
#  ('egyptenaren', 0.6711156368255615),
#  ('autochtonen', 0.6701482534408569),
#  ('vlamingen', 0.6699246168136597),
#  ('roemenen', 0.6686428785324097),
#  ('bejaarden', 0.668538510799408),
#  ('relschoppers', 0.664923906326294),
#  ('arbeiders', 0.6648951172828674),
#  ('senioren', 0.6615986227989197),
#  ('tieners', 0.6601510047912598),
#  ('homoseksuelen', 0.6566836833953857),
#  ('leraren', 0.6549863219261169),
#  ('illegalen', 0.6536412239074707),
#  ('jongeren', 0.6531134247779846),
#  ('leerkrachten', 0.6523746252059937),
#  ('albanezen', 0.650849461555481),
#  ('gedetineerden', 0.6503453254699707),
#  ('twintigers', 0.6500190496444702),
#  ('arrestanten', 0.649864137172699),
#  ('immigranten', 0.6493021845817566),
#  ('militanten', 0.6491392850875854),
#  ('zakenmensen', 0.6477583646774292),
#  ('gezinnen', 0.6448293924331665),
#  ('verpleegkundigen', 0.6446804404258728),
#  ('demonstranten', 0.6419682502746582),
#  ('verslaafden', 0.6398837566375732),
#  ('overlevenden', 0.6380885243415833),
#  ('bulgaren', 0.6377546191215515),
#  ('strijders', 0.6375688314437866),
#  ('leidinggevenden', 0.6373733878135681),
#  ('raadsleden', 0.6365834474563599),
#  ('zakenlieden', 0.6360388994216919),
#  ('vluchtelingen', 0.6359090805053711),
#  ('meisjes', 0.6350213289260864),
#  ('zwarten', 0.634985625743866),
#  ('expats', 0.6345913410186768),
#  ('groeperingen', 0.6341243982315063),
#  ('nederlanders', 0.6330090165138245),
#  ('hagenaars', 0.6311464905738831),
#  ('dierenartsen', 0.6304382085800171),
#  ('burgemeesters', 0.6296275854110718),
#  ('westerlingen', 0.6286438703536987),
#  ('asielzoekers', 0.6281400918960571),
#  ('taxichauffeurs', 0.6278508901596069),
#  ('slachtoffers', 0.6275638937950134),
#  ('palestijnen', 0.6265261769294739),
#  ('slachtoffertjes', 0.6263459920883179),
#  ('jagers', 0.6262812614440918),
#  ('plussers', 0.625877857208252),
#  ('hulpverleners', 0.6256939172744751),
#  ('koerden', 0.6250699758529663),
#  ('militairen', 0.624521017074585),
#  ('vrouwen', 0.6237995624542236),
#  ('journalisten', 0.6216011047363281),
#  ('zwervers', 0.6209582686424255),
#  ('vrachtwagenchauffeurs', 0.619534432888031),
#  ('parlementsleden', 0.6194115877151489),
#  ('raddraaiers', 0.6190389394760132),
#  ('families', 0.619004487991333),
#  ('marechaussees', 0.6186301112174988),
#  ('soldaten', 0.6180297136306763),
#  ('verenigingen', 0.6160529255867004),
#  ('schoolkinderen', 0.6155623197555542),
#  ('hooligans', 0.6152544021606445),
#  ('migranten', 0.6140921115875244),
#  ('zigeuners', 0.6122667193412781),
#  ('dokters', 0.6086076498031616),
#  ('politiemensen', 0.6083135604858398),
#  ('actievoerders', 0.6079198122024536),
#  ('brazilianen', 0.6074800491333008),
#  ('minderjarigen', 0.6074557900428772),
#  ('medici', 0.6069846153259277),
#  ('landgenoten', 0.6065391898155212)]
