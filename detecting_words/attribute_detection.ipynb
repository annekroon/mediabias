# %% [markdown]
# # Detecting attributes (e.g., stereotypes) on the basis on np data
# ## Data trained on time period: 2000 - 2016

# %%
import gensim

# %%
#mvolkskrant = gensim.models.Word2Vec.load('/Users/admin/Google Drive/2017_MigrantWorkers/data/trained_models/word2vec-volkskrant (print)-2006-01-01-2016-01-01')

# %% [markdown]
# # Newspaper: Telegraaf

# %%
mtelegraaf = gensim.models.Word2Vec.load('/Users/admin/Google Drive/2017_MigrantWorkers/data/trained_models/trained_2000_2016/telegraaf')

# %% [markdown]
# ## 1a. Target categories:
# ### Bevolkingsgroepen
# https://www.cbs.nl/nl-nl/achtergrond/2016/47/bevolking-naar-migratieachtergrond

# %%
mtelegraaf.wv.most_similar(positive='marokkaan', topn=100)
# Out:
# [('turk', 0.8801292181015015),
#  ('utrechter', 0.8319655656814575),
#  ('antilliaan', 0.8231033086776733),
#  ('taxichauffeur', 0.8189578652381897),
#  ('rotterdammer', 0.8126174211502075),
#  ('vrachtwagenchauffeur', 0.8052381873130798),
#  ('politieman', 0.7997815608978271),
#  ('roemeen', 0.7884068489074707),
#  ('delftenaar', 0.7877012491226196),
#  ('prostituee', 0.7846521139144897),
#  ('surinamer', 0.7829015254974365),
#  ('schutter', 0.7826815247535706),
#  ('schiedammer', 0.7816773653030396),
#  ('knul', 0.7812137007713318),
#  ('pool', 0.7804931402206421),
#  ('jihadist', 0.7793528437614441),
#  ('hagenaar', 0.7787566781044006),
#  ('bouwvakker', 0.7782526016235352),
#  ('ghanees', 0.7759048342704773),
#  ('egyptenaar', 0.775345504283905),
#  ('griek', 0.7741899490356445),
#  ('nigeriaan', 0.773072361946106),
#  ('nijmegenaar', 0.7718414068222046),
#  ('tiener', 0.7705082893371582),
#  ('amsterdammer', 0.7675232887268066),
#  ('arnhemmer', 0.7667785882949829),
# ...

# %%
mtelegraaf.wv.most_similar(positive='marokkanen', topn=100)
# Out:
# [('surinamers', 0.849233090877533),
#  ('antillianen', 0.8363944292068481),
#  ('turken', 0.7761409282684326),
#  ('allochtonen', 0.7625359296798706),
#  ('buitenlanders', 0.7336505651473999),
#  ('prostituees', 0.7275799512863159),
#  ('moslims', 0.7248196601867676),
#  ('afghanen', 0.7166217565536499),
#  ('katholieken', 0.715731143951416),
#  ('arabieren', 0.7114654779434204),
#  ('immigranten', 0.7089077234268188),
#  ('islamieten', 0.7088958024978638),
#  ('roemenen', 0.7076221704483032),
#  ('tieners', 0.7074191570281982),
#  ('veteranen', 0.6986021399497986),
#  ('activisten', 0.6977149844169617),
#  ('christenen', 0.6955261826515198),
#  ('imams', 0.694968581199646),
#  ('joden', 0.6941487789154053),
#  ('molukkers', 0.6932656764984131),
#  ('moslimjongeren', 0.6928541660308838),
#  ('politieagenten', 0.6917197704315186),
#  ('bulgaren', 0.6889986991882324),
#  ('allochtone', 0.686168372631073),
#  ('irakezen', 0.6860834956169128),
#  ('leraren', 0.6833574771881104),
# ...

# %%
mtelegraaf.wv.most_similar(positive='turk', topn=100)
# Out:
# [('marokkaan', 0.8801290392875671),
#  ('antilliaan', 0.8672351241111755),
#  ('surinamer', 0.8273297548294067),
#  ('jihadist', 0.8263682126998901),
#  ('egyptenaar', 0.8214620351791382),
#  ('drugshandelaar', 0.8118829727172852),
#  ('roemeen', 0.8079407215118408),
#  ('palestijn', 0.8029785752296448),
#  ('algerijn', 0.8009077310562134),
#  ('terrorist', 0.8003770112991333),
#  ('drugsdealer', 0.7957221269607544),
#  ('prostituee', 0.7954307794570923),
#  ('tilburger', 0.7845702767372131),
#  ('irakees', 0.7844892740249634),
#  ('oplichter', 0.7832286357879639),
#  ('gangster', 0.7831248641014099),
#  ('kickbokser', 0.7830952405929565),
#  ('pedofiel', 0.7829311490058899),
#  ('huurmoordenaar', 0.7821311950683594),
#  ('seriemoordenaar', 0.7817065715789795),
#  ('pool', 0.7804523706436157),
#  ('drugsbaron', 0.7786256670951843),
#  ('handlanger', 0.7754328846931458),
#  ('scherpschutter', 0.7745972871780396),
#  ('maffiabaas', 0.7732417583465576),
# ...

# %%
mtelegraaf.wv.most_similar(positive='turken', topn=100)
# Out:
# [('russen', 0.8693633079528809),
#  ('duitsers', 0.8602790832519531),
#  ('denen', 0.8565038442611694),
#  ('belgen', 0.8481142520904541),
#  ('italianen', 0.8410557508468628),
#  ('britten', 0.8373668193817139),
#  ('fransen', 0.8351097106933594),
#  ('hongaren', 0.8248182535171509),
#  ('arabieren', 0.824492335319519),
#  ('roemenen', 0.8224622011184692),
#  ('ieren', 0.8147594332695007),
#  ('vlamingen', 0.8142526149749756),
#  ('koerden', 0.8133082389831543),
#  ('palestijnen', 0.8087796568870544),
#  ('spanjaarden', 0.808351993560791),
#  ('afghanen', 0.8053395748138428),
#  ('buitenlanders', 0.8046114444732666),
#  ('japanners', 0.8026278614997864),
#  ('moslims', 0.8001991510391235),
#  ('noren', 0.799323558807373),
#  ('joden', 0.7992061972618103),
#  ('amerikanen', 0.7978887557983398),
#  ('brazilianen', 0.7974159717559814),
#  ('bulgaren', 0.7922781705856323),
#  ('chinezen', 0.7873449325561523),
#  ('aziaten', 0.7827499508857727),
#  ('christenen', 0.7822248935699463),
# ...

# %%
mtelegraaf.wv.most_similar(positive='surinamer', topn=100)
# Out:
# [('tilburger', 0.8617211580276489),
#  ('antilliaan', 0.8454793691635132),
#  ('irakees', 0.8448963165283203),
#  ('amersfoorter', 0.8396101593971252),
#  ('rijswijker', 0.8382176756858826),
#  ('algerijn', 0.8346758484840393),
#  ('leidenaar', 0.8295224905014038),
#  ('turk', 0.8273297548294067),
#  ('stuntman', 0.824225664138794),
#  ('kroegbaas', 0.8194758296012878),
#  ('voorburger', 0.8181226253509521),
#  ('kickbokser', 0.8168667554855347),
#  ('zoetermeerder', 0.8165607452392578),
#  ('zaandammer', 0.8157813549041748),
#  ('bosschenaar', 0.8132688403129578),
#  ('nijmegenaar', 0.8132541179656982),
#  ('drugsdealer', 0.8125064969062805),
#  ('bredanaar', 0.8074009418487549),
#  ('apeldoorner', 0.8069806098937988),
#  ('scherpschutter', 0.8067047595977783),
#  ('drugsbaron', 0.8051377534866333),
#  ('marktkoopman', 0.8027349710464478),
#  ('maastrichtenaar', 0.8015389442443848),
#  ('ghanees', 0.7969130873680115),
#  ('brunette', 0.7968534827232361),
# ...

# %%
mtelegraaf.wv.most_similar(positive='surinamers', topn=100)
# Out:
# [('marokkanen', 0.8492329120635986),
#  ('antillianen', 0.8339243531227112),
#  ('academici', 0.7618043422698975),
#  ('turken', 0.7262499332427979),
#  ('allochtone', 0.7152807116508484),
#  ('autochtonen', 0.7137778997421265),
#  ('islamieten', 0.7036387920379639),
#  ('arabieren', 0.7010064125061035),
#  ('allochtonen', 0.6953871250152588),
#  ('molukkers', 0.6929231882095337),
#  ('afghanen', 0.6916170120239258),
#  ('hoogopgeleide', 0.690605878829956),
#  ('expats', 0.6871750950813293),
#  ('autochtone', 0.6864567399024963),
#  ('katholieken', 0.683097243309021),
#  ('vijftigplussers', 0.6829053163528442),
#  ('weduwen', 0.6808123588562012),
#  ('veertigers', 0.6784954071044922),
#  ('zakenmensen', 0.6767991781234741),
#  ('tibetanen', 0.6737657785415649),
#  ('twintigers', 0.6734360456466675),
#  ('slagers', 0.6731928586959839),
#  ('middenstanders', 0.6730344295501709),
#  ('priesters', 0.672845721244812),
#  ('egyptenaren', 0.6711922287940979),
# ...

# %%
mtelegraaf.wv.most_similar(positive='antilliaan', topn=100)
# Out:
# [('turk', 0.8672351241111755),
#  ('roemeen', 0.8532974720001221),
#  ('surinamer', 0.8454793691635132),
#  ('kickbokser', 0.8330143690109253),
#  ('bulgaar', 0.8277985453605652),
#  ('tilburger', 0.8258302807807922),
#  ('marokkaan', 0.8231033086776733),
#  ('drugsdealer', 0.822838544845581),
#  ('pool', 0.8138599395751953),
#  ('maffiabaas', 0.813286304473877),
#  ('irakees', 0.8084381818771362),
#  ('scherpschutter', 0.8084025382995605),
#  ('drugshandelaar', 0.8069525361061096),
#  ('plaatsgenoot', 0.8069311380386353),
#  ('zoetermeerder', 0.806247353553772),
#  ('algerijn', 0.7994469404220581),
#  ('jihadist', 0.7987989783287048),
#  ('colombiaan', 0.7982815504074097),
#  ('nigeriaan', 0.7969289422035217),
#  ('nijmegenaar', 0.7951197624206543),
#  ('arnhemmer', 0.7947971820831299),
#  ('dordtenaar', 0.7908598184585571),
#  ('palestijn', 0.7891355752944946),
#  ('bodyguard', 0.7870168685913086),
#  ('amersfoorter', 0.7866389155387878),
#  ('brokkenpiloot', 0.7855044603347778),
# ...

# %%
mtelegraaf.wv.most_similar(positive='antillianen', topn=100)
# Out:
# [('marokkanen', 0.8363943099975586),
#  ('surinamers', 0.833924412727356),
#  ('allochtonen', 0.7838608026504517),
#  ('allochtone', 0.7678095102310181),
#  ('autochtonen', 0.7667563557624817),
#  ('moslimjongeren', 0.7629692554473877),
#  ('probleemjongeren', 0.7475394010543823),
#  ('academici', 0.7455651760101318),
#  ('overlastgevende', 0.742267906665802),
#  ('molukkers', 0.7368565797805786),
#  ('jeugdbendes', 0.7362900972366333),
#  ('hangjongeren', 0.7248353362083435),
#  ('islamieten', 0.7239093780517578),
#  ('bendes', 0.7236501574516296),
#  ('minderheden', 0.7204762101173401),
#  ('veelplegers', 0.7184492349624634),
#  ('hoogopgeleide', 0.7110841870307922),
#  ('homoseksuelen', 0.7083016633987427),
#  ('autochtone', 0.7063013911247253),
#  ('afghanen', 0.6982083320617676),
#  ('geestelijken', 0.6978573799133301),
#  ('etnische', 0.6941719055175781),
#  ('imams', 0.6874402761459351),
#  ('zakenmensen', 0.6866900324821472),
#  ('turken', 0.6800872087478638),
# ...

# %%
mtelegraaf.wv.most_similar(positive='irakees', topn=100)
# Out:
# [('drugsdealer', 0.8671073913574219),
#  ('algerijn', 0.8573086261749268),
#  ('surinamer', 0.8448963761329651),
#  ('arrestant', 0.8353318572044373),
#  ('zedendelinquent', 0.8323551416397095),
#  ('flores', 0.8207570314407349),
#  ('dordtenaar', 0.8183028697967529),
#  ('veelpleger', 0.8148961067199707),
#  ('chandrikasing', 0.8136416673660278),
#  ('tilburger', 0.8119818568229675),
#  ('schiedammer', 0.8096320629119873),
#  ('politieagente', 0.8095090389251709),
#  ('antilliaan', 0.8084381818771362),
#  ('kickbokser', 0.7989037036895752),
#  ('verkrachter', 0.7951585054397583),
#  ('arubaan', 0.7943778038024902),
#  ('palestijn', 0.793293833732605),
#  ('rijswijker', 0.7904053926467896),
#  ('pedofiel', 0.7888473868370056),
#  ('kidnapper', 0.7887306809425354),
#  ('drugsverslaafde', 0.7886084318161011),
#  ('terrorist', 0.7883074283599854),
#  ('zoetermeerder', 0.78829425573349),
#  ('bendeleider', 0.7850198745727539),
#  ('turk', 0.7844892740249634),
# ...

# %%
mtelegraaf.wv.most_similar(positive='irakezen', topn=100)
# Out:
# [('betogers', 0.8716913461685181),
#  ('demonstranten', 0.858812689781189),
#  ('afghanen', 0.8462508320808411),
#  ('gijzelaars', 0.8407748937606812),
#  ('palestijnen', 0.8353743553161621),
#  ('egyptenaren', 0.8351370096206665),
#  ('serviers', 0.8345227837562561),
#  ('soldaten', 0.8338291049003601),
#  ('activisten', 0.8293942809104919),
#  ('gevangenen', 0.8217201232910156),
#  ('koerden', 0.8199640512466431),
#  ('arabieren', 0.8123641014099121),
#  ('strijders', 0.8092092871665955),
#  ('militairen', 0.8054461479187012),
#  ('actievoerders', 0.8027044534683228),
#  ('militanten', 0.8019444942474365),
#  ('joden', 0.7978947758674622),
#  ('moslimextremisten', 0.7970824241638184),
#  ('jihadisten', 0.7953747510910034),
#  ('politieagenten', 0.7933624982833862),
#  ('milities', 0.7858864665031433),
#  ('arbeiders', 0.7857793569564819),
#  ('opstandelingen', 0.78477942943573),
#  ('pakistanen', 0.7838032245635986),
#  ('rebellen', 0.7830085158348083),
# ...

# %%
mtelegraaf.wv.most_similar(positive='afghaan', topn=100)
# Out:
# [('demonstrante', 0.8057331442832947),
#  ('leidschendammer', 0.8056175708770752),
#  ('heerlenaar', 0.7868003249168396),
#  ('kamikazepiloot', 0.7863746881484985),
#  ('medeplichtige', 0.7850229144096375),
#  ('nieuwegeiner', 0.7834336757659912),
#  ('silas', 0.7814511060714722),
#  ('fysicus', 0.7810914516448975),
#  ('stalker', 0.7796282172203064),
#  ('edenaar', 0.7792381048202515),
#  ('bandiet', 0.7780170440673828),
#  ('vechtersbaas', 0.7776827812194824),
#  ('indonesier', 0.77693772315979),
#  ('irakees', 0.7761123180389404),
#  ('ontdane', 0.775524377822876),
#  ('hoofdagente', 0.7750524282455444),
#  ('computerexpert', 0.7740706205368042),
#  ('terreurleider', 0.7738109827041626),
#  ('moslimextremist', 0.7737280130386353),
#  ('utrechtenaar', 0.7733469009399414),
#  ('fantast', 0.7725057005882263),
#  ('augustine', 0.7720747590065002),
#  ('gebedsgenezer', 0.7717594504356384),
#  ('albanees', 0.7715615630149841),
#  ('amersfoorter', 0.7704005837440491),
# ...

# %%
mtelegraaf.wv.most_similar(positive='afghanen', topn=100)
# Out:
# [('irakezen', 0.8462508916854858),
#  ('buitenlanders', 0.8200706839561462),
#  ('turken', 0.8053396940231323),
#  ('koerden', 0.8040456771850586),
#  ('gelovigen', 0.8006663918495178),
#  ('arabieren', 0.7961009740829468),
#  ('egyptenaren', 0.7881904244422913),
#  ('dorpelingen', 0.78614342212677),
#  ('westerlingen', 0.785214900970459),
#  ('palestijnen', 0.7818022966384888),
#  ('activisten', 0.777186393737793),
#  ('moslims', 0.7749897241592407),
#  ('arbeiders', 0.7745411992073059),
#  ('zakenmensen', 0.7730300426483154),
#  ('christenen', 0.7727875709533691),
#  ('militairen', 0.7695204019546509),
#  ('jagers', 0.7652971744537354),
#  ('jihadisten', 0.7640537023544312),
#  ('imams', 0.7633142471313477),
#  ('chinezen', 0.7628047466278076),
#  ('vissers', 0.7623950242996216),
#  ('serviers', 0.7600258588790894),
#  ('nigerianen', 0.7593512535095215),
#  ('dierenartsen', 0.7591872215270996),
#  ('middenstanders', 0.7586676478385925),
#  ('joden', 0.7584494352340698),
# ...

# %%
mtelegraaf.wv.most_similar(positive='syrier', topn=100)
# Out:
# [('rahman', 0.8560448884963989),
#  ('moslimextremist', 0.8502593040466309),
#  ('abdeslam', 0.8451031446456909),
#  ('rida', 0.8352029323577881),
#  ('topterrorist', 0.8332531452178955),
#  ('ferhat', 0.8287851810455322),
#  ('yar', 0.8276437520980835),
#  ('belkacem', 0.8261608481407166),
#  ('pakistaan', 0.8258832693099976),
#  ('adua', 0.8242403864860535),
#  ('aydin', 0.8242276906967163),
#  ('mullah', 0.8241727352142334),
#  ('basset', 0.8241269588470459),
#  ('umaru', 0.8230944871902466),
#  ('algerijn', 0.8228437900543213),
#  ('hoofddader', 0.8223994374275208),
#  ('luchtmachtcommandant', 0.8223820924758911),
#  ('malik', 0.8221062421798706),
#  ('osman', 0.8220629692077637),
#  ('walid', 0.8213292360305786),
#  ('draaideurcrimineel', 0.8204801082611084),
#  ('asari', 0.8198627233505249),
#  ('jabli', 0.8198612928390503),
#  ('adeel', 0.8163920640945435),
#  ('matschiner', 0.8161566853523254),
#  ('kalief', 0.8155893683433533),
#  ('aoulad', 0.8154635429382324),
# ...

# %%
mtelegraaf.wv.most_similar(positive='syriers', topn=100)
# Out:
# [('hilla', 0.8656678199768066),
#  ('mvanwinden', 0.8598378896713257),
#  ('doesjevina', 0.8517603874206543),
#  ('werkgeversverenigingen', 0.8489854335784912),
#  ('zarathustra', 0.8487660884857178),
#  ('marineofficieren', 0.8467235565185547),
#  ('meinhof', 0.84657222032547),
#  ('spreien', 0.8457835912704468),
#  ('caner', 0.8452879190444946),
#  ('ferronetti', 0.8447510004043579),
#  ('regeringswoordvoerders', 0.8445755243301392),
#  ('amador', 0.8441460132598877),
#  ('likhovtseva', 0.8440660834312439),
#  ('neust', 0.8435823321342468),
#  ('zonnet', 0.8433993458747864),
#  ('sschen', 0.8429927229881287),
#  ('macedo', 0.842319905757904),
#  ('tens', 0.842218279838562),
#  ('gernot', 0.8420819044113159),
#  ('bdsuniversal', 0.8419625759124756),
#  ('ultralinkse', 0.8417079448699951),
#  ('tikkanen', 0.8414751291275024),
#  ('lovergirls', 0.8410694003105164),
#  ('suleimani', 0.8407394289970398),
#  ('meselech', 0.8403003215789795),
#  ('servicepagina', 0.8399855494499207),
# ...

# %%
mtelegraaf.wv.most_similar(positive='somalier', topn=100)
# Out:
# [('kazaach', 0.8661596179008484),
#  ('provenzano', 0.8635312914848328),
#  ('roesink', 0.8622103929519653),
#  ('tiberius', 0.8560227751731873),
#  ('boral', 0.8455730676651001),
#  ('krzysztof', 0.8401013612747192),
#  ('bolets', 0.8350445032119751),
#  ('reeve', 0.8349170684814453),
#  ('colleen', 0.8339310884475708),
#  ('sjamil', 0.8334062099456787),
#  ('adoptiedochter', 0.8332703113555908),
#  ('vangelis', 0.8327255249023438),
#  ('bedreiger', 0.8325378894805908),
#  ('zimbabwaan', 0.8297292590141296),
#  ('beda', 0.8297118544578552),
#  ('plushenko', 0.8288346529006958),
#  ('annus', 0.8286830186843872),
#  ('callum', 0.8284753561019897),
#  ('norris', 0.8280556201934814),
#  ('sutter', 0.8277959227561951),
#  ('hsyk', 0.8276216387748718),
#  ('edoeard', 0.827195405960083),
#  ('carradine', 0.8265948295593262),
#  ('tiddo', 0.8265442848205566),
#  ('mcneill', 0.8264983296394348),
#  ('plummer', 0.8258224725723267),
#  ('covert', 0.8253432512283325),
# ...

# %%
mtelegraaf.wv.most_similar(positive='somaliers', topn=100)
# Out:
# [('bogdani', 0.9000464081764221),
#  ('pillay', 0.8988425731658936),
#  ('arnason', 0.8954900503158569),
#  ('autolakken', 0.8953274488449097),
#  ('makrani', 0.8915488123893738),
#  ('woonruimteverdeling', 0.8882734179496765),
#  ('zainab', 0.8865917921066284),
#  ('aldonin', 0.8851332068443298),
#  ('epureanu', 0.8843495845794678),
#  ('bdsgov', 0.8839669227600098),
#  ('omari', 0.8836321234703064),
#  ('arbeitman', 0.8835387229919434),
#  ('vasoski', 0.8827527165412903),
#  ('geromel', 0.8819571733474731),
#  ('djemba', 0.8817986845970154),
#  ('julianastaete', 0.8806325793266296),
#  ('gabasjvili', 0.8797401785850525),
#  ('ondernemerswereld', 0.8780615329742432),
#  ('vop', 0.8774008750915527),
#  ('metjo', 0.8771843910217285),
#  ('belaid', 0.8765960931777954),
#  ('cengiz', 0.8765314817428589),
#  ('levitin', 0.8765278458595276),
#  ('purmersteyn', 0.8762009739875793),
#  ('dekalim', 0.8760555982589722),
#  ('gagliardi', 0.874946117401123),
#  ('dwk', 0.8747807145118713),
# ...

# %%
mtelegraaf.wv.most_similar(positive='pool', topn=100)
# Out:
# [('oostenrijker', 0.8782970905303955),
#  ('roemeen', 0.8736348152160645),
#  ('hongaar', 0.863376259803772),
#  ('canadees', 0.8584938049316406),
#  ('bulgaar', 0.8581757545471191),
#  ('noor', 0.8495427966117859),
#  ('duitser', 0.8424407839775085),
#  ('colombiaan', 0.838180422782898),
#  ('engelsman', 0.8301053047180176),
#  ('arnhemmer', 0.8280767202377319),
#  ('tsjech', 0.8263223171234131),
#  ('drent', 0.8260772228240967),
#  ('griek', 0.8214589357376099),
#  ('japanner', 0.8197668790817261),
#  ('antilliaan', 0.8138599395751953),
#  ('australier', 0.8120717406272888),
#  ('mexicaan', 0.811992347240448),
#  ('nigeriaan', 0.8095151782035828),
#  ('argentijn', 0.805962085723877),
#  ('zweed', 0.8051812052726746),
#  ('fransman', 0.8042318820953369),
#  ('utrechter', 0.8025643825531006),
#  ('zwitser', 0.8012787699699402),
#  ('jongeling', 0.8007172346115112),
#  ('haarlemmer', 0.7991583943367004),
#  ('kroaat', 0.7985871434211731),
#  ('eindhovenaar', 0.7981375455856323),
# ...

# %%
mtelegraaf.wv.most_similar(positive='polen', topn=100)
# Out:
# [('duitsland', 0.8593623638153076),
#  ('hongarije', 0.8551285862922668),
#  ('roemeni', 0.8548816442489624),
#  ('bulgarije', 0.8433536291122437),
#  ('denemarken', 0.8390321731567383),
#  ('belgi', 0.8289816379547119),
#  ('turkije', 0.8276095390319824),
#  ('noorwegen', 0.8233267664909363),
#  ('spanje', 0.8220095038414001),
#  ('oostenrijk', 0.8191455602645874),
#  ('roemenie', 0.815614640712738),
#  ('portugal', 0.8134058713912964),
#  ('zweden', 0.8125318288803101),
#  ('itali', 0.8049938678741455),
#  ('italie', 0.8031584024429321),
#  ('frankrijk', 0.79804927110672),
#  ('litouwen', 0.7850112915039062),
#  ('belgie', 0.7846238017082214),
#  ('tsjechi', 0.7823996543884277),
#  ('finland', 0.7778909206390381),
#  ('ierland', 0.7778895497322083),
#  ('sloveni', 0.7742253541946411),
#  ('slowakije', 0.7717527747154236),
#  ('brazili', 0.7693201303482056),
#  ('estland', 0.767622709274292),
#  ('letland', 0.7661964893341064),
#  ('engeland', 0.7659419775009155),
# ...

# %% [markdown]
# ## 1b. Target categories:
# ### Immigranten groups // labels.

# %%
mtelegraaf.wv.most_similar(positive='arabier', topn=100)
# Out:
# [('terrier', 0.816531240940094),
#  ('roofvogel', 0.8121447563171387),
#  ('kangoeroe', 0.8106802105903625),
#  ('politieagente', 0.8069998621940613),
#  ('wildebras', 0.8062393069267273),
#  ('bandiet', 0.804396390914917),
#  ('medestander', 0.7952265739440918),
#  ('joegoslaaf', 0.7924076318740845),
#  ('neger', 0.7921730279922485),
#  ('hobbyist', 0.7888039350509644),
#  ('hamster', 0.7880364060401917),
#  ('legerofficier', 0.7866411805152893),
#  ('eekhoorn', 0.7844736576080322),
#  ('computerexpert', 0.7844172120094299),
#  ('vuilnisman', 0.7841987609863281),
#  ('maniak', 0.7827785015106201),
#  ('medepassagier', 0.7827322483062744),
#  ('drugsdealer', 0.7821516394615173),
#  ('fabrieksarbeider', 0.7818288207054138),
#  ('boerendochter', 0.7811185121536255),
#  ('indiaan', 0.7809444069862366),
#  ('bruidstaart', 0.7804890275001526),
#  ('verpleger', 0.7801880240440369),
#  ('poedel', 0.7785108089447021),
#  ('bendeleider', 0.7779577970504761),
# ...

# %%
mtelegraaf.wv.most_similar(positive='arabieren', topn=100)
# Out:
# [('christenen', 0.8659700155258179),
#  ('joden', 0.8609222173690796),
#  ('katholieken', 0.8430030345916748),
#  ('koerden', 0.8276682496070862),
#  ('soennieten', 0.8273835182189941),
#  ('turken', 0.824492335319519),
#  ('sjiieten', 0.8133496046066284),
#  ('irakezen', 0.8123641014099121),
#  ('russen', 0.8097208738327026),
#  ('islamieten', 0.8045533895492554),
#  ('canadezen', 0.8041493892669678),
#  ('moslims', 0.8036583065986633),
#  ('islamisten', 0.7983094453811646),
#  ('afghanen', 0.7961009740829468),
#  ('egyptenaren', 0.7948101758956909),
#  ('japanners', 0.7933206558227539),
#  ('milities', 0.7898699641227722),
#  ('immigranten', 0.7813525795936584),
#  ('gelovigen', 0.7787761688232422),
#  ('palestijnen', 0.778749942779541),
#  ('serviers', 0.7764825224876404),
#  ('communisten', 0.7705847024917603),
#  ('kolonisten', 0.7701067924499512),
#  ('arbeiders', 0.7667482495307922),
#  ('opstandelingen', 0.7661035656929016),
#  ('britten', 0.7629632353782654),
# ...

# %%
mtelegraaf.wv.most_similar(positive='moslim', topn=100)
# Out:
# [('jood', 0.7842611074447632),
#  ('politicus', 0.7715376019477844),
#  ('activist', 0.7528730630874634),
#  ('broederschap', 0.7467153072357178),
#  ('imam', 0.741396963596344),
#  ('vluchteling', 0.7390424013137817),
#  ('groepering', 0.7387834787368774),
#  ('islam', 0.7327210903167725),
#  ('terrorist', 0.7269124984741211),
#  ('asielzoeker', 0.7155278921127319),
#  ('terreurgroep', 0.713912844657898),
#  ('terreurbeweging', 0.7117919921875),
#  ('profeet', 0.7027359008789062),
#  ('strijder', 0.701130211353302),
#  ('jihad', 0.6985296607017517),
#  ('volksvertegenwoordiger', 0.6933323740959167),
#  ('seculiere', 0.6884022951126099),
#  ('ideologie', 0.6872600317001343),
#  ('terreurorganisatie', 0.6867574453353882),
#  ('presidentskandidaat', 0.6859778165817261),
#  ('diplomaat', 0.6816161870956421),
#  ('dictator', 0.6815043091773987),
#  ('sekte', 0.6784340143203735),
#  ('gelovige', 0.6734674572944641),
#  ('verrader', 0.6722356081008911),
# ...

# %%
mtelegraaf.wv.most_similar(positive='moslims', topn=100)
# Out:
# [('christenen', 0.8956969380378723),
#  ('joden', 0.891379714012146),
#  ('gelovigen', 0.887080729007721),
#  ('palestijnen', 0.8412386178970337),
#  ('extremisten', 0.8157811760902405),
#  ('islamieten', 0.8142099380493164),
#  ('koerden', 0.8098809123039246),
#  ('arabieren', 0.8036582469940186),
#  ('imams', 0.8006523847579956),
#  ('turken', 0.8001991510391235),
#  ('soennieten', 0.7991151213645935),
#  ('homoseksuelen', 0.7927178740501404),
#  ('katholieken', 0.7916038632392883),
#  ('jihadisten', 0.7908236980438232),
#  ('islamisten', 0.7770986557006836),
#  ('terroristen', 0.7768006324768066),
#  ('afghanen', 0.774989664554596),
#  ('geestelijken', 0.7742947340011597),
#  ('vluchtelingen', 0.770850419998169),
#  ('immigranten', 0.7696608304977417),
#  ('sjiieten', 0.7666826248168945),
#  ('activisten', 0.7660955190658569),
#  ('buitenlanders', 0.7646586894989014),
#  ('allochtonen', 0.7634124755859375),
#  ('burgers', 0.7628480195999146),
# ...

# %%
mtelegraaf.wv.most_similar(positive='vluchteling', topn=100)
# Out:
# [('asielzoeker', 0.7814146280288696),
#  ('jood', 0.7594494819641113),
#  ('moslim', 0.7390424013137817),
#  ('strijder', 0.7372229099273682),
#  ('misdadiger', 0.7057485580444336),
#  ('martelaar', 0.7016940116882324),
#  ('priester', 0.7014344334602356),
#  ('jihadist', 0.6961844563484192),
#  ('monnik', 0.6923567652702332),
#  ('vreemdeling', 0.6811343431472778),
#  ('imam', 0.6785295605659485),
#  ('tiran', 0.6719934940338135),
#  ('immigrant', 0.6701030731201172),
#  ('oorlogsmisdadiger', 0.6692038774490356),
#  ('migrant', 0.6682322025299072),
#  ('loodgieter', 0.6625766754150391),
#  ('gevangene', 0.660557746887207),
#  ('hulpverlener', 0.6565949320793152),
#  ('sekte', 0.6519337892532349),
#  ('terrorist', 0.6500011682510376),
#  ('slaaf', 0.6484774351119995),
#  ('palestijn', 0.6482569575309753),
#  ('prediker', 0.647945761680603),
#  ('tolk', 0.646638035774231),
#  ('onderduikster', 0.6433335542678833),
#  ('verrader', 0.6420539617538452),
# ...

# %%
mtelegraaf.wv.most_similar(positive='vluchtelingen', topn=100)
# Out:
# [('migranten', 0.902317225933075),
#  ('immigranten', 0.8759124279022217),
#  ('asielzoekers', 0.8592453002929688),
#  ('illegalen', 0.8509526252746582),
#  ('koerden', 0.8130890130996704),
#  ('buitenlanders', 0.7973807454109192),
#  ('palestijnen', 0.7964481115341187),
#  ('arbeiders', 0.789433479309082),
#  ('vreemdelingen', 0.7884740829467773),
#  ('gevangenen', 0.7862050533294678),
#  ('jihadisten', 0.7800766229629517),
#  ('joden', 0.7724477648735046),
#  ('moslims', 0.7708504796028137),
#  ('irakezen', 0.7686419486999512),
#  ('gelukszoekers', 0.7658798098564148),
#  ('gelovigen', 0.7603704929351807),
#  ('strijders', 0.7587106823921204),
#  ('christenen', 0.75804603099823),
#  ('afghanen', 0.7546713352203369),
#  ('burgers', 0.7527133822441101),
#  ('gedetineerden', 0.7352504730224609),
#  ('toeristen', 0.7328243255615234),
#  ('militairen', 0.7321791648864746),
#  ('betogers', 0.7287400960922241),
#  ('boeren', 0.7264747619628906),
#  ('soldaten', 0.7208993434906006),
# ...

# %%
mtelegraaf.wv.most_similar(positive='allochtoon', topn=100)
# Out:
# [('autochtoon', 0.6839605569839478),
#  ('analfabeet', 0.6370508670806885),
#  ('autochtone', 0.584402322769165),
#  ('lesbisch', 0.581451952457428),
#  ('ongelovige', 0.5747076272964478),
#  ('moslim', 0.5731228590011597),
#  ('alleenstaande', 0.5630308985710144),
#  ('plusser', 0.5630012154579163),
#  ('zinnig', 0.5619817972183228),
#  ('discriminerend', 0.5612885355949402),
#  ('adhd', 0.5599732398986816),
#  ('ongewenst', 0.55991131067276),
#  ('verwerpelijk', 0.5571750402450562),
#  ('katholiek', 0.545871376991272),
#  ('humaan', 0.5403079986572266),
#  ('gelovige', 0.5382604598999023),
#  ('discrimineert', 0.5381001830101013),
#  ('allochtone', 0.531394898891449),
#  ('hufterig', 0.5284942388534546),
#  ('ongehuwd', 0.5278154611587524),
#  ('besnijdenis', 0.5258658528327942),
#  ('discrimineren', 0.5251214504241943),
#  ('obesitas', 0.5249079465866089),
#  ('asociaal', 0.5228145718574524),
#  ('alleenstaand', 0.5223649740219116),
#  ('rolmodel', 0.5210831165313721),
# ...

# %%
mtelegraaf.wv.most_similar(positive='allochtonen', topn=100)
# Out:
# [('autochtonen', 0.8351535201072693),
#  ('antillianen', 0.7838608026504517),
#  ('ouderen', 0.7744934558868408),
#  ('plussers', 0.7668195962905884),
#  ('allochtone', 0.7648686170578003),
#  ('moslims', 0.7634124755859375),
#  ('marokkanen', 0.762535810470581),
#  ('leraren', 0.7598398923873901),
#  ('jongeren', 0.7574905157089233),
#  ('homoseksuelen', 0.7470705509185791),
#  ('senioren', 0.7430775165557861),
#  ('minderheden', 0.7416679859161377),
#  ('buitenlanders', 0.7400840520858765),
#  ('gezinnen', 0.7315922975540161),
#  ('migranten', 0.7262035608291626),
#  ('docenten', 0.7235515117645264),
#  ('scholen', 0.7192979454994202),
#  ('werkenden', 0.7190707921981812),
#  ('huisartsen', 0.7177306413650513),
#  ('burgers', 0.7091936469078064),
#  ('organisaties', 0.7072732448577881),
#  ('gelovigen', 0.700511634349823),
#  ('vreemdelingen', 0.6980263590812683),
#  ('groepen', 0.6967686414718628),
#  ('mantelzorgers', 0.6957005262374878),
#  ('surinamers', 0.6953871846199036),
# ...

# %%
mtelegraaf.wv.most_similar(positive='immigrant', topn=100)
# Out:
# [('edelman', 0.8273639678955078),
#  ('jihadist', 0.8170940279960632),
#  ('arbeider', 0.7898138761520386),
#  ('gangster', 0.7775537967681885),
#  ('missionaris', 0.7763836979866028),
#  ('draagmoeder', 0.7735559940338135),
#  ('prostituee', 0.7720534801483154),
#  ('toeriste', 0.7649951577186584),
#  ('monnik', 0.7630180716514587),
#  ('avonturier', 0.7616101503372192),
#  ('turk', 0.7563368082046509),
#  ('kleermaker', 0.7560043334960938),
#  ('boerenzoon', 0.755452573299408),
#  ('strijder', 0.7540552616119385),
#  ('hippie', 0.7539859414100647),
#  ('spion', 0.7539700269699097),
#  ('spionne', 0.7485959529876709),
#  ('indiaan', 0.7482704520225525),
#  ('volbloed', 0.7474238872528076),
#  ('bouwvakker', 0.7427722215652466),
#  ('loodgieter', 0.7410707473754883),
#  ('asielzoeker', 0.7388652563095093),
#  ('antilliaan', 0.7352997064590454),
#  ('jood', 0.7352585196495056),
#  ('ontdekkingsreiziger', 0.7343559265136719),
#  ('gevangene', 0.7341797947883606),
# ...

# %%
mtelegraaf.wv.most_similar(positive='immigranten', topn=100)
# Out:
# [('migranten', 0.9184063076972961),
#  ('arbeiders', 0.8770569562911987),
#  ('vluchtelingen', 0.8759123682975769),
#  ('jihadisten', 0.8470813632011414),
#  ('buitenlanders', 0.8408422470092773),
#  ('illegalen', 0.8187549114227295),
#  ('gastarbeiders', 0.8178820610046387),
#  ('strijders', 0.8128985166549683),
#  ('koerden', 0.8103504180908203),
#  ('kolonisten', 0.7923635840415955),
#  ('gelukszoekers', 0.7901114225387573),
#  ('joden', 0.789193868637085),
#  ('bendes', 0.7882931232452393),
#  ('gevangenen', 0.7879173755645752),
#  ('arabieren', 0.7813524603843689),
#  ('irakezen', 0.7794246077537537),
#  ('soldaten', 0.7768445611000061),
#  ('prostituees', 0.7716677784919739),
#  ('activisten', 0.7711285948753357),
#  ('moslims', 0.7696608304977417),
#  ('milities', 0.769585132598877),
#  ('vreemdelingen', 0.7638680338859558),
#  ('boeren', 0.7590842247009277),
#  ('extremisten', 0.7558577060699463),
#  ('gelovigen', 0.7549872398376465),
#  ('afghanen', 0.7536804676055908),
# ...

# %%
mtelegraaf.wv.most_similar(positive='migrant', topn=100)
# Out:
# [('missverkiezing', 0.7168298959732056),
#  ('immigrant', 0.7145519852638245),
#  ('bekeerling', 0.6834810972213745),
#  ('cursist', 0.6767948865890503),
#  ('tiran', 0.6751466989517212),
#  ('vertakking', 0.6743524074554443),
#  ('wereldburger', 0.6709495782852173),
#  ('vluchteling', 0.6682321429252625),
#  ('palestijn', 0.6657999753952026),
#  ('schandvlek', 0.6657373309135437),
#  ('jood', 0.6619450449943542),
#  ('wijnliefhebber', 0.6613544225692749),
#  ('jihadist', 0.6606724262237549),
#  ('londenaar', 0.6588650941848755),
#  ('pakistaan', 0.656804621219635),
#  ('arbeider', 0.6563414931297302),
#  ('emigrant', 0.6551600098609924),
#  ('haatprediker', 0.6550542116165161),
#  ('eenheidsstaat', 0.6539890766143799),
#  ('strafklacht', 0.6518615484237671),
#  ('grenswacht', 0.6513990759849548),
#  ('vakantievierder', 0.6513005495071411),
#  ('ingezetene', 0.6509145498275757),
#  ('onderduikster', 0.6503579616546631),
#  ('liefdadigheidsinstelling', 0.6499364376068115),
# ...

# %%
mtelegraaf.wv.most_similar(positive='migranten', topn=100)
# Out:
# [('immigranten', 0.9184063673019409),
#  ('vluchtelingen', 0.902317225933075),
#  ('arbeiders', 0.8309832215309143),
#  ('gelukszoekers', 0.8166047930717468),
#  ('buitenlanders', 0.8152471780776978),
#  ('illegalen', 0.8052966594696045),
#  ('asielzoekers', 0.7865155935287476),
#  ('boeren', 0.7856006622314453),
#  ('jihadisten', 0.7789011597633362),
#  ('koerden', 0.775067150592804),
#  ('arbeidsmigranten', 0.7627522349357605),
#  ('gastarbeiders', 0.7621623277664185),
#  ('vreemdelingen', 0.7555794715881348),
#  ('moslims', 0.7461655139923096),
#  ('gelovigen', 0.7441074848175049),
#  ('chinezen', 0.7404809594154358),
#  ('arabieren', 0.7386443614959717),
#  ('vakantiegangers', 0.737900972366333),
#  ('telers', 0.7378936409950256),
#  ('afghanen', 0.733295202255249),
#  ('joden', 0.7329500913619995),
#  ('expats', 0.7321593761444092),
#  ('vissers', 0.7264035940170288),
#  ('strijders', 0.7262541651725769),
#  ('allochtonen', 0.7262036204338074),
# ...

# %%
mtelegraaf.wv.most_similar(positive='expat', topn=100)
# Out:
# [('asito', 0.8107094764709473),
#  ('marsudi', 0.8000760078430176),
#  ('wijkzuster', 0.7913568019866943),
#  ('vck', 0.786821186542511),
#  ('rappange', 0.7862110137939453),
#  ('moerkerken', 0.7859421968460083),
#  ('img', 0.7849538326263428),
#  ('shirin', 0.7836610078811646),
#  ('buikdanseres', 0.7830686569213867),
#  ('onky', 0.7824969291687012),
#  ('natuurorganisatie', 0.7821998000144958),
#  ('vakantiekampen', 0.7816742062568665),
#  ('modint', 0.7804208993911743),
#  ('fmo', 0.77962726354599),
#  ('marineofficieren', 0.7792953252792358),
#  ('syngenta', 0.7789266705513),
#  ('gruenfeld', 0.7785696983337402),
#  ('aumacon', 0.7778512835502625),
#  ('ndlovu', 0.7777063250541687),
#  ('vivara', 0.7775424718856812),
#  ('kantongerecht', 0.7775372266769409),
#  ('stadsbeiaardier', 0.7771385908126831),
#  ('uitvaartbranche', 0.7761279344558716),
#  ('werkgeversbond', 0.7754130959510803),
#  ('zheyun', 0.7741036415100098),
#  ('rozenboom', 0.7736954092979431),
# ...

# %%
mtelegraaf.wv.most_similar(positive='expats', topn=100)
# Out:
# [('zakenmensen', 0.8505687713623047),
#  ('zakenlui', 0.804084837436676),
#  ('arbeiders', 0.7932776212692261),
#  ('verzamelaars', 0.7874038815498352),
#  ('transporteurs', 0.774877667427063),
#  ('sportverenigingen', 0.7699209451675415),
#  ('kwekers', 0.7633824944496155),
#  ('tuinders', 0.7633284330368042),
#  ('verenigingen', 0.7554726004600525),
#  ('stedelingen', 0.7537429332733154),
#  ('bedrijfjes', 0.7517422437667847),
#  ('dierentuinen', 0.7511281967163086),
#  ('zakenlieden', 0.7482793927192688),
#  ('kooplieden', 0.7431575059890747),
#  ('sportclubs', 0.7374858260154724),
#  ('senioren', 0.734649658203125),
#  ('professionals', 0.7328776717185974),
#  ('ambassades', 0.7327818870544434),
#  ('migranten', 0.7321592569351196),
#  ('transportbedrijven', 0.7301019430160522),
#  ('touroperators', 0.7290980815887451),
#  ('vijftigplussers', 0.7282091975212097),
#  ('academici', 0.7280771136283875),
#  ('entrepreneurs', 0.7262917757034302),
# ...

# %% [markdown]
# # 1a. Reference categories
# Selected on the basis of in-groups ('nederlander (s)' and 'wester(s)' as well as the largest west-european migrant groups living in the Netherlands, according to Statistics Netherlands:  https://www.cbs.nl/nl-nl/achtergrond/2016/47/bevolking-naar-migratieachtergrond)

# %%
mtelegraaf.wv.most_similar(positive='nederlander', topn=100)
# Out:
# [('atleet', 0.7947022318840027),
#  ('amsterdammer', 0.7903258800506592),
#  ('belg', 0.7869824171066284),
#  ('brabander', 0.7751535177230835),
#  ('duitser', 0.7726234197616577),
#  ('amerikaan', 0.7725403904914856),
#  ('brit', 0.7492687702178955),
#  ('tukker', 0.7480319738388062),
#  ('limburger', 0.7413208484649658),
#  ('utrechter', 0.7368019819259644),
#  ('rotterdammer', 0.7358899116516113),
#  ('fransman', 0.7341612577438354),
#  ('griek', 0.7314938306808472),
#  ('japanner', 0.731432318687439),
#  ('renner', 0.7286304235458374),
#  ('golfer', 0.7282004356384277),
#  ('zwemmer', 0.7212816476821899),
#  ('engelsman', 0.7186734676361084),
#  ('zwitser', 0.7183371186256409),
#  ('klimmer', 0.7130215167999268),
#  ('hagenaar', 0.7122793197631836),
#  ('tennisser', 0.7116682529449463),
#  ('italiaan', 0.7054458260536194),
#  ('speelster', 0.70050048828125),
#  ('spanjaard', 0.6968536376953125),
#  ('deen', 0.6964069604873657),
#  ('jongeling', 0.6960067749023438),
# ...

# %%
mtelegraaf.wv.most_similar(positive='nederlanders', topn=100)
# Out:
# [('chinezen', 0.7941722273826599),
#  ('vakantiegangers', 0.7937586307525635),
#  ('buitenlanders', 0.7894184589385986),
#  ('mensen', 0.7697334289550781),
#  ('landgenoten', 0.7651491761207581),
#  ('turken', 0.7559657096862793),
#  ('britten', 0.7521408796310425),
#  ('toeristen', 0.7491564750671387),
#  ('brazilianen', 0.7448400259017944),
#  ('hagenaars', 0.7410067319869995),
#  ('belgen', 0.7313399314880371),
#  ('jongelui', 0.7307566404342651),
#  ('wintersporters', 0.7299485802650452),
#  ('gezinnen', 0.7261366844177246),
#  ('zwemmers', 0.7249292135238647),
#  ('amerikanen', 0.7240636348724365),
#  ('inwoners', 0.7228651642799377),
#  ('japanners', 0.7131386995315552),
#  ('deelnemers', 0.7102855443954468),
#  ('afghanen', 0.7082324624061584),
#  ('jongeren', 0.7016686797142029),
#  ('italianen', 0.7014920711517334),
#  ('nieuwkomers', 0.7001785039901733),
#  ('vlamingen', 0.6989171504974365),
#  ('rokers', 0.6964359283447266),
#  ('aziaten', 0.6952770948410034),
# ...

# %%
mtelegraaf.wv.most_similar(positive='belg', topn=100)
# Out:
# [('zweed', 0.9271366596221924),
#  ('duitser', 0.9057999849319458),
#  ('fransman', 0.9048789143562317),
#  ('deen', 0.8973364233970642),
#  ('zwitser', 0.8934333324432373),
#  ('routinier', 0.890813946723938),
#  ('italiaan', 0.8821077346801758),
#  ('engelsman', 0.8787215948104858),
#  ('spanjaard', 0.8770931959152222),
#  ('jongeling', 0.8682834506034851),
#  ('noor', 0.8677343130111694),
#  ('braziliaan', 0.861203670501709),
#  ('brabander', 0.859451949596405),
#  ('griek', 0.8563786745071411),
#  ('tukker', 0.8543531894683838),
#  ('oostenrijker', 0.8524148464202881),
#  ('limburger', 0.8498700857162476),
#  ('argentijn', 0.8484163284301758),
#  ('utrechter', 0.840478777885437),
#  ('drent', 0.8372503519058228),
#  ('japanner', 0.8369908928871155),
#  ('australier', 0.8368790745735168),
#  ('tsjech', 0.8341914415359497),
#  ('brit', 0.8327353596687317),
#  ('roemeen', 0.8272056579589844),
#  ('hongaar', 0.8230100870132446),
#  ('slowaak', 0.8143281936645508),
# ...

# %%
mtelegraaf.wv.most_similar(positive='belgen', topn=100)
# Out:
# [('fransen', 0.9324578046798706),
#  ('italianen', 0.9221193790435791),
#  ('denen', 0.9099116325378418),
#  ('duitsers', 0.8976277112960815),
#  ('noren', 0.8902859091758728),
#  ('spanjaarden', 0.8878127932548523),
#  ('engelsen', 0.8865900039672852),
#  ('britten', 0.8829647898674011),
#  ('ieren', 0.8744770288467407),
#  ('finnen', 0.8555867075920105),
#  ('japanners', 0.8549094200134277),
#  ('russen', 0.8524045944213867),
#  ('brazilianen', 0.8512783646583557),
#  ('turken', 0.8481141328811646),
#  ('portugezen', 0.846558690071106),
#  ('argentijnen', 0.8213388919830322),
#  ('schotten', 0.8175342082977295),
#  ('amerikanen', 0.81598961353302),
#  ('vlamingen', 0.8104592561721802),
#  ('oostenrijkers', 0.8034409284591675),
#  ('aziaten', 0.797643780708313),
#  ('chinezen', 0.790825605392456),
#  ('groningers', 0.7852332592010498),
#  ('hongaren', 0.7801046371459961),
#  ('friezen', 0.7766829133033752),
#  ('canadezen', 0.7728058099746704),
#  ('brabanders', 0.769925594329834),
# ...

# %%
mtelegraaf.wv.most_similar(positive='duitser', topn=100)
# Out:
# [('fransman', 0.9480106830596924),
#  ('zwitser', 0.9254431128501892),
#  ('italiaan', 0.9202629923820496),
#  ('spanjaard', 0.9107276797294617),
#  ('belg', 0.9058001041412354),
#  ('brit', 0.9043248891830444),
#  ('oostenrijker', 0.89319908618927),
#  ('zweed', 0.8927046060562134),
#  ('noor', 0.8901834487915039),
#  ('engelsman', 0.8877158164978027),
#  ('japanner', 0.880130410194397),
#  ('australier', 0.8779218792915344),
#  ('amerikaan', 0.8744149208068848),
#  ('canadees', 0.8728102445602417),
#  ('roemeen', 0.8617589473724365),
#  ('argentijn', 0.8580112457275391),
#  ('tsjech', 0.8555545210838318),
#  ('pool', 0.8424407839775085),
#  ('hongaar', 0.8403931856155396),
#  ('jongeling', 0.8397666215896606),
#  ('slowaak', 0.8356661796569824),
#  ('griek', 0.8352223634719849),
#  ('routinier', 0.8334987759590149),
#  ('colombiaan', 0.8301515579223633),
#  ('deen', 0.8285542726516724),
#  ('kroaat', 0.8257812857627869),
#  ('mexicaan', 0.8254745602607727),
# ...

# %%
mtelegraaf.wv.most_similar(positive='duitsers', topn=100)
# Out:
# [('fransen', 0.9096890687942505),
#  ('ieren', 0.90590500831604),
#  ('italianen', 0.8978772759437561),
#  ('belgen', 0.8976277112960815),
#  ('russen', 0.8970063924789429),
#  ('engelsen', 0.8937696218490601),
#  ('britten', 0.8897774815559387),
#  ('denen', 0.8891787528991699),
#  ('spanjaarden', 0.8844319581985474),
#  ('amerikanen', 0.8733968734741211),
#  ('turken', 0.8602790236473083),
#  ('japanners', 0.8591381907463074),
#  ('noren', 0.8560976982116699),
#  ('portugezen', 0.8248807787895203),
#  ('finnen', 0.8073155879974365),
#  ('aziaten', 0.8063216209411621),
#  ('argentijnen', 0.8011688590049744),
#  ('chinezen', 0.7935513257980347),
#  ('canadezen', 0.7829763293266296),
#  ('brazilianen', 0.7809776067733765),
#  ('schotten', 0.7792103290557861),
#  ('hongaren', 0.7778168320655823),
#  ('roemenen', 0.7559288144111633),
#  ('tsjechen', 0.752692699432373),
#  ('groningers', 0.743323564529419),
#  ('arabieren', 0.7406027913093567),
#  ('bulgaren', 0.7362143397331238),
# ...

# %%
mtelegraaf.wv.most_similar(positive='westers', topn=100)
# Out:
# [('religieus', 0.7308582067489624),
#  ('beschaafd', 0.7237198352813721),
#  ('welvarend', 0.7221300601959229),
#  ('aziatisch', 0.7021076679229736),
#  ('islamitisch', 0.677737295627594),
#  ('spiritueel', 0.6740028858184814),
#  ('primitief', 0.6711267232894897),
#  ('vooruitstrevend', 0.6578067541122437),
#  ('indisch', 0.6499528884887695),
#  ('organiserend', 0.6441942453384399),
#  ('palestijns', 0.6423906683921814),
#  ('eeuwenoud', 0.6402204036712646),
#  ('joods', 0.6396373510360718),
#  ('communistisch', 0.6380312442779541),
#  ('dictatoriaal', 0.637892484664917),
#  ('tuinbouworganisatie', 0.6373928785324097),
#  ('alledaags', 0.626305341720581),
#  ('humanitair', 0.6242828369140625),
#  ('invloedrijk', 0.6242557764053345),
#  ('christelijk', 0.6240817308425903),
#  ('ontwikkelingsland', 0.6237474679946899),
#  ('russisch', 0.6235314607620239),
#  ('toeristisch', 0.6216622591018677),
#  ('arabisch', 0.6193153858184814),
#  ('federaal', 0.615891695022583),
# ...

# %%
mtelegraaf.wv.most_similar(positive='christen', topn=100)
# Out:
# [('fdp', 0.8236947059631348),
#  ('csu', 0.8128479719161987),
#  ('cdu', 0.8119060397148132),
#  ('liberale', 0.8025404214859009),
#  ('democraten', 0.7896556854248047),
#  ('spd', 0.7839767932891846),
#  ('liberaal', 0.7826300263404846),
#  ('groenen', 0.7819716930389404),
#  ('regeringspartij', 0.7791405916213989),
#  ('coalitiepartner', 0.765555739402771),
#  ('democraat', 0.7633552551269531),
#  ('conservatieve', 0.7564718127250671),
#  ('sociaaldemocratische', 0.7555450201034546),
#  ('rechtse', 0.7490009665489197),
#  ('christendemocraten', 0.7446308135986328),
#  ('labour', 0.7419344186782837),
#  ('nationalistische', 0.7416281700134277),
#  ('conservatieven', 0.7386454939842224),
#  ('anc', 0.7356815338134766),
#  ('socialisten', 0.7334508895874023),
#  ('socialistische', 0.7328237295150757),
#  ('ump', 0.7313377857208252),
#  ('pasok', 0.729978084564209),
#  ('akp', 0.7298823595046997),
#  ('democratische', 0.7281879186630249),
#  ('senator', 0.7279895544052124),
# ...

# %%
mtelegraaf.wv.most_similar(positive='christenen', topn=100)
# Out:
# [('joden', 0.9193923473358154),
#  ('moslims', 0.8956969380378723),
#  ('soennieten', 0.8689225316047668),
#  ('arabieren', 0.8659698963165283),
#  ('koerden', 0.8635465502738953),
#  ('sjiieten', 0.8520265817642212),
#  ('katholieken', 0.8502001166343689),
#  ('islamieten', 0.8343326449394226),
#  ('palestijnen', 0.8303964138031006),
#  ('gelovigen', 0.8224778175354004),
#  ('extremisten', 0.812103271484375),
#  ('islamisten', 0.8068023920059204),
#  ('kolonisten', 0.7981356382369995),
#  ('milities', 0.7928575873374939),
#  ('homoseksuelen', 0.7854083776473999),
#  ('turken', 0.7822248935699463),
#  ('protestanten', 0.781241774559021),
#  ('minderheden', 0.7809733152389526),
#  ('geestelijken', 0.7781268358230591),
#  ('afghanen', 0.7727875709533691),
#  ('fundamentalisten', 0.7710219025611877),
#  ('rebellen', 0.768635630607605),
#  ('terroristen', 0.7678090929985046),
#  ('ongelovigen', 0.76070237159729),
#  ('moslimextremisten', 0.7596327662467957),
# ...
