# %% [markdown]
# # Detecting attributes (e.g., stereotypes) on the basis on np data
# ## Data trained on time period: 2000 - 2016

# %%
import gensim

# %%
PATH = "/Users/admin/surfdrive/Werk/projects/17_mediabias/mediabias/trained_models/2000_2016/"

# %% [markdown]
# # Newspaper: Trouw

# %%
mtr = gensim.models.Word2Vec.load(PATH + 'trouw')

# %% [markdown]
# ## 1a. Target categories:
# ### Bevolkingsgroepen
# https://www.cbs.nl/nl-nl/achtergrond/2016/47/bevolking-naar-migratieachtergrond

# %%
mtr.wv.most_similar(positive='marokkaan', topn=100)
# Out:
# [('turk', 0.862625002861023),
#  ('politieagent', 0.765763521194458),
#  ('vrachtwagenchauffeur', 0.755788266658783),
#  ('buitenlander', 0.754590630531311),
#  ('taxichauffeur', 0.7495706081390381),
#  ('bouwvakker', 0.7420836687088013),
#  ('jongeman', 0.741142988204956),
#  ('afghaan', 0.7408460974693298),
#  ('politieman', 0.7362526655197144),
#  ('surinamer', 0.7334657907485962),
#  ('pedofiel', 0.731298565864563),
#  ('antilliaan', 0.7298048734664917),
#  ('marinier', 0.7293119430541992),
#  ('jongen', 0.7283872365951538),
#  ('irakees', 0.7273112535476685),
#  ('schutter', 0.7221640944480896),
#  ('rotterdammer', 0.7217530012130737),
#  ('tiener', 0.7204954624176025),
#  ('arabier', 0.7200922966003418),
#  ('terrorist', 0.715623140335083),
#  ('zwerver', 0.7136519551277161),
#  ('palestijn', 0.7121875286102295),
#  ('misdadiger', 0.7106316089630127),
#  ('algerijn', 0.7102590799331665),
#  ('prostituee', 0.7101277112960815),
#  ('mijnwerker', 0.702020525932312),
# ...

# %%
mtr.wv.most_similar(positive='marokkanen', topn=100)
# Out:
# [('antillianen', 0.8883103132247925),
#  ('surinamers', 0.8766091465950012),
#  ('turken', 0.8353134989738464),
#  ('allochtonen', 0.8010791540145874),
#  ('autochtonen', 0.7743469476699829),
#  ('molukkers', 0.7502844333648682),
#  ('moslims', 0.741929292678833),
#  ('nederlanders', 0.7377084493637085),
#  ('buitenlanders', 0.7280998229980469),
#  ('migranten', 0.7216916084289551),
#  ('autochtone', 0.7209246158599854),
#  ('roemenen', 0.7187017202377319),
#  ('moslimjongeren', 0.7121654152870178),
#  ('immigranten', 0.7029147148132324),
#  ('zwarten', 0.6958867311477661),
#  ('islamieten', 0.6871042251586914),
#  ('jongeren', 0.6869474649429321),
#  ('imams', 0.6814166307449341),
#  ('christenen', 0.6802512407302856),
#  ('boeddhisten', 0.6761049032211304),
#  ('vlamingen', 0.673426628112793),
#  ('moslimvrouwen', 0.6721979379653931),
#  ('bulgaren', 0.6713094711303711),
#  ('afghanen', 0.6707008481025696),
#  ('somaliers', 0.6693916320800781),
# ...

# %%
mtr.wv.most_similar(positive='turk', topn=100)
# Out:
# [('marokkaan', 0.862625002861023),
#  ('afghaan', 0.8076217770576477),
#  ('arabier', 0.7877899408340454),
#  ('irakees', 0.7771334648132324),
#  ('buitenlander', 0.7743163108825684),
#  ('antilliaan', 0.7721502184867859),
#  ('surinamer', 0.7670154571533203),
#  ('vrachtwagenchauffeur', 0.7606071829795837),
#  ('palestijn', 0.7535672783851624),
#  ('taxichauffeur', 0.7521066665649414),
#  ('misdadiger', 0.7488673329353333),
#  ('rebel', 0.7471352815628052),
#  ('pakistaan', 0.7463154196739197),
#  ('terrorist', 0.7451075315475464),
#  ('immigrant', 0.7423945069313049),
#  ('politieagent', 0.7421534657478333),
#  ('griek', 0.741623044013977),
#  ('bouwvakker', 0.7395472526550293),
#  ('koerd', 0.7348949313163757),
#  ('jood', 0.7328276634216309),
#  ('rotterdammer', 0.7312026023864746),
#  ('algerijn', 0.7273743152618408),
#  ('strijder', 0.7232969999313354),
#  ('pedofiel', 0.7223079204559326),
#  ('oorlogsmisdadiger', 0.7208248376846313),
#  ('politieman', 0.7173490524291992),
# ...

# %%
mtr.wv.most_similar(positive='turken', topn=100)
# Out:
# [('marokkanen', 0.8353134989738464),
#  ('duitsers', 0.8338125944137573),
#  ('koerden', 0.8231783509254456),
#  ('hongaren', 0.8155510425567627),
#  ('surinamers', 0.8094726800918579),
#  ('molukkers', 0.8078573942184448),
#  ('fransen', 0.8059737682342529),
#  ('ieren', 0.7961466312408447),
#  ('moslims', 0.7959619760513306),
#  ('egyptenaren', 0.7901836633682251),
#  ('belgen', 0.7897782325744629),
#  ('christenen', 0.7895539999008179),
#  ('russen', 0.789456844329834),
#  ('nederlanders', 0.7879650592803955),
#  ('arabieren', 0.7863295078277588),
#  ('albanezen', 0.7862337827682495),
#  ('grieken', 0.7853810787200928),
#  ('spanjaarden', 0.7836886644363403),
#  ('buitenlanders', 0.7836686372756958),
#  ('vlamingen', 0.7836155891418457),
#  ('afghanen', 0.7818266153335571),
#  ('denen', 0.7804691195487976),
#  ('italianen', 0.7749364376068115),
#  ('joden', 0.7679766416549683),
#  ('japanners', 0.7674958109855652),
#  ('serviers', 0.7640801668167114),
# ...

# %%
mtr.wv.most_similar(positive='surinamer', topn=100)
# Out:
# [('oplichter', 0.8125821352005005),
#  ('travestiet', 0.8125101327896118),
#  ('stalker', 0.8072340488433838),
#  ('zonderling', 0.793394148349762),
#  ('indiaan', 0.7876002788543701),
#  ('somalier', 0.7860097885131836),
#  ('sukkel', 0.7850919961929321),
#  ('zeventigjarige', 0.7849611043930054),
#  ('loser', 0.7848615646362305),
#  ('huisvader', 0.7836462259292603),
#  ('antilliaan', 0.78175288438797),
#  ('kluizenaar', 0.7791138887405396),
#  ('gentleman', 0.7774651646614075),
#  ('veertiger', 0.7772195935249329),
#  ('serveerster', 0.7768526077270508),
#  ('goochelaar', 0.7767914533615112),
#  ('fantast', 0.7727380990982056),
#  ('zigeuner', 0.7677454948425293),
#  ('turk', 0.7670154571533203),
#  ('titelheld', 0.765851616859436),
#  ('automonteur', 0.7638354301452637),
#  ('arabier', 0.7626912593841553),
#  ('lotgenoot', 0.7624981999397278),
#  ('psychopaat', 0.7607035636901855),
#  ('pakistaan', 0.7604076862335205),
#  ('huurmoordenaar', 0.7590832710266113),
# ...

# %%
mtr.wv.most_similar(positive='surinamers', topn=100)
# Out:
# [('marokkanen', 0.8766091465950012),
#  ('antillianen', 0.8610169291496277),
#  ('turken', 0.8094726800918579),
#  ('hindoestanen', 0.8027799129486084),
#  ('molukkers', 0.7905706167221069),
#  ('aziaten', 0.7633292078971863),
#  ('autochtonen', 0.7588027715682983),
#  ('indiers', 0.7430318593978882),
#  ('pakistanen', 0.7401566505432129),
#  ('autochtone', 0.736513614654541),
#  ('boeddhisten', 0.7322866320610046),
#  ('roemenen', 0.7322584390640259),
#  ('ghanezen', 0.7241460084915161),
#  ('academici', 0.7236270308494568),
#  ('arubanen', 0.7235753536224365),
#  ('zwarten', 0.7233937382698059),
#  ('hongaren', 0.7147508859634399),
#  ('nederlanders', 0.7142758369445801),
#  ('allochtonen', 0.7107165455818176),
#  ('vlamingen', 0.7066136598587036),
#  ('zigeuners', 0.7053413391113281),
#  ('bulgaren', 0.7027006149291992),
#  ('afghanen', 0.6983833909034729),
#  ('nigerianen', 0.6975200176239014),
#  ('egyptenaren', 0.6970018744468689),
#  ('emigranten', 0.6961454153060913),
# ...

# %%
mtr.wv.most_similar(positive='antilliaan', topn=100)
# Out:
# [('eindhovenaar', 0.8251974582672119),
#  ('nigeriaan', 0.8198906183242798),
#  ('keniaan', 0.8161986470222473),
#  ('friezin', 0.8133299350738525),
#  ('arnhemmer', 0.811569333076477),
#  ('roemeen', 0.8066912293434143),
#  ('parijzenaar', 0.8055751323699951),
#  ('nijmegenaar', 0.7976449728012085),
#  ('tilburger', 0.7956967353820801),
#  ('bask', 0.7947391271591187),
#  ('angolees', 0.7899287939071655),
#  ('rotterdammer', 0.7851117849349976),
#  ('haarlemmer', 0.782521665096283),
#  ('surinamer', 0.7817527651786804),
#  ('japanner', 0.7784985303878784),
#  ('motorrijder', 0.7748318910598755),
#  ('londenaar', 0.7730752825737),
#  ('turk', 0.7721501588821411),
#  ('congolees', 0.7711005210876465),
#  ('vrachtwagenchauffeur', 0.7709782123565674),
#  ('tukker', 0.7706393003463745),
#  ('cubaan', 0.7704943418502808),
#  ('pool', 0.7701627016067505),
#  ('catalaan', 0.7694927453994751),
#  ('plaatsgenoot', 0.7679296731948853),
#  ('automobiliste', 0.7656986117362976),
# ...

# %%
mtr.wv.most_similar(positive='antillianen', topn=100)
# Out:
# [('marokkanen', 0.8883103132247925),
#  ('surinamers', 0.8610169291496277),
#  ('autochtonen', 0.8277753591537476),
#  ('allochtonen', 0.8265451788902283),
#  ('autochtone', 0.762056827545166),
#  ('migranten', 0.753127932548523),
#  ('turken', 0.7455691695213318),
#  ('allochtone', 0.7386536598205566),
#  ('molukkers', 0.7262228727340698),
#  ('roemenen', 0.7166112661361694),
#  ('jongeren', 0.7132611870765686),
#  ('bulgaren', 0.7070116996765137),
#  ('somaliers', 0.7067469954490662),
#  ('prostituees', 0.70085608959198),
#  ('arubanen', 0.69940185546875),
#  ('buitenlanders', 0.6927738189697266),
#  ('probleemjongeren', 0.6905956864356995),
#  ('hoogopgeleide', 0.6883179545402527),
#  ('hindoestanen', 0.6834641098976135),
#  ('moslimjongeren', 0.6827663779258728),
#  ('immigranten', 0.68246990442276),
#  ('hoogopgeleiden', 0.6739914417266846),
#  ('academici', 0.6722729206085205),
#  ('ouderen', 0.6621280312538147),
#  ('nieuwkomers', 0.6606330871582031),
# ...

# %%
mtr.wv.most_similar(positive='irakees', topn=100)
# Out:
# [('palestijn', 0.8881645202636719),
#  ('afghaan', 0.8605654239654541),
#  ('politieman', 0.8326246738433838),
#  ('terrorist', 0.8257653117179871),
#  ('koerd', 0.8198304772377014),
#  ('politieagent', 0.8194640874862671),
#  ('overvaller', 0.8016086220741272),
#  ('demonstrant', 0.7890205383300781),
#  ('agent', 0.7792648673057556),
#  ('turk', 0.7771334648132324),
#  ('libanees', 0.7768031358718872),
#  ('algerijn', 0.7759719491004944),
#  ('pakistaan', 0.7745522260665894),
#  ('gedetineerde', 0.7672179937362671),
#  ('oorlogsmisdadiger', 0.7642002105712891),
#  ('arrestant', 0.763611912727356),
#  ('gevangene', 0.7628273963928223),
#  ('agente', 0.7621985077857971),
#  ('zelfmoordterrorist', 0.7607730627059937),
#  ('strijder', 0.7593945264816284),
#  ('taxichauffeur', 0.7582603096961975),
#  ('schutter', 0.7558419704437256),
#  ('brandweerman', 0.7543202042579651),
#  ('egyptenaar', 0.7531586289405823),
#  ('marinier', 0.7520185708999634),
# ...

# %%
mtr.wv.most_similar(positive='irakezen', topn=100)
# Out:
# [('afghanen', 0.9287917613983154),
#  ('libanezen', 0.8873521685600281),
#  ('koerden', 0.8553888201713562),
#  ('iraniers', 0.8546696901321411),
#  ('japanners', 0.836338222026825),
#  ('tsjetsjenen', 0.8361068964004517),
#  ('egyptenaren', 0.8328489065170288),
#  ('israeliers', 0.8294674158096313),
#  ('strijders', 0.827183187007904),
#  ('opstandelingen', 0.8214794993400574),
#  ('amerikanen', 0.8207172155380249),
#  ('pakistanen', 0.8204017877578735),
#  ('buitenlanders', 0.8188292980194092),
#  ('jihadisten', 0.8151338696479797),
#  ('serviers', 0.8146899342536926),
#  ('chinezen', 0.8076624274253845),
#  ('dorpelingen', 0.8059374690055847),
#  ('gijzelaars', 0.8040372133255005),
#  ('palestijnen', 0.80347740650177),
#  ('russen', 0.8010647892951965),
#  ('tibetanen', 0.7981065511703491),
#  ('activisten', 0.7976976037025452),
#  ('rebellen', 0.7901453375816345),
#  ('betogers', 0.7899481058120728),
#  ('kosovaren', 0.7851722240447998),
#  ('arabieren', 0.7843903303146362),
# ...

# %%
mtr.wv.most_similar(positive='afghaan', topn=100)
# Out:
# [('irakees', 0.8605654239654541),
#  ('palestijn', 0.8218847513198853),
#  ('turk', 0.8076217174530029),
#  ('pakistaan', 0.7885312438011169),
#  ('marinier', 0.786529004573822),
#  ('politieagent', 0.7858213186264038),
#  ('politieman', 0.7812244892120361),
#  ('koerd', 0.7793905735015869),
#  ('algerijn', 0.7759972810745239),
#  ('demonstrant', 0.7744814157485962),
#  ('vrachtwagenchauffeur', 0.772842288017273),
#  ('taxichauffeur', 0.7701010704040527),
#  ('jihadist', 0.7595787644386292),
#  ('korporaal', 0.7590129375457764),
#  ('arrestant', 0.758770227432251),
#  ('brandweerman', 0.7570077180862427),
#  ('antilliaan', 0.753808856010437),
#  ('kolonist', 0.7497327327728271),
#  ('stewardess', 0.7479625344276428),
#  ('sluipschutter', 0.745068371295929),
#  ('marokkaan', 0.7408460974693298),
#  ('egyptenaar', 0.74031001329422),
#  ('zelfmoordterrorist', 0.7397953271865845),
#  ('djihadist', 0.7377044558525085),
#  ('zedendelinquent', 0.7359146475791931),
# ...

# %%
mtr.wv.most_similar(positive='afghanen', topn=100)
# Out:
# [('irakezen', 0.9287917613983154),
#  ('libanezen', 0.8985146880149841),
#  ('iraniers', 0.8968985676765442),
#  ('pakistanen', 0.8782824277877808),
#  ('zimbabwanen', 0.8660529255867004),
#  ('tibetanen', 0.8561791181564331),
#  ('egyptenaren', 0.8384621143341064),
#  ('buitenlanders', 0.8381275534629822),
#  ('koerden', 0.837249219417572),
#  ('kenianen', 0.8319923877716064),
#  ('tsjetsjenen', 0.8292492628097534),
#  ('jihadisten', 0.8238610625267029),
#  ('nigerianen', 0.8210818767547607),
#  ('japanners', 0.819576621055603),
#  ('indonesiers', 0.8191701173782349),
#  ('kosovaren', 0.8091375231742859),
#  ('chinezen', 0.807879626750946),
#  ('ontheemden', 0.8068839311599731),
#  ('albanezen', 0.8030784726142883),
#  ('dorpelingen', 0.8019154667854309),
#  ('hongaren', 0.7986240983009338),
#  ('mexicanen', 0.7939201593399048),
#  ('tamils', 0.7936147451400757),
#  ('somaliers', 0.7878414392471313),
#  ('burmezen', 0.7855771780014038),
#  ('algerijnen', 0.7849136590957642),
# ...

# %%
mtr.wv.most_similar(positive='syrier', topn=100)
# Out:
# [('mensenrechtenadvocate', 0.8810673356056213),
#  ('hussain', 0.8761980533599854),
#  ('khalaf', 0.8760941028594971),
#  ('nizar', 0.8743508458137512),
#  ('balta', 0.8690503835678101),
#  ('bendeleider', 0.866105854511261),
#  ('salma', 0.8647594451904297),
#  ('zbigniew', 0.863943874835968),
#  ('bey', 0.8638253211975098),
#  ('ould', 0.8636950254440308),
#  ('filmcriticus', 0.8604544401168823),
#  ('charly', 0.8582631349563599),
#  ('fares', 0.8573513627052307),
#  ('drugsbaron', 0.8565256595611572),
#  ('kamil', 0.8560882806777954),
#  ('ismael', 0.8559383153915405),
#  ('guek', 0.855337381362915),
#  ('idris', 0.854732096195221),
#  ('cassius', 0.8545091152191162),
#  ('nidal', 0.8539513945579529),
#  ('darko', 0.8535157442092896),
#  ('adan', 0.8526634573936462),
#  ('mirko', 0.8507630825042725),
#  ('erkan', 0.8504014015197754),
#  ('inlichtingenchef', 0.8501014113426208),
#  ('murad', 0.8499915599822998),
#  ('gontsjarik', 0.8497526049613953),
# ...

# %%
mtr.wv.most_similar(positive='syriers', topn=100)
# Out:
# [('tsjetsjenen', 0.8315104842185974),
#  ('serviers', 0.8104947805404663),
#  ('kosovaren', 0.8009787797927856),
#  ('oorlogsveteranen', 0.8008189797401428),
#  ('militieleden', 0.8005658388137817),
#  ('tamils', 0.7982900142669678),
#  ('moslimstrijders', 0.7961825132369995),
#  ('libanezen', 0.7961471080780029),
#  ('albanezen', 0.7907642126083374),
#  ('deserteurs', 0.7874324917793274),
#  ('israeliers', 0.7869222164154053),
#  ('moslimbroeders', 0.7835439443588257),
#  ('saoediers', 0.7813174724578857),
#  ('moslimextremisten', 0.7783059477806091),
#  ('oeigoeren', 0.7763552069664001),
#  ('gijzelnemers', 0.7758018970489502),
#  ('jihadisten', 0.7749679088592529),
#  ('kroaten', 0.7731272578239441),
#  ('opstandelingen', 0.7711914777755737),
#  ('jordaniers', 0.7686776518821716),
#  ('zelfmoordenaars', 0.7681769132614136),
#  ('tibetanen', 0.7661111354827881),
#  ('aanslagplegers', 0.7642691135406494),
#  ('colombianen', 0.7639512419700623),
# ...

# %%
mtr.wv.most_similar(positive='somalier', topn=100)
# Out:
# [('syrier', 0.8465547561645508),
#  ('winkelbediende', 0.8357178568840027),
#  ('bendeleider', 0.8356295228004456),
#  ('dierenbeul', 0.8310885429382324),
#  ('sjaripov', 0.8270525932312012),
#  ('mismaakte', 0.8248640298843384),
#  ('khalaf', 0.8239264488220215),
#  ('buurtgenoot', 0.8238654732704163),
#  ('rabei', 0.8233474493026733),
#  ('beveiligingsbeambte', 0.8226765394210815),
#  ('brahim', 0.8220638036727905),
#  ('roxana', 0.8219946622848511),
#  ('pester', 0.8203830718994141),
#  ('achternicht', 0.8203676342964172),
#  ('medegevangene', 0.8171213865280151),
#  ('maulana', 0.8150854706764221),
#  ('doodgraver', 0.8140040040016174),
#  ('dorpeling', 0.8137069344520569),
#  ('huzaar', 0.8119910955429077),
#  ('tsjetsjeen', 0.8114485144615173),
#  ('ndlovu', 0.8108761310577393),
#  ('fazal', 0.8098241090774536),
#  ('erkan', 0.8095455765724182),
#  ('tsering', 0.809471845626831),
#  ('schijterd', 0.8084065318107605),
#  ('tasjesdief', 0.807599663734436),
# ...

# %%
mtr.wv.most_similar(positive='somaliers', topn=100)
# Out:
# [('iraniers', 0.8074966669082642),
#  ('oeigoeren', 0.8000063300132751),
#  ('tamils', 0.799175500869751),
#  ('tibetanen', 0.7955962419509888),
#  ('pakistanen', 0.7935627698898315),
#  ('illegalen', 0.7921204566955566),
#  ('molukkers', 0.7879084348678589),
#  ('afghanen', 0.7878414392471313),
#  ('nigerianen', 0.7792527675628662),
#  ('zimbabwanen', 0.7762807607650757),
#  ('ontheemden', 0.7742533683776855),
#  ('buitenlanders', 0.7672220468521118),
#  ('libanezen', 0.7581995725631714),
#  ('malinezen', 0.7534793615341187),
#  ('kosovaren', 0.7495371103286743),
#  ('congolezen', 0.7432961463928223),
#  ('burmezen', 0.7397772073745728),
#  ('zigeuners', 0.7391684651374817),
#  ('nepalezen', 0.7372697591781616),
#  ('tamilburgers', 0.7360783815383911),
#  ('rwandezen', 0.7339029312133789),
#  ('kenianen', 0.7330743074417114),
#  ('liberianen', 0.7322344779968262),
#  ('angolezen', 0.7316394448280334),
#  ('oezbeken', 0.7312501668930054),
#  ('hongerstakers', 0.7303552627563477),
# ...

# %%
mtr.wv.most_similar(positive='pool', topn=100)
# Out:
# [('engelsman', 0.8399668335914612),
#  ('japanner', 0.8282033205032349),
#  ('oostenrijker', 0.8225588798522949),
#  ('roemeen', 0.8204602599143982),
#  ('duitser', 0.8200682401657104),
#  ('keniaan', 0.81914222240448),
#  ('brit', 0.8143795728683472),
#  ('noor', 0.8120453357696533),
#  ('griek', 0.8010803461074829),
#  ('belg', 0.7994207143783569),
#  ('nigeriaan', 0.7916954755783081),
#  ('zweed', 0.7907431125640869),
#  ('avonturier', 0.790587842464447),
#  ('canadees', 0.7902408838272095),
#  ('bokser', 0.7866637110710144),
#  ('vlaming', 0.7820464372634888),
#  ('fransman', 0.7820041179656982),
#  ('australier', 0.7793856859207153),
#  ('klimmer', 0.7793495059013367),
#  ('gier', 0.778915286064148),
#  ('rotterdammer', 0.7787340879440308),
#  ('chileen', 0.7756961584091187),
#  ('magnus', 0.7744645476341248),
#  ('hongaar', 0.7739904522895813),
#  ('debutant', 0.7719284296035767),
#  ('antilliaan', 0.7701627016067505),
#  ('turner', 0.7667528390884399),
# ...

# %%
mtr.wv.most_similar(positive='polen', topn=100)
# Out:
# [('hongarije', 0.868380606174469),
#  ('duitsland', 0.8574960827827454),
#  ('turkije', 0.8473832011222839),
#  ('bulgarije', 0.8314186334609985),
#  ('spanje', 0.82859867811203),
#  ('frankrijk', 0.828294038772583),
#  ('roemenie', 0.8197702765464783),
#  ('oostenrijk', 0.8130165338516235),
#  ('denemarken', 0.8118290901184082),
#  ('roemeni', 0.8103628158569336),
#  ('rusland', 0.8008938431739807),
#  ('italie', 0.8006546497344971),
#  ('itali', 0.7988632917404175),
#  ('oekraine', 0.7986828088760376),
#  ('griekenland', 0.7908107042312622),
#  ('zweden', 0.7830042839050293),
#  ('belgie', 0.7738553285598755),
#  ('noorwegen', 0.7732049226760864),
#  ('litouwen', 0.7592439651489258),
#  ('finland', 0.7534208297729492),
#  ('slowakije', 0.7511491179466248),
#  ('tsjechie', 0.747121274471283),
#  ('tsjechi', 0.7433192729949951),
#  ('belgi', 0.7400776743888855),
#  ('portugal', 0.7376433610916138),
#  ('japan', 0.7368009090423584),
#  ('buurlanden', 0.7337605357170105),
# ...

# %% [markdown]
# ## 1b. Target categories:
# ### Immigranten groups // labels.

# %%
mtr.wv.most_similar(positive='arabier', topn=100)
# Out:
# [('turk', 0.7877898812294006),
#  ('verrader', 0.7839884757995605),
#  ('misdadiger', 0.7788524627685547),
#  ('racist', 0.7712928652763367),
#  ('jood', 0.7700492143630981),
#  ('ketter', 0.7661409378051758),
#  ('surinamer', 0.7626912593841553),
#  ('indiaan', 0.7616180181503296),
#  ('terrorist', 0.7598832845687866),
#  ('schurk', 0.7566701769828796),
#  ('pacifist', 0.7557650804519653),
#  ('fundamentalist', 0.7544575929641724),
#  ('boeddhist', 0.7493165731430054),
#  ('palestijn', 0.7481892108917236),
#  ('kluizenaar', 0.7443751096725464),
#  ('rebel', 0.7436710596084595),
#  ('tiran', 0.7400099635124207),
#  ('strijder', 0.7377222180366516),
#  ('fascist', 0.7376670837402344),
#  ('hoer', 0.7348802089691162),
#  ('kolonist', 0.7277599573135376),
#  ('vrijheidsstrijder', 0.7255499362945557),
#  ('israelier', 0.7244521975517273),
#  ('volgeling', 0.7213065028190613),
#  ('slavin', 0.7204499244689941),
#  ('marokkaan', 0.7200922966003418),
#  ('zigeuner', 0.7192085981369019),
# ...

# %%
mtr.wv.most_similar(positive='arabieren', topn=100)
# Out:
# [('koerden', 0.8668658137321472),
#  ('sjiieten', 0.8634470105171204),
#  ('egyptenaren', 0.8544683456420898),
#  ('tsjetsjenen', 0.8420287370681763),
#  ('soennieten', 0.841170072555542),
#  ('joden', 0.8332408666610718),
#  ('israeliers', 0.8306847214698792),
#  ('indianen', 0.8268246650695801),
#  ('christenen', 0.8252728581428528),
#  ('islamisten', 0.8249176740646362),
#  ('serviers', 0.8214970827102661),
#  ('hindoes', 0.8199607729911804),
#  ('armeniers', 0.8135306239128113),
#  ('albanezen', 0.8093938231468201),
#  ('islamieten', 0.805251955986023),
#  ('tibetanen', 0.8044629096984863),
#  ('fundamentalisten', 0.8029601573944092),
#  ('kroaten', 0.8014886379241943),
#  ('extremisten', 0.7997753620147705),
#  ('alawieten', 0.7965763807296753),
#  ('salafisten', 0.7939560413360596),
#  ('zwarten', 0.7931600213050842),
#  ('radicalen', 0.7909002900123596),
#  ('seculieren', 0.7884602546691895),
#  ('westerlingen', 0.7874817848205566),
#  ('moslims', 0.7869206070899963),
# ...

# %%
mtr.wv.most_similar(positive='moslim', topn=100)
# Out:
# [('jood', 0.8290826082229614),
#  ('gelovige', 0.781710147857666),
#  ('extremist', 0.7139045000076294),
#  ('buitenlander', 0.7029902935028076),
#  ('strijder', 0.7013369202613831),
#  ('ongelovige', 0.6978553533554077),
#  ('sekte', 0.696811318397522),
#  ('fundamentalist', 0.6945658922195435),
#  ('minderheid', 0.691714882850647),
#  ('terrorist', 0.691210925579071),
#  ('martelaar', 0.6869309544563293),
#  ('allochtoon', 0.6822034120559692),
#  ('turk', 0.6784677505493164),
#  ('fundamentalisten', 0.6754029989242554),
#  ('islam', 0.6751952171325684),
#  ('verrader', 0.6738729476928711),
#  ('vluchteling', 0.673742413520813),
#  ('imam', 0.6731096506118774),
#  ('moslims', 0.6639918088912964),
#  ('godsdienst', 0.6614092588424683),
#  ('djihad', 0.6604734659194946),
#  ('homoseksueel', 0.6579006910324097),
#  ('orthodoxen', 0.6568143963813782),
#  ('priester', 0.651404857635498),
#  ('arabier', 0.6512105464935303),
#  ('katholiek', 0.6484697461128235),
# ...

# %%
mtr.wv.most_similar(positive='moslims', topn=100)
# Out:
# [('christenen', 0.9452643394470215),
#  ('joden', 0.8563727736473083),
#  ('gelovigen', 0.8435690999031067),
#  ('islamieten', 0.843369722366333),
#  ('koerden', 0.8046468496322632),
#  ('turken', 0.7959620952606201),
#  ('moslimjongeren', 0.793781578540802),
#  ('arabieren', 0.7869207859039307),
#  ('fundamentalisten', 0.7751673460006714),
#  ('imams', 0.7730143666267395),
#  ('soennieten', 0.7726433277130127),
#  ('homoseksuelen', 0.7695960402488708),
#  ('extremisten', 0.7651562690734863),
#  ('sjiieten', 0.7575608491897583),
#  ('boeddhisten', 0.7554805278778076),
#  ('katholieken', 0.7535332441329956),
#  ('buitenlanders', 0.7489051818847656),
#  ('moslimvrouwen', 0.7483565807342529),
#  ('migranten', 0.7457678914070129),
#  ('palestijnen', 0.7436546087265015),
#  ('salafisten', 0.7430871725082397),
#  ('ongelovigen', 0.7426759004592896),
#  ('marokkanen', 0.7419294118881226),
#  ('westerlingen', 0.7418118715286255),
#  ('tibetanen', 0.741593599319458),
# ...

# %%
mtr.wv.most_similar(positive='vluchteling', topn=100)
# Out:
# [('asielzoeker', 0.7675188779830933),
#  ('immigrant', 0.7591484785079956),
#  ('gevangene', 0.7324780225753784),
#  ('strijder', 0.7173709869384766),
#  ('migrant', 0.7113351821899414),
#  ('koerd', 0.7053914070129395),
#  ('activist', 0.6975533962249756),
#  ('moslim', 0.673742413520813),
#  ('balling', 0.6731781959533691),
#  ('terrorist', 0.6708779335021973),
#  ('buitenlander', 0.6674310564994812),
#  ('prostituee', 0.6584724187850952),
#  ('turk', 0.6555739045143127),
#  ('tolk', 0.6529946327209473),
#  ('spion', 0.6499578952789307),
#  ('palestijn', 0.6462122201919556),
#  ('hulpverlener', 0.6431963443756104),
#  ('afghaan', 0.6423702239990234),
#  ('diplomaat', 0.6400789022445679),
#  ('politieagent', 0.6400431394577026),
#  ('gedetineerde', 0.6400184631347656),
#  ('activiste', 0.6371394395828247),
#  ('dissident', 0.6365867257118225),
#  ('monnik', 0.6360443830490112),
#  ('libanees', 0.6334272623062134),
#  ('bezettingsmacht', 0.6321523189544678),
# ...

# %%
mtr.wv.most_similar(positive='vluchtelingen', topn=100)
# Out:
# [('migranten', 0.8717324137687683),
#  ('asielzoekers', 0.8709255456924438),
#  ('ontheemden', 0.8289898037910461),
#  ('illegalen', 0.8140720129013062),
#  ('immigranten', 0.8010792136192322),
#  ('vreemdelingen', 0.797188937664032),
#  ('afghanen', 0.7742717266082764),
#  ('bootvluchtelingen', 0.7724359035491943),
#  ('buitenlanders', 0.7678399682044983),
#  ('arbeidsmigranten', 0.7666807174682617),
#  ('irakezen', 0.742837131023407),
#  ('koerden', 0.7353127002716064),
#  ('tibetanen', 0.7285885810852051),
#  ('gedetineerden', 0.7268770933151245),
#  ('somaliers', 0.7243199944496155),
#  ('gevangenen', 0.7230454087257385),
#  ('militairen', 0.7197974920272827),
#  ('jihadisten', 0.7070568799972534),
#  ('blauwhelmen', 0.7041869163513184),
#  ('strijders', 0.7039177417755127),
#  ('djihadisten', 0.7017120122909546),
#  ('tamils', 0.6984848380088806),
#  ('kosovaren', 0.6904537081718445),
#  ('inwoners', 0.6881095170974731),
#  ('burgers', 0.6872945427894592),
# ...

# %%
mtr.wv.most_similar(positive='allochtoon', topn=100)
# Out:
# [('autochtoon', 0.8603958487510681),
#  ('moslim', 0.6822034120559692),
#  ('autochtone', 0.6715205311775208),
#  ('allochtone', 0.6511332988739014),
#  ('analfabeet', 0.6384704113006592),
#  ('gelovige', 0.6152181625366211),
#  ('hoogopgeleid', 0.6093109250068665),
#  ('gelovig', 0.6045043468475342),
#  ('autochtonen', 0.5950575470924377),
#  ('allochtonen', 0.5882219076156616),
#  ('katholiek', 0.5837434530258179),
#  ('protestant', 0.5832512378692627),
#  ('marokkanen', 0.5762647390365601),
#  ('leerkracht', 0.5752187967300415),
#  ('marokkaans', 0.5698373317718506),
#  ('alleenstaande', 0.5686233043670654),
#  ('hoogopgeleide', 0.5658466219902039),
#  ('antillianen', 0.5586681962013245),
#  ('homoseksueel', 0.5571690797805786),
#  ('etniciteit', 0.5554255247116089),
#  ('ouder', 0.5550879836082458),
#  ('leraar', 0.5541254281997681),
#  ('volwassene', 0.552639901638031),
#  ('hardwerkende', 0.5499264597892761),
#  ('kostwinner', 0.5491037964820862),
# ...

# %%
mtr.wv.most_similar(positive='allochtonen', topn=100)
# Out:
# [('autochtonen', 0.8651082515716553),
#  ('antillianen', 0.826545238494873),
#  ('jongeren', 0.8235434889793396),
#  ('nieuwkomers', 0.8225921988487244),
#  ('ouderen', 0.8082039952278137),
#  ('marokkanen', 0.8010791540145874),
#  ('migranten', 0.7835509777069092),
#  ('hoogopgeleiden', 0.7700440883636475),
#  ('allochtone', 0.7694697380065918),
#  ('leraren', 0.7423270344734192),
#  ('plussers', 0.7344882488250732),
#  ('laagopgeleiden', 0.7335772514343262),
#  ('gezinnen', 0.731326699256897),
#  ('vrouwen', 0.7252184152603149),
#  ('leerkrachten', 0.7202268838882446),
#  ('kansarmen', 0.7108371257781982),
#  ('surinamers', 0.7107166051864624),
#  ('werkzoekenden', 0.7103315591812134),
#  ('immigranten', 0.7094512581825256),
#  ('leerlingen', 0.704034686088562),
#  ('uitkeringsgerechtigden', 0.7023352384567261),
#  ('nederlanders', 0.6987075209617615),
#  ('moslimjongeren', 0.698556661605835),
#  ('probleemjongeren', 0.6982512474060059),
#  ('moslims', 0.6971441507339478),
# ...

# %%
mtr.wv.most_similar(positive='immigrant', topn=100)
# Out:
# [('koerd', 0.7889456748962402),
#  ('spion', 0.7724665403366089),
#  ('djihadist', 0.7643396854400635),
#  ('vluchteling', 0.759148359298706),
#  ('migrant', 0.7537864446640015),
#  ('strijder', 0.7505902647972107),
#  ('vluchtelinge', 0.7489779591560364),
#  ('balling', 0.7471816539764404),
#  ('prostituee', 0.7465627789497375),
#  ('turk', 0.7423943877220154),
#  ('zakenman', 0.7383677959442139),
#  ('soldaat', 0.7341374158859253),
#  ('origine', 0.7250955104827881),
#  ('dissident', 0.7175664305686951),
#  ('activiste', 0.7174569368362427),
#  ('monnik', 0.7170228958129883),
#  ('kolonie', 0.7162330150604248),
#  ('gevangene', 0.716127872467041),
#  ('asielzoeker', 0.7143872976303101),
#  ('terrorist', 0.7142705321311951),
#  ('toerist', 0.7128809690475464),
#  ('diplomaat', 0.7061820030212402),
#  ('vrachtwagenchauffeur', 0.7046980857849121),
#  ('libanees', 0.6977279186248779),
#  ('arbeider', 0.6969641447067261),
#  ('gijzelaar', 0.6956971287727356),
# ...

# %%
mtr.wv.most_similar(positive='immigranten', topn=100)
# Out:
# [('migranten', 0.946014404296875),
#  ('arbeidsmigranten', 0.8207433223724365),
#  ('buitenlanders', 0.8151710033416748),
#  ('gastarbeiders', 0.8052780628204346),
#  ('vluchtelingen', 0.8010792136192322),
#  ('emigranten', 0.7905348539352417),
#  ('chinezen', 0.7750815153121948),
#  ('arbeiders', 0.7706849575042725),
#  ('tibetanen', 0.7667170166969299),
#  ('vreemdelingen', 0.7486551403999329),
#  ('nieuwkomers', 0.7456550002098083),
#  ('jihadisten', 0.741762101650238),
#  ('moslims', 0.7396717667579651),
#  ('koerden', 0.7332844734191895),
#  ('prostituees', 0.729299783706665),
#  ('turken', 0.7273685336112976),
#  ('illegalen', 0.7259403467178345),
#  ('djihadisten', 0.7231508493423462),
#  ('gezinnen', 0.7217788696289062),
#  ('afghanen', 0.7189956903457642),
#  ('bootvluchtelingen', 0.7155286073684692),
#  ('slaven', 0.7135928869247437),
#  ('asielzoekers', 0.7135088443756104),
#  ('nederlanders', 0.7112434506416321),
#  ('boeren', 0.7097172737121582),
# ...

# %%
mtr.wv.most_similar(positive='migrant', topn=100)
# Out:
# [('immigrant', 0.7537864446640015),
#  ('vluchteling', 0.7113351821899414),
#  ('turk', 0.6935645341873169),
#  ('buitenlander', 0.6687668561935425),
#  ('asielzoeker', 0.6680276989936829),
#  ('arbeider', 0.6571152210235596),
#  ('afghaan', 0.6520757079124451),
#  ('toerist', 0.6462363004684448),
#  ('djihadist', 0.63914954662323),
#  ('ingezetene', 0.6245155334472656),
#  ('arabier', 0.6215946078300476),
#  ('volwassene', 0.6178473830223083),
#  ('nabestaande', 0.6168139576911926),
#  ('balling', 0.6155694723129272),
#  ('minderheidsgroep', 0.6096541285514832),
#  ('ontwikkelingsland', 0.6088006496429443),
#  ('wereldburger', 0.6081721186637878),
#  ('prostituee', 0.6051140427589417),
#  ('vluchtelinge', 0.6048670411109924),
#  ('schoonmaker', 0.6034129858016968),
#  ('narcostaat', 0.6019604206085205),
#  ('topsporter', 0.5973502397537231),
#  ('gastarbeider', 0.5959532260894775),
#  ('gedetineerde', 0.5943478345870972),
#  ('kindsoldaat', 0.5929975509643555),
# ...

# %%
mtr.wv.most_similar(positive='migranten', topn=100)
# Out:
# [('immigranten', 0.9460143446922302),
#  ('vluchtelingen', 0.871732234954834),
#  ('arbeidsmigranten', 0.8446380496025085),
#  ('buitenlanders', 0.8307130932807922),
#  ('asielzoekers', 0.8126089572906494),
#  ('vreemdelingen', 0.8075873851776123),
#  ('nieuwkomers', 0.8046663999557495),
#  ('illegalen', 0.7994053363800049),
#  ('allochtonen', 0.7835507392883301),
#  ('gezinnen', 0.7677617073059082),
#  ('tibetanen', 0.7658423185348511),
#  ('chinezen', 0.7615995407104492),
#  ('arbeiders', 0.7615369558334351),
#  ('afghanen', 0.7601159811019897),
#  ('gastarbeiders', 0.7599288821220398),
#  ('antillianen', 0.7531278133392334),
#  ('jongeren', 0.7513148784637451),
#  ('prostituees', 0.7459225654602051),
#  ('moslims', 0.7457678318023682),
#  ('burgers', 0.7383518218994141),
#  ('turken', 0.7365738153457642),
#  ('moslimjongeren', 0.7327844500541687),
#  ('boeren', 0.7326411008834839),
#  ('emigranten', 0.7311694622039795),
#  ('nederlanders', 0.730902373790741),
# ...

# %%
mtr.wv.most_similar(positive='expat', topn=100)
# Out:
# [('paardenfokker', 0.8348221778869629),
#  ('arabiste', 0.8236751556396484),
#  ('vereeuwigde', 0.816209077835083),
#  ('punker', 0.8152124881744385),
#  ('veeboer', 0.8113138675689697),
#  ('ingemar', 0.8102525472640991),
#  ('ngozi', 0.8084679245948792),
#  ('mcmillan', 0.8061416149139404),
#  ('ejiofor', 0.8021849393844604),
#  ('jazzpianist', 0.8011845946311951),
#  ('pardoel', 0.8004153370857239),
#  ('abigail', 0.8002794981002808),
#  ('operazanger', 0.8001559972763062),
#  ('wasbeer', 0.7990731596946716),
#  ('chiwetel', 0.7986295223236084),
#  ('hamam', 0.7973507642745972),
#  ('omara', 0.7972286939620972),
#  ('lubich', 0.7965223789215088),
#  ('hiphopper', 0.7963800430297852),
#  ('arbeiderszoon', 0.7963138818740845),
#  ('yuki', 0.7953050136566162),
#  ('northam', 0.7951663732528687),
#  ('belastinginspecteur', 0.7950259447097778),
#  ('naaister', 0.795012354850769),
#  ('cosmo', 0.7941420078277588),
#  ('bobsleester', 0.7929770946502686),
# ...

# %%
mtr.wv.most_similar(positive='expats', topn=100)
# Out:
# [('hindoestanen', 0.7709614038467407),
#  ('emigranten', 0.7662752866744995),
#  ('adoptiekinderen', 0.7651565670967102),
#  ('oorlogsslachtoffers', 0.7440550327301025),
#  ('handelaars', 0.7391591668128967),
#  ('hulpprojecten', 0.7385177612304688),
#  ('miljardairs', 0.7378560900688171),
#  ('zakenmensen', 0.7328193187713623),
#  ('verzamelaars', 0.7316248416900635),
#  ('kooplui', 0.7281622290611267),
#  ('vakantiegangers', 0.7278760671615601),
#  ('stadsbewoners', 0.7264499664306641),
#  ('wijnboeren', 0.7254967093467712),
#  ('zakenmannen', 0.7243855595588684),
#  ('zakenlui', 0.7237564325332642),
#  ('gastarbeiders', 0.7232158184051514),
#  ('gelukzoekers', 0.7226777076721191),
#  ('arbeidsmigranten', 0.7220271825790405),
#  ('kwekers', 0.7127383947372437),
#  ('bekeerlingen', 0.7117363214492798),
#  ('fabrieksarbeiders', 0.7111397981643677),
#  ('arbeiders', 0.7111161947250366),
#  ('kenniswerkers', 0.7099015116691589),
#  ('reisorganisaties', 0.7095116972923279),
# ...

# %% [markdown]
# # 1a. Reference categories
# Selected on the basis of in-groups ('nederlander (s)' and 'wester(s)' as well as the largest west-european migrant groups living in the Netherlands, according to Statistics Netherlands:  https://www.cbs.nl/nl-nl/achtergrond/2016/47/bevolking-naar-migratieachtergrond)

# %%
mtr.wv.most_similar(positive='nederlander', topn=100)
# Out:
# [('atleet', 0.7517108917236328),
#  ('rotterdammer', 0.7351699471473694),
#  ('renner', 0.7327120900154114),
#  ('sporter', 0.7273975610733032),
#  ('amerikaan', 0.7160876393318176),
#  ('duitser', 0.7080518007278442),
#  ('belg', 0.7070522308349609),
#  ('buitenlander', 0.7035413980484009),
#  ('europeaan', 0.701969563961029),
#  ('schaatser', 0.6931079626083374),
#  ('nieuwkomer', 0.6900347471237183),
#  ('klimmer', 0.6845557689666748),
#  ('coureur', 0.683486819267273),
#  ('griek', 0.6833256483078003),
#  ('pool', 0.6730644702911377),
#  ('sprinter', 0.6682420372962952),
#  ('vlaming', 0.6623047590255737),
#  ('turk', 0.6621308922767639),
#  ('zwemmer', 0.6611508131027222),
#  ('brit', 0.6580104231834412),
#  ('speelster', 0.6577092409133911),
#  ('voetballer', 0.6546972990036011),
#  ('speler', 0.6538897752761841),
#  ('keniaan', 0.6523067355155945),
#  ('marokkaan', 0.6496472954750061),
#  ('brabander', 0.6493961811065674),
#  ('tennisser', 0.6425729393959045),
# ...

# %%
mtr.wv.most_similar(positive='nederlanders', topn=100)
# Out:
# [('chinezen', 0.7976012825965881),
#  ('japanners', 0.7926116585731506),
#  ('turken', 0.7879650592803955),
#  ('buitenlanders', 0.7738000750541687),
#  ('kenianen', 0.7698732614517212),
#  ('mensen', 0.7644656896591187),
#  ('belgen', 0.7625712156295776),
#  ('cubanen', 0.7578890323638916),
#  ('afghanen', 0.7481905817985535),
#  ('kerkgangers', 0.7380402684211731),
#  ('marokkanen', 0.7377084493637085),
#  ('europeanen', 0.7346673607826233),
#  ('nieuwkomers', 0.7310725450515747),
#  ('migranten', 0.7309024333953857),
#  ('iraniers', 0.728986918926239),
#  ('jongeren', 0.7229112386703491),
#  ('italianen', 0.7214106321334839),
#  ('amsterdammers', 0.7169371843338013),
#  ('egyptenaren', 0.7160011529922485),
#  ('irakezen', 0.7155236601829529),
#  ('zimbabwanen', 0.7144843339920044),
#  ('surinamers', 0.7142758369445801),
#  ('duitsers', 0.7136176824569702),
#  ('immigranten', 0.7112434506416321),
#  ('denen', 0.7106797099113464),
#  ('brazilianen', 0.7089914679527283),
# ...

# %%
mtr.wv.most_similar(positive='belg', topn=100)
# Out:
# [('duitser', 0.9177682995796204),
#  ('zweed', 0.9125771522521973),
#  ('fransman', 0.8981059193611145),
#  ('deen', 0.8921247124671936),
#  ('zwitser', 0.8911377191543579),
#  ('oostenrijker', 0.8882337808609009),
#  ('italiaan', 0.8874433040618896),
#  ('noor', 0.886079728603363),
#  ('spanjaard', 0.8809572458267212),
#  ('routinier', 0.8802571296691895),
#  ('australier', 0.8739840388298035),
#  ('debutant', 0.8684197068214417),
#  ('knegt', 0.8638385534286499),
#  ('tsjech', 0.8613939881324768),
#  ('argentijn', 0.8613823652267456),
#  ('sprinter', 0.8592183589935303),
#  ('brit', 0.8473393321037292),
#  ('schaatsster', 0.8457209467887878),
#  ('braziliaan', 0.8456584215164185),
#  ('raborenner', 0.8441989421844482),
#  ('schaatser', 0.8414546251296997),
#  ('wielrenner', 0.8395117521286011),
#  ('roemeen', 0.8392737507820129),
#  ('engelsman', 0.8388472199440002),
#  ('coureur', 0.8375428915023804),
#  ('veldrijder', 0.8342293500900269),
#  ('jongh', 0.8329683542251587),
# ...

# %%
mtr.wv.most_similar(positive='belgen', topn=100)
# Out:
# [('italianen', 0.9097597002983093),
#  ('denen', 0.9009356498718262),
#  ('fransen', 0.899747908115387),
#  ('spanjaarden', 0.873287558555603),
#  ('engelsen', 0.8696771860122681),
#  ('duitsers', 0.8659653663635254),
#  ('noren', 0.8647935390472412),
#  ('ieren', 0.8629322052001953),
#  ('oostenrijkers', 0.8528397083282471),
#  ('brazilianen', 0.8337512612342834),
#  ('portugezen', 0.8276109099388123),
#  ('finnen', 0.8209179639816284),
#  ('grieken', 0.819879412651062),
#  ('tsjechen', 0.8118293285369873),
#  ('argentijnen', 0.809091329574585),
#  ('japanners', 0.8038381934165955),
#  ('vlamingen', 0.8017078638076782),
#  ('schotten', 0.7971108555793762),
#  ('britten', 0.7953180074691772),
#  ('friezen', 0.7935292720794678),
#  ('russen', 0.7909409403800964),
#  ('turken', 0.7897782325744629),
#  ('amsterdammers', 0.7795670032501221),
#  ('hongaren', 0.7792037129402161),
#  ('slowaken', 0.777276873588562),
#  ('canadezen', 0.7707617282867432),
# ...

# %%
mtr.wv.most_similar(positive='duitser', topn=100)
# Out:
# [('fransman', 0.951381266117096),
#  ('belg', 0.9177683591842651),
#  ('zweed', 0.9134117960929871),
#  ('oostenrijker', 0.9118030071258545),
#  ('italiaan', 0.8976958394050598),
#  ('zwitser', 0.8956480026245117),
#  ('brit', 0.8875376582145691),
#  ('australier', 0.8861803412437439),
#  ('noor', 0.8830088973045349),
#  ('spanjaard', 0.8728139996528625),
#  ('engelsman', 0.869379997253418),
#  ('roemeen', 0.8634961843490601),
#  ('argentijn', 0.8628009557723999),
#  ('tsjech', 0.8613104224205017),
#  ('japanner', 0.8599835634231567),
#  ('hongaar', 0.8550657033920288),
#  ('amerikaan', 0.8496954441070557),
#  ('bulgaar', 0.8472442626953125),
#  ('braziliaan', 0.8465700745582581),
#  ('kroaat', 0.8356004953384399),
#  ('keniaan', 0.8334633111953735),
#  ('chileen', 0.8311399817466736),
#  ('deen', 0.8263002634048462),
#  ('debutant', 0.8259472846984863),
#  ('pool', 0.8200682401657104),
#  ('slowaak', 0.8151799440383911),
#  ('landgenoot', 0.8102601170539856),
# ...

# %%
mtr.wv.most_similar(positive='duitsers', topn=100)
# Out:
# [('fransen', 0.9113649129867554),
#  ('engelsen', 0.8968954682350159),
#  ('spanjaarden', 0.8957928419113159),
#  ('russen', 0.8956956267356873),
#  ('italianen', 0.8886234164237976),
#  ('belgen', 0.8659653663635254),
#  ('britten', 0.856241762638092),
#  ('ieren', 0.8536869287490845),
#  ('japanners', 0.8506472110748291),
#  ('denen', 0.8408005833625793),
#  ('portugezen', 0.8401247262954712),
#  ('turken', 0.8338127136230469),
#  ('grieken', 0.8332686424255371),
#  ('oostenrijkers', 0.8154143691062927),
#  ('tsjechen', 0.8074809908866882),
#  ('amerikanen', 0.7974997758865356),
#  ('brazilianen', 0.7894484996795654),
#  ('chinezen', 0.7848511338233948),
#  ('europeanen', 0.7841491103172302),
#  ('hongaren', 0.7835447788238525),
#  ('noren', 0.778622031211853),
#  ('argentijnen', 0.7732880711555481),
#  ('canadezen', 0.7657615542411804),
#  ('geallieerden', 0.7655960321426392),
#  ('finnen', 0.751152753829956),
#  ('aziaten', 0.7506293058395386),
# ...

# %%
mtr.wv.most_similar(positive='westers', topn=100)
# Out:
# [('seculier', 0.8125892877578735),
#  ('islamitisch', 0.7566776871681213),
#  ('religieus', 0.7510757446289062),
#  ('nationalistisch', 0.7468202710151672),
#  ('communistisch', 0.7024517059326172),
#  ('totalitair', 0.7006497383117676),
#  ('socialistisch', 0.700208842754364),
#  ('autoritair', 0.6981627345085144),
#  ('kapitalistisch', 0.6950177550315857),
#  ('godsdienstig', 0.6822139024734497),
#  ('fundamentalistisch', 0.6816825866699219),
#  ('intellectueel', 0.6792489290237427),
#  ('racistisch', 0.6750767230987549),
#  ('achterlijk', 0.6703344583511353),
#  ('koloniaal', 0.668171763420105),
#  ('conservatief', 0.6681169271469116),
#  ('opkomend', 0.6629685163497925),
#  ('russisch', 0.6616347432136536),
#  ('soennitisch', 0.6607733368873596),
#  ('autonoom', 0.6555415987968445),
#  ('aziatisch', 0.6537502408027649),
#  ('democratisch', 0.6535520553588867),
#  ('modern', 0.6526580452919006),
#  ('geori', 0.6519535183906555),
#  ('nationalisme', 0.6509381532669067),
# ...

# %%
mtr.wv.most_similar(positive='christen', topn=100)
# Out:
# [('liberaal', 0.7934106588363647),
#  ('liberale', 0.7375171184539795),
#  ('conservatief', 0.6820270419120789),
#  ('liberalen', 0.6740432977676392),
#  ('conservatieven', 0.6586756706237793),
#  ('democraat', 0.6547409296035767),
#  ('linkse', 0.6435813903808594),
#  ('sociaal', 0.6365768313407898),
#  ('republikeinen', 0.6332497596740723),
#  ('conservatieve', 0.6293107271194458),
#  ('presidentskandidaat', 0.6267913579940796),
#  ('socialisten', 0.6236150860786438),
#  ('republikein', 0.6235044002532959),
#  ('progressieve', 0.620477020740509),
#  ('staatsvorm', 0.6182750463485718),
#  ('groenen', 0.6151409149169922),
#  ('moslim', 0.6126518845558167),
#  ('hervormer', 0.6090614795684814),
#  ('socialist', 0.6056349277496338),
#  ('fdp', 0.6014350652694702),
#  ('akp', 0.6002302169799805),
#  ('politicus', 0.5981617569923401),
#  ('rechtstaat', 0.5954559445381165),
#  ('vrijzinnig', 0.5911448001861572),
#  ('rechtsstaat', 0.589663028717041),
#  ('partij', 0.5885568857192993),
# ...

# %%
mtr.wv.most_similar(positive='christenen', topn=100)
# Out:
# [('moslims', 0.9452642798423767),
#  ('joden', 0.8858824968338013),
#  ('gelovigen', 0.8846035003662109),
#  ('islamieten', 0.8523245453834534),
#  ('katholieken', 0.8348531126976013),
#  ('arabieren', 0.8252728581428528),
#  ('protestanten', 0.8119691014289856),
#  ('hindoes', 0.8105896711349487),
#  ('boeddhisten', 0.8068833351135254),
#  ('soennieten', 0.7987725734710693),
#  ('koerden', 0.798275887966156),
#  ('sjiieten', 0.7958363890647888),
#  ('orthodoxen', 0.7946362495422363),
#  ('ongelovigen', 0.7918754816055298),
#  ('turken', 0.7895539999008179),
#  ('fundamentalisten', 0.7864383459091187),
#  ('westerlingen', 0.762724757194519),
#  ('egyptenaren', 0.7613424062728882),
#  ('salafisten', 0.7569347023963928),
#  ('seculieren', 0.7531498670578003),
#  ('extremisten', 0.7490159869194031),
#  ('palestijnen', 0.746273398399353),
#  ('islamisten', 0.7417358160018921),
#  ('priesters', 0.741606593132019),
#  ('tibetanen', 0.7400802373886108),
# ...
