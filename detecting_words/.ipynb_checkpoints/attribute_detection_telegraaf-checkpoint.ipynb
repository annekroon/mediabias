# %% [markdown]
# # detecting attributes (e.g., stereotypes) on the basis on trained models

# %%
import gensim

# %%
#mvolkskrant = gensim.models.Word2Vec.load('/Users/admin/Google Drive/2017_MigrantWorkers/data/trained_models/word2vec-volkskrant (print)-2006-01-01-2016-01-01')

# %%
mtelegraaf = gensim.models.Word2Vec.load('/Users/admin/Google Drive/2017_MigrantWorkers/data/trained_models/trained_2000_2016/telegraaf')

# %%
mtelegraaf.wv.most_similar(positive='marokkaan', topn=150)
# Out:
# [('turk', 0.8801292181015015),
#  ('utrechter', 0.8319655656814575),
#  ('antilliaan', 0.8231033086776733),
#  ('taxichauffeur', 0.8189578652381897),
#  ('rotterdammer', 0.8126174211502075),
#  ('vrachtwagenchauffeur', 0.8052381873130798),
#  ('politieman', 0.7997815608978271),
#  ('roemeen', 0.7884068489074707),
#  ('delftenaar', 0.7877012491226196),
#  ('prostituee', 0.7846521139144897),
#  ('surinamer', 0.7829015254974365),
#  ('schutter', 0.7826815247535706),
#  ('schiedammer', 0.7816773653030396),
#  ('knul', 0.7812137007713318),
#  ('pool', 0.7804931402206421),
#  ('jihadist', 0.7793528437614441),
#  ('hagenaar', 0.7787566781044006),
#  ('bouwvakker', 0.7782526016235352),
#  ('ghanees', 0.7759048342704773),
#  ('egyptenaar', 0.775345504283905),
#  ('griek', 0.7741899490356445),
#  ('nigeriaan', 0.773072361946106),
#  ('nijmegenaar', 0.7718414068222046),
#  ('tiener', 0.7705082893371582),
#  ('amsterdammer', 0.7675232887268066),
#  ('arnhemmer', 0.7667785882949829),
# ...

# %%
mtelegraaf.wv.most_similar(positive='marokkanen', topn=150)
# Out:
# [('surinamers', 0.849233090877533),
#  ('antillianen', 0.8363944292068481),
#  ('turken', 0.7761409282684326),
#  ('allochtonen', 0.7625359296798706),
#  ('buitenlanders', 0.7336505651473999),
#  ('prostituees', 0.7275799512863159),
#  ('moslims', 0.7248196601867676),
#  ('afghanen', 0.7166217565536499),
#  ('katholieken', 0.715731143951416),
#  ('arabieren', 0.7114654779434204),
#  ('immigranten', 0.7089077234268188),
#  ('islamieten', 0.7088958024978638),
#  ('roemenen', 0.7076221704483032),
#  ('tieners', 0.7074191570281982),
#  ('veteranen', 0.6986021399497986),
#  ('activisten', 0.6977149844169617),
#  ('christenen', 0.6955261826515198),
#  ('imams', 0.694968581199646),
#  ('joden', 0.6941487789154053),
#  ('molukkers', 0.6932656764984131),
#  ('moslimjongeren', 0.6928541660308838),
#  ('politieagenten', 0.6917197704315186),
#  ('bulgaren', 0.6889986991882324),
#  ('allochtone', 0.686168372631073),
#  ('irakezen', 0.6860834956169128),
#  ('leraren', 0.6833574771881104),
# ...

# %%
mtelegraaf.wv.most_similar(positive='marokkanen', topn=150)
# Out:
# [('surinamers', 0.849233090877533),
#  ('antillianen', 0.8363944292068481),
#  ('turken', 0.7761409282684326),
#  ('allochtonen', 0.7625359296798706),
#  ('buitenlanders', 0.7336505651473999),
#  ('prostituees', 0.7275799512863159),
#  ('moslims', 0.7248196601867676),
#  ('afghanen', 0.7166217565536499),
#  ('katholieken', 0.715731143951416),
#  ('arabieren', 0.7114654779434204),
#  ('immigranten', 0.7089077234268188),
#  ('islamieten', 0.7088958024978638),
#  ('roemenen', 0.7076221704483032),
#  ('tieners', 0.7074191570281982),
#  ('veteranen', 0.6986021399497986),
#  ('activisten', 0.6977149844169617),
#  ('christenen', 0.6955261826515198),
#  ('imams', 0.694968581199646),
#  ('joden', 0.6941487789154053),
#  ('molukkers', 0.6932656764984131),
#  ('moslimjongeren', 0.6928541660308838),
#  ('politieagenten', 0.6917197704315186),
#  ('bulgaren', 0.6889986991882324),
#  ('allochtone', 0.686168372631073),
#  ('irakezen', 0.6860834956169128),
#  ('leraren', 0.6833574771881104),
# ...
