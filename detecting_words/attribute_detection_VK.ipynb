# %% [markdown]
# # Detecting attributes (e.g., stereotypes) on the basis on np data
# ## Data trained on time period: 2000 - 2016

# %%
import gensim

# %% [markdown]
# # Newspaper: Volkskrant

# %%
mvk = gensim.models.Word2Vec.load('/Users/admin/Google Drive/2017_MigrantWorkers/data/trained_models/trained_2000_2016/volkskrant')

# %% [markdown]
# ## 1a. Target categories:
# ### Bevolkingsgroepen
# https://www.cbs.nl/nl-nl/achtergrond/2016/47/bevolking-naar-migratieachtergrond

# %%
mvk.wv.most_similar(positive='marokkaan', topn=100)
# Out:
# [('turk', 0.9196149110794067),
#  ('surinamer', 0.848940372467041),
#  ('antilliaan', 0.835710346698761),
#  ('afghaan', 0.8170002698898315),
#  ('arabier', 0.8008547425270081),
#  ('politieagent', 0.7901934385299683),
#  ('taxichauffeur', 0.7849849462509155),
#  ('buitenlander', 0.7722747325897217),
#  ('politieman', 0.7522616386413574),
#  ('irakees', 0.7491406202316284),
#  ('algerijn', 0.746071457862854),
#  ('jood', 0.7445240616798401),
#  ('jongen', 0.7432786822319031),
#  ('pedofiel', 0.7407262921333313),
#  ('palestijn', 0.7358148097991943),
#  ('misdadiger', 0.7260615825653076),
#  ('inbreker', 0.725827693939209),
#  ('hoer', 0.714922308921814),
#  ('bouwvakker', 0.7145551443099976),
#  ('buschauffeur', 0.7127547264099121),
#  ('prostituee', 0.7105187177658081),
#  ('tiener', 0.710125207901001),
#  ('moslim', 0.709429919719696),
#  ('terrorist', 0.7066622972488403),
#  ('jongeman', 0.7056965231895447),
#  ('rotterdammer', 0.7034581899642944),
# ...

# %%
mvk.wv.most_similar(positive='marokkanen', topn=100)
# Out:
# [('turken', 0.8958092927932739),
#  ('surinamers', 0.8821322917938232),
#  ('antillianen', 0.875781238079071),
#  ('allochtonen', 0.8532118201255798),
#  ('autochtonen', 0.8120657205581665),
#  ('moslims', 0.7851225137710571),
#  ('buitenlanders', 0.7656226754188538),
#  ('jongeren', 0.7547056078910828),
#  ('molukkers', 0.744120717048645),
#  ('nederlanders', 0.7415497303009033),
#  ('zwarten', 0.7285068035125732),
#  ('migranten', 0.7258096933364868),
#  ('moslimjongeren', 0.7196362018585205),
#  ('christenen', 0.7130316495895386),
#  ('islamieten', 0.7128534317016602),
#  ('autochtone', 0.7121170163154602),
#  ('immigranten', 0.7074592113494873),
#  ('vlamingen', 0.7065906524658203),
#  ('roemenen', 0.7031788229942322),
#  ('homoseksuelen', 0.691165030002594),
#  ('hangjongeren', 0.6890284419059753),
#  ('marokkaanse', 0.678375244140625),
#  ('bulgaren', 0.6779531240463257),
#  ('vrouwen', 0.665997326374054),
#  ('zigeuners', 0.6621644496917725),
#  ('imams', 0.6614099740982056),
# ...

# %%
mvk.wv.most_similar(positive='turk', topn=100)
# Out:
# [('marokkaan', 0.9196147918701172),
#  ('surinamer', 0.8387429714202881),
#  ('afghaan', 0.800142765045166),
#  ('antilliaan', 0.791921854019165),
#  ('arabier', 0.7908058762550354),
#  ('jood', 0.7694408893585205),
#  ('buitenlander', 0.7677960991859436),
#  ('algerijn', 0.7462770938873291),
#  ('hoer', 0.7416588068008423),
#  ('taxichauffeur', 0.7371001243591309),
#  ('politieagent', 0.7361394166946411),
#  ('inbreker', 0.7261788845062256),
#  ('alcoholist', 0.7189847230911255),
#  ('misdadiger', 0.7146029472351074),
#  ('pedofiel', 0.7116642594337463),
#  ('tiener', 0.706493616104126),
#  ('palestijn', 0.704086422920227),
#  ('egyptenaar', 0.7026320695877075),
#  ('moslim', 0.7000591158866882),
#  ('terrorist', 0.698377251625061),
#  ('politieman', 0.6979519724845886),
#  ('bouwvakker', 0.6964830160140991),
#  ('ghanees', 0.6937580108642578),
#  ('vrachtwagenchauffeur', 0.6930990219116211),
#  ('iranier', 0.6925638318061829),
#  ('rotterdammer', 0.6912944316864014),
# ...

# %%
mvk.wv.most_similar(positive='turken', topn=100)
# Out:
# [('marokkanen', 0.8958092331886292),
#  ('surinamers', 0.8468072414398193),
#  ('buitenlanders', 0.8467968702316284),
#  ('roemenen', 0.8262289762496948),
#  ('moslims', 0.8170619010925293),
#  ('christenen', 0.8102947473526001),
#  ('arabieren', 0.8095476627349854),
#  ('molukkers', 0.8079054951667786),
#  ('zwarten', 0.8069756627082825),
#  ('vlamingen', 0.8023470640182495),
#  ('antillianen', 0.7998307943344116),
#  ('nederlanders', 0.7981606721878052),
#  ('koerden', 0.7959685325622559),
#  ('hongaren', 0.7945206165313721),
#  ('duitsers', 0.7940875291824341),
#  ('kroaten', 0.7828860282897949),
#  ('bulgaren', 0.7827223539352417),
#  ('joden', 0.7773629426956177),
#  ('denen', 0.7733626961708069),
#  ('migranten', 0.7723241448402405),
#  ('ieren', 0.7716842293739319),
#  ('albanezen', 0.7712298631668091),
#  ('afghanen', 0.7701873779296875),
#  ('autochtonen', 0.765255331993103),
#  ('immigranten', 0.7637634873390198),
#  ('allochtonen', 0.7630695700645447),
# ...

# %%
mvk.wv.most_similar(positive='surinamer', topn=100)
# Out:
# [('marokkaan', 0.8489403128623962),
#  ('turk', 0.8387429714202881),
#  ('antilliaan', 0.7938047647476196),
#  ('arabier', 0.7873525619506836),
#  ('afghaan', 0.7718175649642944),
#  ('huisvader', 0.7687484622001648),
#  ('buitenlander', 0.7506099939346313),
#  ('loodgieter', 0.7453047037124634),
#  ('bouwvakker', 0.7415602803230286),
#  ('taxichauffeur', 0.7406575679779053),
#  ('knul', 0.7393409609794617),
#  ('buschauffeur', 0.7381613254547119),
#  ('dertiger', 0.7351431846618652),
#  ('postbode', 0.7283006906509399),
#  ('academicus', 0.7247620820999146),
#  ('inbreker', 0.7238300442695618),
#  ('hoer', 0.7213665246963501),
#  ('zwerver', 0.7209019660949707),
#  ('oplichter', 0.7170770168304443),
#  ('misdadiger', 0.7166413068771362),
#  ('alcoholist', 0.7157450914382935),
#  ('politieagent', 0.7155885696411133),
#  ('neger', 0.7107719779014587),
#  ('bedelaar', 0.7065596580505371),
#  ('pitbull', 0.7056221961975098),
#  ('kleuter', 0.7052350044250488),
# ...

# %%
mvk.wv.most_similar(positive='surinamers', topn=100)
# Out:
# [('antillianen', 0.9008880853652954),
#  ('marokkanen', 0.8821322917938232),
#  ('turken', 0.8468073606491089),
#  ('autochtonen', 0.7636871337890625),
#  ('zwarten', 0.7591992616653442),
#  ('autochtone', 0.7584344148635864),
#  ('arubanen', 0.758208692073822),
#  ('aziaten', 0.7552695274353027),
#  ('molukkers', 0.7489073276519775),
#  ('ghanezen', 0.7469719648361206),
#  ('roemenen', 0.7385337948799133),
#  ('bulgaren', 0.7376894950866699),
#  ('hongaren', 0.7311676740646362),
#  ('allochtonen', 0.7257430553436279),
#  ('vlamingen', 0.7179456949234009),
#  ('indiers', 0.7138305306434631),
#  ('somaliers', 0.7062356472015381),
#  ('hindoestanen', 0.6966608762741089),
#  ('buitenlanders', 0.6966135501861572),
#  ('nederlanders', 0.6934095621109009),
#  ('nigerianen', 0.69268798828125),
#  ('algerijnen', 0.6926435232162476),
#  ('twintigers', 0.6924632787704468),
#  ('zigeuners', 0.6889585852622986),
#  ('kroaten', 0.6861951351165771),
#  ('hoogopgeleide', 0.6832039952278137),
# ...

# %%
mvk.wv.most_similar(positive='antilliaan', topn=100)
# Out:
# [('marokkaan', 0.8357102870941162),
#  ('afghaan', 0.8153066635131836),
#  ('rotterdammer', 0.7986242771148682),
#  ('surinamer', 0.7938047647476196),
#  ('turk', 0.791921854019165),
#  ('pakistaan', 0.7897325754165649),
#  ('arrestant', 0.7892318964004517),
#  ('eindhovenaar', 0.7854688763618469),
#  ('nigeriaan', 0.777499794960022),
#  ('elektricien', 0.7705448865890503),
#  ('ghanees', 0.7693785429000854),
#  ('politieagente', 0.768634557723999),
#  ('algerijn', 0.7674649953842163),
#  ('cipier', 0.7672274708747864),
#  ('buschauffeur', 0.7659162878990173),
#  ('servier', 0.7653224468231201),
#  ('stewardess', 0.7648769617080688),
#  ('iranier', 0.7630929946899414),
#  ('taxichauffeur', 0.7604238986968994),
#  ('hagenaar', 0.7604056596755981),
#  ('tilburger', 0.7589837312698364),
#  ('pedofiel', 0.7556939125061035),
#  ('utrechter', 0.7539386749267578),
#  ('hoofdagent', 0.7526360750198364),
#  ('indier', 0.7519175410270691),
#  ('kroegbaas', 0.7462977170944214),
# ...

# %%
mvk.wv.most_similar(positive='antillianen', topn=100)
# Out:
# [('surinamers', 0.9008880853652954),
#  ('marokkanen', 0.875781238079071),
#  ('allochtonen', 0.8181129693984985),
#  ('autochtonen', 0.8148954510688782),
#  ('turken', 0.7998308539390564),
#  ('migranten', 0.7522391080856323),
#  ('prostituees', 0.7442420125007629),
#  ('buitenlanders', 0.7438941597938538),
#  ('autochtone', 0.7395210266113281),
#  ('jongeren', 0.7282452583312988),
#  ('hoogopgeleiden', 0.7246006727218628),
#  ('ghanezen', 0.7222573757171631),
#  ('molukkers', 0.7208194732666016),
#  ('zwarten', 0.7194073796272278),
#  ('tweeverdieners', 0.7179566025733948),
#  ('gezinnen', 0.7176480293273926),
#  ('bulgaren', 0.7134791612625122),
#  ('immigranten', 0.7115926742553711),
#  ('allochtone', 0.7105178833007812),
#  ('hoogopgeleide', 0.7087233662605286),
#  ('somaliers', 0.7032945156097412),
#  ('expats', 0.6995803117752075),
#  ('verslaafden', 0.6979970932006836),
#  ('ouderen', 0.6978713274002075),
#  ('bejaarden', 0.6974568367004395),
# ...

# %%
mvk.wv.most_similar(positive='irakees', topn=100)
# Out:
# [('palestijn', 0.8862962126731873),
#  ('afghaan', 0.8495995998382568),
#  ('politieman', 0.8394793272018433),
#  ('politieagent', 0.8251552581787109),
#  ('terrorist', 0.816824734210968),
#  ('arrestant', 0.8072822690010071),
#  ('gedetineerde', 0.8032711148262024),
#  ('servier', 0.8009681701660156),
#  ('gevangene', 0.7920100092887878),
#  ('koerd', 0.7905066013336182),
#  ('overvaller', 0.7891956567764282),
#  ('betoger', 0.7791101932525635),
#  ('kolonist', 0.7763749957084656),
#  ('demonstrant', 0.7755714654922485),
#  ('schutter', 0.7735539674758911),
#  ('algerijn', 0.771507203578949),
#  ('strijder', 0.763158917427063),
#  ('soldaat', 0.7603211402893066),
#  ('agent', 0.7598724365234375),
#  ('asielzoeker', 0.7564654350280762),
#  ('misdadiger', 0.7558499574661255),
#  ('korporaal', 0.7522985935211182),
#  ('pedofiel', 0.7501926422119141),
#  ('marokkaan', 0.7491406202316284),
#  ('bewaker', 0.7449201941490173),
#  ('sluipschutter', 0.7435951232910156),
# ...

# %%
mvk.wv.most_similar(positive='irakezen', topn=100)
# Out:
# [('afghanen', 0.934851884841919),
#  ('libanezen', 0.8420830965042114),
#  ('palestijnen', 0.8374593257904053),
#  ('koerden', 0.8293827772140503),
#  ('amerikanen', 0.8266689777374268),
#  ('tsjetsjenen', 0.8252054452896118),
#  ('militairen', 0.8175544738769531),
#  ('pakistanen', 0.8167839646339417),
#  ('soldaten', 0.8106421232223511),
#  ('strijders', 0.8087863326072693),
#  ('rebellen', 0.8031660914421082),
#  ('opstandelingen', 0.7974884510040283),
#  ('manschappen', 0.7877655625343323),
#  ('arabieren', 0.7871298789978027),
#  ('serviers', 0.7830060720443726),
#  ('iraniers', 0.7816359996795654),
#  ('dorpelingen', 0.7814124822616577),
#  ('cubanen', 0.7806521654129028),
#  ('albanezen', 0.7792825698852539),
#  ('mexicanen', 0.778015673160553),
#  ('gijzelaars', 0.7757519483566284),
#  ('terroristen', 0.7728252410888672),
#  ('zimbabwanen', 0.7726452946662903),
#  ('indonesiers', 0.7707067131996155),
#  ('russen', 0.7673757672309875),
#  ('taliban', 0.7639256119728088),
# ...

# %%
mvk.wv.most_similar(positive='afghaan', topn=100)
# Out:
# [('irakees', 0.8495995998382568),
#  ('iranier', 0.820035994052887),
#  ('koerd', 0.8187860250473022),
#  ('marokkaan', 0.8170002698898315),
#  ('antilliaan', 0.8153066635131836),
#  ('pakistaan', 0.8110578060150146),
#  ('algerijn', 0.8093589544296265),
#  ('palestijn', 0.8091861009597778),
#  ('turk', 0.800142765045166),
#  ('betoger', 0.7966195344924927),
#  ('arrestant', 0.7936837673187256),
#  ('arabier', 0.792051374912262),
#  ('misdadiger', 0.7886205911636353),
#  ('politieagent', 0.7742328643798828),
#  ('servier', 0.7726483941078186),
#  ('surinamer', 0.7718175649642944),
#  ('korporaal', 0.7705075740814209),
#  ('taxichauffeur', 0.7700674533843994),
#  ('politieman', 0.7682237029075623),
#  ('terrorist', 0.7669870853424072),
#  ('pedofiel', 0.7658596634864807),
#  ('buschauffeur', 0.7635284662246704),
#  ('egyptenaar', 0.763358473777771),
#  ('jihadist', 0.7578353881835938),
#  ('inbreker', 0.7574408054351807),
#  ('bouwvakker', 0.7528518438339233),
# ...

# %%
mvk.wv.most_similar(positive='afghanen', topn=100)
# Out:
# [('irakezen', 0.9348519444465637),
#  ('libanezen', 0.892802357673645),
#  ('pakistanen', 0.8677811026573181),
#  ('koerden', 0.8630470037460327),
#  ('dorpelingen', 0.850676417350769),
#  ('cubanen', 0.8379164934158325),
#  ('westerlingen', 0.8363756537437439),
#  ('arabieren', 0.8356080055236816),
#  ('tsjetsjenen', 0.8336264491081238),
#  ('strijders', 0.8327325582504272),
#  ('buitenlanders', 0.8302459120750427),
#  ('tibetanen', 0.8291568160057068),
#  ('egyptenaren', 0.8276036977767944),
#  ('mexicanen', 0.8267143964767456),
#  ('iraniers', 0.8240207433700562),
#  ('chinezen', 0.8225720524787903),
#  ('zimbabwanen', 0.8219999074935913),
#  ('albanezen', 0.817797839641571),
#  ('indonesiers', 0.8175327777862549),
#  ('militairen', 0.8173778057098389),
#  ('soldaten', 0.814355731010437),
#  ('amerikanen', 0.808424174785614),
#  ('jihadisten', 0.8075387477874756),
#  ('opstandelingen', 0.8045825362205505),
#  ('palestijnen', 0.8040903806686401),
# ...

# %%
mvk.wv.most_similar(positive='syrier', topn=100)
# Out:
# [('achraf', 0.8776560425758362),
#  ('jemeniet', 0.8553708791732788),
#  ('libier', 0.849319577217102),
#  ('mahmud', 0.8342849016189575),
#  ('bendeleider', 0.8341432809829712),
#  ('shaikh', 0.8317895531654358),
#  ('jotcha', 0.8306137919425964),
#  ('mafiabaas', 0.8264943361282349),
#  ('naeem', 0.8230846524238586),
#  ('mensenrechtenadvocaat', 0.8202279210090637),
#  ('kazemi', 0.8177257776260376),
#  ('atef', 0.8144081830978394),
#  ('eddin', 0.8116113543510437),
#  ('tayeb', 0.8109824657440186),
#  ('amar', 0.8077992796897888),
#  ('pakistaan', 0.8069055080413818),
#  ('blagojevic', 0.8060709834098816),
#  ('hani', 0.8054126501083374),
#  ('bomexpert', 0.8049793839454651),
#  ('naser', 0.8046326637268066),
#  ('koelov', 0.8042320013046265),
#  ('fuad', 0.8038249015808105),
#  ('oezbeek', 0.8033744692802429),
#  ('sadeq', 0.8023873567581177),
#  ('kickbokser', 0.8022346496582031),
#  ('anas', 0.8021950721740723),
#  ('younes', 0.8019319772720337),
# ...

# %%
mvk.wv.most_similar(positive='syriers', topn=100)
# Out:
# [('macedoniers', 0.8399714231491089),
#  ('iraniers', 0.8266974687576294),
#  ('israeliers', 0.8239088654518127),
#  ('serviers', 0.8102104663848877),
#  ('tsjetsjenen', 0.8023444414138794),
#  ('pakistanen', 0.8013678789138794),
#  ('libanezen', 0.8004083633422852),
#  ('indonesiers', 0.7832858562469482),
#  ('oppositieleden', 0.7760986089706421),
#  ('nepalezen', 0.7760912179946899),
#  ('stamleiders', 0.7670238018035889),
#  ('regeringssoldaten', 0.765966534614563),
#  ('maoisten', 0.7653284668922424),
#  ('tamils', 0.7647855281829834),
#  ('tibetanen', 0.7582748532295227),
#  ('afghanen', 0.7560276985168457),
#  ('militieleden', 0.7553888559341431),
#  ('guerrillastrijders', 0.7547042369842529),
#  ('kosovaren', 0.7523139119148254),
#  ('soennieten', 0.75230872631073),
#  ('indiers', 0.7504633665084839),
#  ('oppositieleiders', 0.7488113045692444),
#  ('mexicanen', 0.7463715672492981),
#  ('paramilitairen', 0.7456581592559814),
#  ('hmong', 0.7455780506134033),
# ...

# %%
mvk.wv.most_similar(positive='somalier', topn=100)
# Out:
# [('verspringster', 0.7917852401733398),
#  ('kazemi', 0.7902860045433044),
#  ('hongerstaker', 0.7870008945465088),
#  ('ramptoerist', 0.7850747108459473),
#  ('zwollenaar', 0.7832112312316895),
#  ('atef', 0.7823357582092285),
#  ('bomexpert', 0.7818925976753235),
#  ('rebiya', 0.7807867527008057),
#  ('syrier', 0.7793784737586975),
#  ('berland', 0.7778997421264648),
#  ('habchi', 0.7771244049072266),
#  ('saudier', 0.7762973308563232),
#  ('khadr', 0.7761683464050293),
#  ('kindermoordenaar', 0.7755771279335022),
#  ('tsjetsjeen', 0.7749230265617371),
#  ('mormoon', 0.7748472690582275),
#  ('varkensboerderij', 0.7744119167327881),
#  ('seksist', 0.772949755191803),
#  ('blagojevic', 0.7729441523551941),
#  ('verzekeringsagent', 0.7728241682052612),
#  ('amar', 0.7718590497970581),
#  ('fatou', 0.7715872526168823),
#  ('spijbelaar', 0.7713382840156555),
#  ('molukker', 0.771074652671814),
#  ('gevangenisbewaarder', 0.7704808712005615),
#  ('indonesier', 0.7694491744041443),
# ...

# %%
mvk.wv.most_similar(positive='somaliers', topn=100)
# Out:
# [('ghanezen', 0.848147451877594),
#  ('nigerianen', 0.8449958562850952),
#  ('congolezen', 0.8219859004020691),
#  ('indiers', 0.8142353892326355),
#  ('ethiopiers', 0.8022909164428711),
#  ('iraniers', 0.7996714115142822),
#  ('nepalezen', 0.7991098761558533),
#  ('birmezen', 0.7986457943916321),
#  ('sudanezen', 0.7981716990470886),
#  ('indonesiers', 0.7944895625114441),
#  ('rwandezen', 0.7909349799156189),
#  ('srilankanen', 0.7876592874526978),
#  ('pakistanen', 0.7871302366256714),
#  ('algerijnen', 0.779832661151886),
#  ('libanezen', 0.7796515822410583),
#  ('tibetanen', 0.7663644552230835),
#  ('madurezen', 0.7630239725112915),
#  ('dayaks', 0.7597404718399048),
#  ('jemenieten', 0.758812665939331),
#  ('ugandezen', 0.7579501867294312),
#  ('moskovieten', 0.7518126964569092),
#  ('drugsgebruikers', 0.7514329552650452),
#  ('buspassagiers', 0.7446221709251404),
#  ('molukkers', 0.7441741228103638),
#  ('atjeers', 0.7426452040672302),
#  ('oezbeken', 0.7426223754882812),
# ...

# %%
mvk.wv.most_similar(positive='pool', topn=100)
# Out:
# [('engelsman', 0.849189043045044),
#  ('japanner', 0.8277831673622131),
#  ('keniaan', 0.8169528245925903),
#  ('hongaar', 0.8115968108177185),
#  ('griek', 0.807076096534729),
#  ('roemeen', 0.8050721883773804),
#  ('brit', 0.7972162961959839),
#  ('slowaak', 0.7807106375694275),
#  ('debutant', 0.7789195775985718),
#  ('duitser', 0.7776051759719849),
#  ('ghanees', 0.7755141258239746),
#  ('oostenrijker', 0.7723554968833923),
#  ('australier', 0.7670269012451172),
#  ('kroaat', 0.7664902210235596),
#  ('honkballer', 0.7651283144950867),
#  ('zwitser', 0.7619047164916992),
#  ('texaan', 0.7608630061149597),
#  ('oekrainer', 0.7596970796585083),
#  ('tsjech', 0.7582889199256897),
#  ('golfer', 0.7573199272155762),
#  ('cubaan', 0.7571110129356384),
#  ('zweed', 0.7557886242866516),
#  ('nigeriaan', 0.7530742883682251),
#  ('worstelaar', 0.7496622204780579),
#  ('zwemmer', 0.748528003692627),
#  ('colombiaan', 0.7480854988098145),
#  ('werper', 0.7480040788650513),
# ...

# %%
mvk.wv.most_similar(positive='polen', topn=100)
# Out:
# [('duitsland', 0.8300697803497314),
#  ('hongarije', 0.8288000822067261),
#  ('spanje', 0.8287845253944397),
#  ('bulgarije', 0.8267409801483154),
#  ('itali', 0.8146755695343018),
#  ('zweden', 0.8087440729141235),
#  ('turkije', 0.8061600923538208),
#  ('denemarken', 0.7952181100845337),
#  ('roemeni', 0.7910618782043457),
#  ('roemenen', 0.7890362739562988),
#  ('frankrijk', 0.7857924699783325),
#  ('portugal', 0.7843500971794128),
#  ('oostenrijk', 0.7797613739967346),
#  ('noorwegen', 0.7780441641807556),
#  ('belgi', 0.7768441438674927),
#  ('ijsland', 0.7599334716796875),
#  ('slowakije', 0.7570705413818359),
#  ('bulgaren', 0.7458398342132568),
#  ('litouwen', 0.7455968260765076),
#  ('ierland', 0.7365858554840088),
#  ('brazili', 0.736433207988739),
#  ('kroati', 0.7306088209152222),
#  ('letland', 0.7304202318191528),
#  ('estland', 0.7286556959152222),
#  ('zwitserland', 0.7280020713806152),
#  ('turken', 0.7278709411621094),
#  ('engeland', 0.7265564203262329),
# ...

# %% [markdown]
# ## 1b. Target categories:
# ### Immigranten groups // labels.

# %%
mvk.wv.most_similar(positive='arabier', topn=100)
# Out:
# [('jood', 0.8301355242729187),
#  ('terrorist', 0.8112589120864868),
#  ('misdadiger', 0.8072718977928162),
#  ('marokkaan', 0.8008546829223633),
#  ('afghaan', 0.792051374912262),
#  ('turk', 0.7908058762550354),
#  ('surinamer', 0.7873525023460388),
#  ('palestijn', 0.7783282399177551),
#  ('politieagent', 0.7761586308479309),
#  ('hoer', 0.7757587432861328),
#  ('verrader', 0.7586479187011719),
#  ('racist', 0.7554987668991089),
#  ('neger', 0.7551309466362),
#  ('extremist', 0.7536913156509399),
#  ('strijder', 0.7448155879974365),
#  ('buitenlander', 0.7428897619247437),
#  ('inbreker', 0.7414085268974304),
#  ('irakees', 0.7354934215545654),
#  ('psychopaat', 0.7337849736213684),
#  ('taxichauffeur', 0.7332696914672852),
#  ('monnik', 0.7294039726257324),
#  ('pedofiel', 0.72776198387146),
#  ('fundamentalist', 0.7270594835281372),
#  ('drugsdealer', 0.7266088724136353),
#  ('klootzak', 0.7224005460739136),
#  ('antilliaan', 0.7174556255340576),
# ...

# %%
mvk.wv.most_similar(positive='arabieren', topn=100)
# Out:
# [('christenen', 0.9224784970283508),
#  ('koerden', 0.888729989528656),
#  ('joden', 0.8536557555198669),
#  ('soennieten', 0.8534021377563477),
#  ('kroaten', 0.8511633276939392),
#  ('westerlingen', 0.8468393087387085),
#  ('albanezen', 0.8440399765968323),
#  ('tsjetsjenen', 0.8430525064468384),
#  ('egyptenaren', 0.8371124863624573),
#  ('afghanen', 0.8356080055236816),
#  ('indianen', 0.8349407911300659),
#  ('islamieten', 0.83121657371521),
#  ('zwarten', 0.8287674188613892),
#  ('hindoes', 0.8236996531486511),
#  ('libanezen', 0.8224667310714722),
#  ('tibetanen', 0.8183878064155579),
#  ('kolonisten', 0.8132778406143188),
#  ('moslims', 0.8096397519111633),
#  ('turken', 0.8095477223396301),
#  ('pakistanen', 0.8093496561050415),
#  ('tamils', 0.8070946931838989),
#  ('islamisten', 0.7994230389595032),
#  ('fundamentalisten', 0.7990566492080688),
#  ('protestanten', 0.7984688878059387),
#  ('macedoniers', 0.7967761754989624),
#  ('sjiieten', 0.79499351978302),
# ...

# %%
mvk.wv.most_similar(positive='moslim', topn=100)
# Out:
# [('jood', 0.8521975874900818),
#  ('gelovige', 0.7778857946395874),
#  ('islamieten', 0.7482620477676392),
#  ('terrorist', 0.7333961725234985),
#  ('fundamentalist', 0.730522632598877),
#  ('sekte', 0.7304972410202026),
#  ('imam', 0.7236506938934326),
#  ('fundamentalisten', 0.712986946105957),
#  ('islam', 0.7100430727005005),
#  ('minderheid', 0.7098246812820435),
#  ('bevolkingsgroep', 0.7097801566123962),
#  ('marokkaan', 0.709429919719696),
#  ('militant', 0.7049261331558228),
#  ('groepering', 0.7041078805923462),
#  ('moslims', 0.7039448022842407),
#  ('extremist', 0.7035773396492004),
#  ('arabier', 0.7023858428001404),
#  ('turk', 0.7000591158866882),
#  ('strijder', 0.6987980604171753),
#  ('broederschap', 0.6967160105705261),
#  ('christenen', 0.6906557083129883),
#  ('rabbijn', 0.6878368258476257),
#  ('orthodox', 0.6846114993095398),
#  ('racist', 0.6841480731964111),
#  ('ongelovige', 0.6808582544326782),
#  ('vreemdeling', 0.6801527738571167),
# ...

# %%
mvk.wv.most_similar(positive='moslims', topn=100)
# Out:
# [('christenen', 0.884035050868988),
#  ('gelovigen', 0.8614829778671265),
#  ('joden', 0.8526365756988525),
#  ('islamieten', 0.849600076675415),
#  ('turken', 0.8170620203018188),
#  ('arabieren', 0.8096397519111633),
#  ('koerden', 0.8064274787902832),
#  ('moslimvrouwen', 0.8033322095870972),
#  ('moslimjongeren', 0.7951462268829346),
#  ('fundamentalisten', 0.792682409286499),
#  ('imams', 0.7921138405799866),
#  ('marokkanen', 0.7851225137710571),
#  ('burgers', 0.7730087041854858),
#  ('katholieken', 0.771802544593811),
#  ('soennieten', 0.7705162763595581),
#  ('islamisten', 0.7682164311408997),
#  ('extremisten', 0.7623600363731384),
#  ('homoseksuelen', 0.7606807947158813),
#  ('westerlingen', 0.7581712603569031),
#  ('afghanen', 0.7549475431442261),
#  ('palestijnen', 0.7517905831336975),
#  ('zwarten', 0.7514240741729736),
#  ('buitenlanders', 0.7506325244903564),
#  ('immigranten', 0.7484613656997681),
#  ('islam', 0.7466757893562317),
# ...

# %%
mvk.wv.most_similar(positive='vluchteling', topn=100)
# Out:
# [('asielzoeker', 0.7737219929695129),
#  ('koerd', 0.7517111897468567),
#  ('immigrant', 0.7168283462524414),
#  ('gevangene', 0.7108757495880127),
#  ('strijder', 0.7041546702384949),
#  ('jood', 0.7040673494338989),
#  ('krijgsgevangene', 0.6770302057266235),
#  ('moslim', 0.6710835695266724),
#  ('kolonist', 0.6664365530014038),
#  ('gijzelaar', 0.6607929468154907),
#  ('vluchtelinge', 0.6524381637573242),
#  ('activist', 0.6492277383804321),
#  ('krijgsheer', 0.6489882469177246),
#  ('afghaan', 0.6478866338729858),
#  ('irakees', 0.6460946798324585),
#  ('terrorist', 0.6369595527648926),
#  ('martelaar', 0.6368626356124878),
#  ('vreemdeling', 0.6359739899635315),
#  ('spion', 0.6329402923583984),
#  ('bevrijdingsbeweging', 0.6307684779167175),
#  ('balling', 0.6294342875480652),
#  ('kolonie', 0.6267848014831543),
#  ('arabier', 0.6267529726028442),
#  ('ambassadeur', 0.6233943700790405),
#  ('palestijn', 0.6232170462608337),
#  ('migrant', 0.6226590275764465),
# ...

# %%
mvk.wv.most_similar(positive='vluchtelingen', topn=100)
# Out:
# [('asielzoekers', 0.8845714330673218),
#  ('migranten', 0.8758352994918823),
#  ('illegalen', 0.8424656391143799),
#  ('ontheemden', 0.8394708037376404),
#  ('immigranten', 0.8294262886047363),
#  ('vreemdelingen', 0.8230057954788208),
#  ('bootvluchtelingen', 0.8062223792076111),
#  ('afghanen', 0.7963176369667053),
#  ('buitenlanders', 0.7745860815048218),
#  ('arbeidsmigranten', 0.7638063430786133),
#  ('koerden', 0.7633984088897705),
#  ('militairen', 0.7463113069534302),
#  ('inwoners', 0.7394445538520813),
#  ('tibetanen', 0.7360308766365051),
#  ('burgers', 0.7360219955444336),
#  ('albanezen', 0.7317168116569519),
#  ('irakezen', 0.7305701971054077),
#  ('gevangenen', 0.7284424901008606),
#  ('congolezen', 0.7210702896118164),
#  ('kolonisten', 0.7175657749176025),
#  ('gastarbeiders', 0.7157615423202515),
#  ('palestijnen', 0.7152639627456665),
#  ('jihadisten', 0.7145544290542603),
#  ('libanezen', 0.7116469144821167),
#  ('strijders', 0.7110679149627686),
# ...

# %%
mvk.wv.most_similar(positive='allochtoon', topn=100)
# Out:
# [('autochtoon', 0.8003265857696533),
#  ('moslim', 0.671786904335022),
#  ('migrant', 0.6639618873596191),
#  ('allochtonen', 0.6482037305831909),
#  ('autochtone', 0.6456050872802734),
#  ('autochtonen', 0.6377601027488708),
#  ('allochtone', 0.6298581957817078),
#  ('gelovige', 0.6110364198684692),
#  ('ras', 0.6028947234153748),
#  ('marokkanen', 0.6027231216430664),
#  ('marokkaans', 0.5991982221603394),
#  ('katholiek', 0.5947949886322021),
#  ('etniciteit', 0.580016553401947),
#  ('afkomst', 0.575726330280304),
#  ('analfabeet', 0.5687042474746704),
#  ('marokkaanse', 0.5640891790390015),
#  ('jood', 0.5608140230178833),
#  ('hoogopgeleide', 0.5581406950950623),
#  ('werkloze', 0.5535349249839783),
#  ('volwassene', 0.5532304644584656),
#  ('orthodox', 0.5508439540863037),
#  ('protestant', 0.5476744174957275),
#  ('antillianen', 0.5475860834121704),
#  ('marokkaan', 0.5387077331542969),
#  ('leerkracht', 0.5384234189987183),
#  ('praktiserend', 0.5372267365455627),
# ...

# %%
mvk.wv.most_similar(positive='allochtonen', topn=100)
# Out:
# [('autochtonen', 0.8833271861076355),
#  ('marokkanen', 0.8532118201255798),
#  ('jongeren', 0.8315900564193726),
#  ('ouderen', 0.8186905384063721),
#  ('antillianen', 0.8181129693984985),
#  ('nieuwkomers', 0.7984796762466431),
#  ('hoogopgeleiden', 0.7955540418624878),
#  ('migranten', 0.7804376482963562),
#  ('allochtone', 0.7782535552978516),
#  ('plussers', 0.7665570378303528),
#  ('turken', 0.7630696296691895),
#  ('leerkrachten', 0.7345695495605469),
#  ('moslims', 0.7344884276390076),
#  ('immigranten', 0.7336010932922363),
#  ('buitenlanders', 0.7331745028495789),
#  ('leraren', 0.733119010925293),
#  ('surinamers', 0.7257430553436279),
#  ('werkenden', 0.7095254063606262),
#  ('moslimjongeren', 0.7086460590362549),
#  ('scholieren', 0.7076926231384277),
#  ('autochtone', 0.7068957090377808),
#  ('kansarmen', 0.706820547580719),
#  ('nederlanders', 0.7067216038703918),
#  ('leerlingen', 0.7063089609146118),
#  ('docenten', 0.7010643482208252),
# ...

# %%
mvk.wv.most_similar(positive='immigrant', topn=100)
# Out:
# [('jood', 0.7581498622894287),
#  ('toerist', 0.7283334136009216),
#  ('asielzoeker', 0.7270621061325073),
#  ('spion', 0.7261171936988831),
#  ('gijzelaar', 0.7224292159080505),
#  ('misdadiger', 0.7192345857620239),
#  ('vluchteling', 0.7168283462524414),
#  ('zakenman', 0.7164121270179749),
#  ('migrant', 0.715551495552063),
#  ('arabier', 0.7029733657836914),
#  ('kolonie', 0.7010884284973145),
#  ('missionaris', 0.6978447437286377),
#  ('toeriste', 0.6971709728240967),
#  ('vrachtwagenchauffeur', 0.6961525678634644),
#  ('gastarbeider', 0.694266676902771),
#  ('tiener', 0.693834662437439),
#  ('prostituee', 0.6934037208557129),
#  ('jihadist', 0.6915469169616699),
#  ('boerenzoon', 0.6867554187774658),
#  ('marokkaan', 0.6866964101791382),
#  ('koerd', 0.686566948890686),
#  ('arbeider', 0.6827093958854675),
#  ('monnik', 0.682334840297699),
#  ('vrijheidsstrijder', 0.681082010269165),
#  ('marinier', 0.6803861856460571),
#  ('aristocraat', 0.6798388361930847),
# ...

# %%
mvk.wv.most_similar(positive='immigranten', topn=100)
# Out:
# [('migranten', 0.9413442611694336),
#  ('gastarbeiders', 0.8312355279922485),
#  ('arbeidsmigranten', 0.8304157853126526),
#  ('vluchtelingen', 0.8294262886047363),
#  ('buitenlanders', 0.8271844983100891),
#  ('vreemdelingen', 0.7893975377082825),
#  ('emigranten', 0.788599967956543),
#  ('arbeiders', 0.7820137143135071),
#  ('turken', 0.7637636065483093),
#  ('asielzoekers', 0.760221004486084),
#  ('moslims', 0.7484613656997681),
#  ('illegalen', 0.7460648417472839),
#  ('gezinnen', 0.7434126734733582),
#  ('ingezetenen', 0.7386196255683899),
#  ('koerden', 0.7380015850067139),
#  ('allochtonen', 0.7336010932922363),
#  ('zwarten', 0.7330788373947144),
#  ('chinezen', 0.7316824197769165),
#  ('moslimvrouwen', 0.7269541025161743),
#  ('nieuwkomers', 0.722642183303833),
#  ('joden', 0.7209423184394836),
#  ('boeren', 0.7201099395751953),
#  ('afghanen', 0.7199103236198425),
#  ('prostituees', 0.7190411686897278),
#  ('tibetanen', 0.7141721248626709),
# ...

# %%
mvk.wv.most_similar(positive='migrant', topn=100)
# Out:
# [('immigrant', 0.715551495552063),
#  ('surinamer', 0.691145122051239),
#  ('vreemdeling', 0.6814665794372559),
#  ('plusser', 0.6810430288314819),
#  ('toerist', 0.6806212067604065),
#  ('jood', 0.679023265838623),
#  ('moslim', 0.671000599861145),
#  ('moslimvrouw', 0.6708875298500061),
#  ('allochtoon', 0.6639618873596191),
#  ('hulpverlener', 0.6523890495300293),
#  ('marokkaan', 0.6513438820838928),
#  ('volwassene', 0.6501589417457581),
#  ('buitenlander', 0.6436915993690491),
#  ('academicus', 0.6357906460762024),
#  ('turk', 0.6355740427970886),
#  ('misdadiger', 0.6327151656150818),
#  ('onderklasse', 0.6325113773345947),
#  ('arbeider', 0.6315262317657471),
#  ('ingezetene', 0.6289440393447876),
#  ('westerling', 0.6264228820800781),
#  ('vluchteling', 0.6226590275764465),
#  ('roker', 0.6205846071243286),
#  ('bekeerling', 0.6167563199996948),
#  ('professional', 0.6147433519363403),
#  ('beschermer', 0.6144958734512329),
#  ('sollicitant', 0.6144334673881531),
# ...

# %%
mvk.wv.most_similar(positive='migranten', topn=100)
# Out:
# [('immigranten', 0.941344141960144),
#  ('vluchtelingen', 0.8758352994918823),
#  ('arbeidsmigranten', 0.8523609638214111),
#  ('vreemdelingen', 0.838367760181427),
#  ('buitenlanders', 0.8368329405784607),
#  ('asielzoekers', 0.819587767124176),
#  ('illegalen', 0.7984808683395386),
#  ('gastarbeiders', 0.7897393703460693),
#  ('nieuwkomers', 0.7884465456008911),
#  ('allochtonen', 0.7804376482963562),
#  ('turken', 0.7723241448402405),
#  ('gezinnen', 0.7711586952209473),
#  ('jongeren', 0.7679890990257263),
#  ('arbeiders', 0.7677537202835083),
#  ('burgers', 0.7604449987411499),
#  ('antillianen', 0.7522391080856323),
#  ('boeren', 0.7482244372367859),
#  ('nederlanders', 0.746281087398529),
#  ('afghanen', 0.7462155818939209),
#  ('moslims', 0.744178295135498),
#  ('chinezen', 0.7362000346183777),
#  ('ouderen', 0.7313068509101868),
#  ('marokkanen', 0.7258096933364868),
#  ('koerden', 0.7246610522270203),
#  ('stedelingen', 0.7237918376922607),
# ...

# %%
mvk.wv.most_similar(positive='expat', topn=100)
# Out:
# [('vrijwilligster', 0.7365957498550415),
#  ('schoonmaker', 0.688819169998169),
#  ('schoonmaakster', 0.6805602312088013),
#  ('fabrieksarbeider', 0.6686999201774597),
#  ('landeigenaar', 0.6507455110549927),
#  ('elektricien', 0.6441925168037415),
#  ('vakkenvuller', 0.6434841156005859),
#  ('afwasser', 0.641666829586029),
#  ('uitzendkracht', 0.6357401013374329),
#  ('verpleger', 0.6346139907836914),
#  ('huismoeder', 0.6318783760070801),
#  ('bordenwasser', 0.6308779120445251),
#  ('immigrante', 0.6296582221984863),
#  ('vraagbaak', 0.627761960029602),
#  ('gezinsvervangend', 0.6252558827400208),
#  ('gastarbeider', 0.6246407628059387),
#  ('hulpverleenster', 0.6244996190071106),
#  ('onderwijzeres', 0.6236349940299988),
#  ('vrouwenvereniging', 0.6233549118041992),
#  ('mijnwerker', 0.6224900484085083),
#  ('vrijwilliger', 0.6205817461013794),
#  ('dakloze', 0.6203168630599976),
#  ('berooide', 0.6172361373901367),
#  ('onderneemster', 0.6169238090515137),
# ...

# %%
mvk.wv.most_similar(positive='expats', topn=100)
# Out:
# [('emigranten', 0.7948920726776123),
#  ('vakantiegangers', 0.7940653562545776),
#  ('arbeidsmigranten', 0.7798687219619751),
#  ('gastarbeiders', 0.7782988548278809),
#  ('stedelingen', 0.7752094268798828),
#  ('zakenmensen', 0.7590219974517822),
#  ('huisvrouwen', 0.7496945261955261),
#  ('yuppen', 0.7491028308868408),
#  ('hindoestanen', 0.7484645843505859),
#  ('hoogopgeleiden', 0.7406525611877441),
#  ('arbeiders', 0.7402353882789612),
#  ('tweeverdieners', 0.7319056391716003),
#  ('miljonairs', 0.7317394018173218),
#  ('zakenlui', 0.7214680314064026),
#  ('toeristen', 0.7187875509262085),
#  ('ondernemers', 0.7186005711555481),
#  ('landbouwers', 0.7153303027153015),
#  ('stadsbewoners', 0.7140797972679138),
#  ('daklozen', 0.7113704085350037),
#  ('immigranten', 0.7108237743377686),
#  ('slagers', 0.7065751552581787),
#  ('ghanezen', 0.7054233551025391),
#  ('kenniswerkers', 0.7042328119277954),
#  ('migranten', 0.7038300037384033),
#  ('antillianen', 0.6995803117752075),
# ...

# %% [markdown]
# # 1a. Reference categories
# Selected on the basis of in-groups ('nederlander (s)' and 'wester(s)' as well as the largest west-european migrant groups living in the Netherlands, according to Statistics Netherlands:  https://www.cbs.nl/nl-nl/achtergrond/2016/47/bevolking-naar-migratieachtergrond)

# %%
mvk.wv.most_similar(positive='nederlander', topn=100)
# Out:
# [('atleet', 0.7574188709259033),
#  ('griek', 0.7461904883384705),
#  ('schaatser', 0.7448713779449463),
#  ('belg', 0.7413007020950317),
#  ('renner', 0.7359412312507629),
#  ('duitser', 0.727774441242218),
#  ('voetballer', 0.7256160378456116),
#  ('zwemmer', 0.71893310546875),
#  ('plusser', 0.7138285636901855),
#  ('sporter', 0.7130436301231384),
#  ('buitenlander', 0.7090916633605957),
#  ('deelnemer', 0.7075048685073853),
#  ('sprinter', 0.6919375658035278),
#  ('surinamer', 0.6917366981506348),
#  ('rotterdammer', 0.6904734969139099),
#  ('speelster', 0.6864358186721802),
#  ('brabander', 0.6862318515777588),
#  ('marokkaan', 0.6812890768051147),
#  ('hagenaar', 0.680968165397644),
#  ('debutant', 0.6791883707046509),
#  ('europeaan', 0.672764003276825),
#  ('amerikaan', 0.662225604057312),
#  ('klimmer', 0.6617739200592041),
#  ('roeier', 0.6602151393890381),
#  ('fransman', 0.6592469215393066),
#  ('tennisser', 0.6586965322494507),
#  ('stayer', 0.6581798791885376),
# ...

# %%
mvk.wv.most_similar(positive='nederlanders', topn=100)
# Out:
# [('buitenlanders', 0.816046953201294),
#  ('turken', 0.7981606721878052),
#  ('vlamingen', 0.7893341779708862),
#  ('amsterdammers', 0.7819807529449463),
#  ('chinezen', 0.773510217666626),
#  ('mensen', 0.7633165121078491),
#  ('duitsers', 0.7542788982391357),
#  ('belgen', 0.7541785836219788),
#  ('zimbabwanen', 0.7515034675598145),
#  ('afghanen', 0.7504484057426453),
#  ('migranten', 0.746281087398529),
#  ('marokkanen', 0.7415497303009033),
#  ('italianen', 0.7347461581230164),
#  ('fransen', 0.7347374558448792),
#  ('japanners', 0.7331734895706177),
#  ('argentijnen', 0.7310613989830017),
#  ('mexicanen', 0.7304278612136841),
#  ('kenianen', 0.7299740314483643),
#  ('amerikanen', 0.7256602048873901),
#  ('jongeren', 0.7237061262130737),
#  ('grieken', 0.7210502624511719),
#  ('cubanen', 0.719990074634552),
#  ('groningers', 0.7199661731719971),
#  ('huishoudens', 0.7198673486709595),
#  ('vrouwen', 0.7156389355659485),
#  ('nieuwkomers', 0.7140512466430664),
# ...

# %%
mvk.wv.most_similar(positive='belg', topn=100)
# Out:
# [('zweed', 0.9101267457008362),
#  ('duitser', 0.9017184972763062),
#  ('zwitser', 0.8833453059196472),
#  ('fransman', 0.8782937526702881),
#  ('oostenrijker', 0.8746300935745239),
#  ('spanjaard', 0.8679693341255188),
#  ('routinier', 0.861805260181427),
#  ('italiaan', 0.8587766289710999),
#  ('griek', 0.8553340435028076),
#  ('hongaar', 0.8530579805374146),
#  ('sprinter', 0.8461591601371765),
#  ('brabander', 0.8416000008583069),
#  ('tsjech', 0.8374985456466675),
#  ('debutant', 0.8373233079910278),
#  ('keniaan', 0.8368849754333496),
#  ('argentijn', 0.8320310711860657),
#  ('stayer', 0.822968065738678),
#  ('braziliaan', 0.8192737102508545),
#  ('roemeen', 0.8192557096481323),
#  ('hagenaar', 0.8121448159217834),
#  ('engelsman', 0.8104276657104492),
#  ('noor', 0.8096591234207153),
#  ('japanner', 0.8094118237495422),
#  ('wielrenner', 0.8074439167976379),
#  ('australier', 0.8064825534820557),
#  ('deen', 0.8039981722831726),
#  ('knegt', 0.8019517660140991),
# ...

# %%
mvk.wv.most_similar(positive='belgen', topn=100)
# Out:
# [('italianen', 0.938775897026062),
#  ('denen', 0.9132923483848572),
#  ('spanjaarden', 0.9103918671607971),
#  ('engelsen', 0.8997376561164856),
#  ('noren', 0.884242594242096),
#  ('fransen', 0.8812412023544312),
#  ('oostenrijkers', 0.8783866167068481),
#  ('ieren', 0.8781492114067078),
#  ('duitsers', 0.8755412101745605),
#  ('brazilianen', 0.8588617444038391),
#  ('finnen', 0.8546353578567505),
#  ('vlamingen', 0.846425473690033),
#  ('argentijnen', 0.8399459719657898),
#  ('tsjechen', 0.8342756032943726),
#  ('grieken', 0.8302593231201172),
#  ('britten', 0.8292712569236755),
#  ('hongaren', 0.8277270197868347),
#  ('portugezen', 0.8227130770683289),
#  ('limburgers', 0.8188188076019287),
#  ('japanners', 0.8171334862709045),
#  ('groningers', 0.8114026784896851),
#  ('roemenen', 0.8048675060272217),
#  ('canadezen', 0.8048087358474731),
#  ('friezen', 0.8046618700027466),
#  ('russen', 0.7995314598083496),
#  ('brabanders', 0.7956469655036926),
# ...

# %%
mvk.wv.most_similar(positive='duitser', topn=100)
# Out:
# [('fransman', 0.9059377908706665),
#  ('belg', 0.9017183184623718),
#  ('zwitser', 0.9010016322135925),
#  ('oostenrijker', 0.8977428078651428),
#  ('zweed', 0.8947378396987915),
#  ('italiaan', 0.8630784749984741),
#  ('griek', 0.8610400557518005),
#  ('spanjaard', 0.8601635694503784),
#  ('engelsman', 0.8543806672096252),
#  ('keniaan', 0.8488523960113525),
#  ('tsjech', 0.8426411151885986),
#  ('hongaar', 0.8424761295318604),
#  ('argentijn', 0.84096360206604),
#  ('japanner', 0.8400906324386597),
#  ('brit', 0.8399156332015991),
#  ('noor', 0.8395391702651978),
#  ('kroaat', 0.8309232592582703),
#  ('roemeen', 0.8308284282684326),
#  ('amerikaan', 0.8292909264564514),
#  ('debutant', 0.818423330783844),
#  ('braziliaan', 0.8160112500190735),
#  ('australier', 0.8134177923202515),
#  ('sprinter', 0.8097984194755554),
#  ('colombiaan', 0.8070215582847595),
#  ('mexicaan', 0.7998749017715454),
#  ('stayer', 0.7985374927520752),
#  ('brabander', 0.7901350259780884),
# ...

# %%
mvk.wv.most_similar(positive='duitsers', topn=100)
# Out:
# [('fransen', 0.924987256526947),
#  ('italianen', 0.9170119166374207),
#  ('russen', 0.9037220478057861),
#  ('spanjaarden', 0.8929558396339417),
#  ('engelsen', 0.8892982006072998),
#  ('belgen', 0.8755412101745605),
#  ('ieren', 0.8752902150154114),
#  ('grieken', 0.8695923686027527),
#  ('britten', 0.865845799446106),
#  ('denen', 0.851804792881012),
#  ('japanners', 0.8395849466323853),
#  ('oostenrijkers', 0.8280044794082642),
#  ('portugezen', 0.8251227140426636),
#  ('amerikanen', 0.8219316005706787),
#  ('europeanen', 0.8215059041976929),
#  ('chinezen', 0.8215019702911377),
#  ('argentijnen', 0.8191336393356323),
#  ('hongaren', 0.8029571771621704),
#  ('brazilianen', 0.8019500970840454),
#  ('noren', 0.7998391389846802),
#  ('finnen', 0.7961322665214539),
#  ('turken', 0.7940875887870789),
#  ('hollanders', 0.78939288854599),
#  ('aziaten', 0.7828853726387024),
#  ('vlamingen', 0.7805923223495483),
#  ('tsjechen', 0.774106502532959),
#  ('roemenen', 0.768027663230896),
# ...

# %%
mvk.wv.most_similar(positive='westers', topn=100)
# Out:
# [('religieus', 0.7651864290237427),
#  ('autoritair', 0.7618909478187561),
#  ('koloniaal', 0.7553793787956238),
#  ('islamitisch', 0.7537365555763245),
#  ('kapitalistisch', 0.7528347373008728),
#  ('seculier', 0.7515732049942017),
#  ('socialistisch', 0.7283494472503662),
#  ('communistisch', 0.7106472253799438),
#  ('nationalistisch', 0.7098008990287781),
#  ('democratisch', 0.7035983800888062),
#  ('progressief', 0.7011014223098755),
#  ('amerikaans', 0.6957775354385376),
#  ('spiritueel', 0.6906335353851318),
#  ('afrikaans', 0.6861809492111206),
#  ('totalitair', 0.6846894025802612),
#  ('ideologisch', 0.6833287477493286),
#  ('russisch', 0.6832610368728638),
#  ('conservatief', 0.6788432598114014),
#  ('aziatisch', 0.6786333322525024),
#  ('intellectueel', 0.6770890951156616),
#  ('buitenlands', 0.6749204993247986),
#  ('gemeenschappelijk', 0.6746754050254822),
#  ('welvarend', 0.6734956502914429),
#  ('angelsaksisch', 0.6719211339950562),
# ...

# %%
mvk.wv.most_similar(positive='christen', topn=100)
# Out:
# [('liberaal', 0.8452836275100708),
#  ('liberale', 0.7518824338912964),
#  ('fdp', 0.7278494834899902),
#  ('socialisten', 0.7174944877624512),
#  ('populisten', 0.7084444165229797),
#  ('vrijzinnig', 0.7059869766235352),
#  ('liberalen', 0.7007332444190979),
#  ('volkspartij', 0.6967215538024902),
#  ('groenen', 0.6941962242126465),
#  ('vld', 0.6904054880142212),
#  ('conservatieven', 0.6875244379043579),
#  ('regeringspartij', 0.6863551139831543),
#  ('conservatief', 0.6830260753631592),
#  ('syriza', 0.681820273399353),
#  ('regerende', 0.6779884099960327),
#  ('progressieve', 0.6752009391784668),
#  ('evp', 0.6678812503814697),
#  ('coalitiepartner', 0.667655348777771),
#  ('conservatieve', 0.6632829904556274),
#  ('akp', 0.6629595160484314),
#  ('senator', 0.662517786026001),
#  ('spd', 0.6624523997306824),
#  ('ukip', 0.6623325943946838),
#  ('socialistische', 0.6616024971008301),
#  ('presidentskandidaat', 0.6565813422203064),
#  ('newt', 0.6547677516937256),
# ...

# %%
mvk.wv.most_similar(positive='christenen', topn=100)
# Out:
# [('arabieren', 0.9224785566329956),
#  ('moslims', 0.884035050868988),
#  ('islamieten', 0.8838126063346863),
#  ('joden', 0.8830298185348511),
#  ('hindoes', 0.8773370385169983),
#  ('katholieken', 0.8681192398071289),
#  ('boeddhisten', 0.8621296882629395),
#  ('protestanten', 0.8570454716682434),
#  ('koerden', 0.8431959748268127),
#  ('ongelovigen', 0.8361364006996155),
#  ('soennieten', 0.8316022157669067),
#  ('fundamentalisten', 0.8289972543716431),
#  ('gelovigen', 0.8281290531158447),
#  ('kroaten', 0.8205994367599487),
#  ('zwarten', 0.8154990673065186),
#  ('turken', 0.8102948069572449),
#  ('islamisten', 0.7995995283126831),
#  ('albanezen', 0.7993653416633606),
#  ('zionisten', 0.7981269955635071),
#  ('sjiieten', 0.7906175851821899),
#  ('tibetanen', 0.7872366309165955),
#  ('geestelijken', 0.7832127809524536),
#  ('extremisten', 0.7825382947921753),
#  ('egyptenaren', 0.7819055318832397),
#  ('kolonisten', 0.7754589319229126),
#  ('westerlingen', 0.774699866771698),
# ...
