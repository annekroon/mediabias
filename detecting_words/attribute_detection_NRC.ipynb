# %% [markdown]
# # Detecting attributes (e.g., stereotypes) on the basis on np data
# ## Data trained on time period: 2000 - 2016

# %%
import gensim

# %% [markdown]
# # Newspaper: Volkskrant

# %%
mnrc = gensim.models.Word2Vec.load('/Users/admin/Google Drive/2017_MigrantWorkers/data/trained_models/trained_2000_2016/nrc')

# %% [markdown]
# ## 1a. Target categories:
# ### Bevolkingsgroepen
# https://www.cbs.nl/nl-nl/achtergrond/2016/47/bevolking-naar-migratieachtergrond

# %%
mnrc.wv.most_similar(positive='marokkaan', topn=100)
# Out:
# [('turk', 0.8976926803588867),
#  ('surinamer', 0.8045576810836792),
#  ('jood', 0.7881278991699219),
#  ('arabier', 0.7698254585266113),
#  ('buitenlander', 0.7602400183677673),
#  ('politieagent', 0.7558076977729797),
#  ('taxichauffeur', 0.7528698444366455),
#  ('afghaan', 0.7511872053146362),
#  ('griek', 0.7403318285942078),
#  ('egyptenaar', 0.7368021607398987),
#  ('antilliaan', 0.7319457530975342),
#  ('vrachtwagenchauffeur', 0.7295503616333008),
#  ('pakistaan', 0.7275641560554504),
#  ('politieman', 0.719733476638794),
#  ('loodgieter', 0.7181145548820496),
#  ('migrant', 0.7173547744750977),
#  ('priester', 0.7116527557373047),
#  ('rotterdammer', 0.7113990783691406),
#  ('bouwvakker', 0.7079558372497559),
#  ('pedofiel', 0.7066609859466553),
#  ('immigrant', 0.7037464380264282),
#  ('onderwijzer', 0.7024883031845093),
#  ('tiener', 0.7013652324676514),
#  ('moslim', 0.6993880271911621),
#  ('israelier', 0.6973425149917603),
#  ('klootzak', 0.696412980556488),
# ...

# %%
mnrc.wv.most_similar(positive='marokkanen', topn=100)
# Out:
# [('surinamers', 0.9027153253555298),
#  ('antillianen', 0.8903188705444336),
#  ('turken', 0.8762601613998413),
#  ('allochtonen', 0.8207099437713623),
#  ('autochtonen', 0.7844358682632446),
#  ('nederlanders', 0.7739877700805664),
#  ('molukkers', 0.7668012976646423),
#  ('moslims', 0.7659000158309937),
#  ('buitenlanders', 0.7610697746276855),
#  ('arubanen', 0.7493425607681274),
#  ('vlamingen', 0.7304577827453613),
#  ('jongeren', 0.7280093431472778),
#  ('autochtone', 0.7173675298690796),
#  ('immigranten', 0.7170026302337646),
#  ('zwarten', 0.7139827013015747),
#  ('moslimjongeren', 0.7119799256324768),
#  ('imams', 0.7080187797546387),
#  ('katholieken', 0.7024574279785156),
#  ('christenen', 0.70203697681427),
#  ('blanken', 0.701472282409668),
#  ('migranten', 0.6976337432861328),
#  ('somaliers', 0.6912145614624023),
#  ('hongaren', 0.6731331944465637),
#  ('roemenen', 0.672989547252655),
#  ('allochtone', 0.6723604202270508),
#  ('rotterdammers', 0.6710935831069946),
# ...

# %%
mnrc.wv.most_similar(positive='turk', topn=100)
# Out:
# [('marokkaan', 0.8976926803588867),
#  ('jood', 0.8150227069854736),
#  ('arabier', 0.8064546585083008),
#  ('surinamer', 0.7998472452163696),
#  ('buitenlander', 0.7633490562438965),
#  ('griek', 0.7538876533508301),
#  ('afghaan', 0.7429823875427246),
#  ('bouwvakker', 0.7429335117340088),
#  ('taxichauffeur', 0.7397398948669434),
#  ('pakistaan', 0.7360422611236572),
#  ('loodgieter', 0.7336952090263367),
#  ('immigrant', 0.7288028001785278),
#  ('fundamentalist', 0.7138779163360596),
#  ('klootzak', 0.7106606960296631),
#  ('politieagent', 0.7070666551589966),
#  ('vrachtwagenchauffeur', 0.7037385702133179),
#  ('communist', 0.7018898725509644),
#  ('politieman', 0.701805055141449),
#  ('monnik', 0.7011908292770386),
#  ('priester', 0.7009326219558716),
#  ('migrant', 0.6999696493148804),
#  ('arbeider', 0.6995756030082703),
#  ('rebel', 0.6995446681976318),
#  ('moslim', 0.6960501670837402),
#  ('aristocraat', 0.6951510310173035),
#  ('antilliaan', 0.6948691606521606),
# ...

# %%
mnrc.wv.most_similar(positive='turken', topn=100)
# Out:
# [('marokkanen', 0.8762601017951965),
#  ('hongaren', 0.8646659255027771),
#  ('moslims', 0.83637934923172),
#  ('nederlanders', 0.8343538045883179),
#  ('buitenlanders', 0.8293435573577881),
#  ('surinamers', 0.8280688524246216),
#  ('christenen', 0.8271116614341736),
#  ('arabieren', 0.8256015181541443),
#  ('koerden', 0.8221546411514282),
#  ('joden', 0.805737316608429),
#  ('duitsers', 0.8054801225662231),
#  ('molukkers', 0.7992727756500244),
#  ('katholieken', 0.7941892147064209),
#  ('antillianen', 0.7915912866592407),
#  ('vlamingen', 0.7887944579124451),
#  ('fransen', 0.7871792316436768),
#  ('russen', 0.7811587452888489),
#  ('spanjaarden', 0.7786157131195068),
#  ('immigranten', 0.7785422205924988),
#  ('egyptenaren', 0.7783244848251343),
#  ('zwarten', 0.7782151699066162),
#  ('italianen', 0.7749898433685303),
#  ('westerlingen', 0.7711053490638733),
#  ('roemenen', 0.769891619682312),
#  ('japanners', 0.7688589096069336),
#  ('blanken', 0.7676988840103149),
# ...

# %%
mnrc.wv.most_similar(positive='surinamer', topn=100)
# Out:
# [('antilliaan', 0.8254849910736084),
#  ('marokkaan', 0.8045575618743896),
#  ('turk', 0.7998472452163696),
#  ('bouwvakker', 0.7984693050384521),
#  ('alcoholist', 0.7968815565109253),
#  ('rotterdammer', 0.7858710289001465),
#  ('transseksueel', 0.7856208086013794),
#  ('ghanees', 0.7826657295227051),
#  ('vechter', 0.7794573903083801),
#  ('middenstander', 0.7776106595993042),
#  ('griek', 0.771801233291626),
#  ('psychopaat', 0.76816326379776),
#  ('meeloper', 0.7668887972831726),
#  ('hongaar', 0.7642214894294739),
#  ('travestiet', 0.7631440758705139),
#  ('hagenaar', 0.7594107389450073),
#  ('vechtjas', 0.7592732906341553),
#  ('neurochirurg', 0.7583589553833008),
#  ('ijshockeyer', 0.7550694346427917),
#  ('bokser', 0.7547099590301514),
#  ('londenaar', 0.7540860772132874),
#  ('moslimvrouw', 0.7538279294967651),
#  ('barkeeper', 0.7528635859489441),
#  ('nigeriaan', 0.7528235912322998),
#  ('lesbienne', 0.7519095540046692),
#  ('indier', 0.7511700391769409),
# ...

# %%
mnrc.wv.most_similar(positive='surinamers', topn=100)
# Out:
# [('antillianen', 0.9127695560455322),
#  ('marokkanen', 0.9027152061462402),
#  ('turken', 0.8280689120292664),
#  ('molukkers', 0.8196407556533813),
#  ('arubanen', 0.7933158874511719),
#  ('autochtonen', 0.7806533575057983),
#  ('hindoestanen', 0.7700880169868469),
#  ('somaliers', 0.7648994326591492),
#  ('allochtonen', 0.7537382245063782),
#  ('indiers', 0.7535099983215332),
#  ('vlamingen', 0.7418846487998962),
#  ('aziaten', 0.7377874851226807),
#  ('nederlanders', 0.7363702058792114),
#  ('autochtone', 0.7328953742980957),
#  ('zwarten', 0.7319704294204712),
#  ('dertigers', 0.7251926064491272),
#  ('expats', 0.7246350049972534),
#  ('blanken', 0.7238621711730957),
#  ('hoogopgeleiden', 0.7236794233322144),
#  ('hongaren', 0.7227963209152222),
#  ('amsterdammers', 0.7118865251541138),
#  ('rotterdammers', 0.7023147940635681),
#  ('nigerianen', 0.7022910118103027),
#  ('buitenlanders', 0.7019007205963135),
#  ('gastarbeiders', 0.6923508644104004),
# ...

# %%
mnrc.wv.most_similar(positive='antilliaan', topn=100)
# Out:
# [('surinamer', 0.8254849910736084),
#  ('kickbokser', 0.8193899989128113),
#  ('politieagente', 0.8173839449882507),
#  ('drugsdealer', 0.8130404949188232),
#  ('autodief', 0.8063444495201111),
#  ('ghanees', 0.800844132900238),
#  ('londenaar', 0.7984988689422607),
#  ('automobiliste', 0.7983808517456055),
#  ('uroloog', 0.7983375191688538),
#  ('restauranthouder', 0.7896345257759094),
#  ('verzekeringsagent', 0.7885181903839111),
#  ('nigeriaan', 0.787911057472229),
#  ('hoofdagent', 0.7848997712135315),
#  ('politievrouw', 0.7845600843429565),
#  ('stacy', 0.7832821607589722),
#  ('transseksueel', 0.7828367948532104),
#  ('syrier', 0.7820676565170288),
#  ('vrachtwagenchauffeur', 0.7808516621589661),
#  ('algerijn', 0.7802979350090027),
#  ('haarlemmer', 0.7796099185943604),
#  ('motoragent', 0.7794756293296814),
#  ('barkeeper', 0.7791928052902222),
#  ('farida', 0.7780326008796692),
#  ('medestudent', 0.7778935432434082),
#  ('eindhovenaar', 0.777802586555481),
# ...

# %%
mnrc.wv.most_similar(positive='antillianen', topn=100)
# Out:
# [('surinamers', 0.9127695560455322),
#  ('marokkanen', 0.8903188109397888),
#  ('autochtonen', 0.8266295194625854),
#  ('arubanen', 0.8248068690299988),
#  ('allochtonen', 0.8068958520889282),
#  ('autochtone', 0.797980785369873),
#  ('turken', 0.7915912866592407),
#  ('molukkers', 0.7878502607345581),
#  ('allochtone', 0.7507259845733643),
#  ('somaliers', 0.7479757070541382),
#  ('hoogopgeleiden', 0.7382782697677612),
#  ('migranten', 0.7259334921836853),
#  ('hoogopgeleide', 0.7241803407669067),
#  ('hindoestanen', 0.7241049408912659),
#  ('hangjongeren', 0.7215484380722046),
#  ('buitenlanders', 0.7182841300964355),
#  ('immigranten', 0.7114118337631226),
#  ('jongeren', 0.7099536657333374),
#  ('laagopgeleide', 0.7077744007110596),
#  ('gezinnen', 0.6996279358863831),
#  ('indiers', 0.6976799964904785),
#  ('expats', 0.6965458393096924),
#  ('zwarten', 0.696129322052002),
#  ('achterstandsleerlingen', 0.6947311758995056),
#  ('nederlanders', 0.6930708885192871),
# ...

# %%
mnrc.wv.most_similar(positive='irakees', topn=100)
# Out:
# [('palestijn', 0.8773781061172485),
#  ('politieman', 0.8213220834732056),
#  ('afghaan', 0.8167983293533325),
#  ('politieagent', 0.808329164981842),
#  ('egyptenaar', 0.804232120513916),
#  ('gedetineerde', 0.7977362871170044),
#  ('demonstrant', 0.7976027727127075),
#  ('gijzelnemer', 0.789404571056366),
#  ('algerijn', 0.7889426946640015),
#  ('pakistaan', 0.7871276140213013),
#  ('zelfmoordterrorist', 0.7823623418807983),
#  ('overvaller', 0.7801526784896851),
#  ('israelier', 0.7772170901298523),
#  ('betoger', 0.7740340828895569),
#  ('korporaal', 0.7708125710487366),
#  ('servier', 0.7653521299362183),
#  ('koerd', 0.7619810104370117),
#  ('sluipschutter', 0.761615514755249),
#  ('terrorist', 0.7612167596817017),
#  ('syrier', 0.7574174404144287),
#  ('zelfmoordenaar', 0.7573127150535583),
#  ('verkrachter', 0.7531012296676636),
#  ('arrestant', 0.7525112628936768),
#  ('schutter', 0.7496538758277893),
#  ('gijzelaar', 0.7472978830337524),
# ...

# %%
mnrc.wv.most_similar(positive='irakezen', topn=100)
# Out:
# [('afghanen', 0.9441332817077637),
#  ('israeliers', 0.8801451921463013),
#  ('pakistanen', 0.8615788817405701),
#  ('koerden', 0.8580454587936401),
#  ('palestijnen', 0.8456411957740784),
#  ('egyptenaren', 0.8448083400726318),
#  ('libanezen', 0.8352881669998169),
#  ('amerikanen', 0.8311394453048706),
#  ('kenianen', 0.8307722806930542),
#  ('serviers', 0.8294861316680908),
#  ('strijders', 0.8268200159072876),
#  ('tsjetsjenen', 0.8264383673667908),
#  ('arabieren', 0.8137709498405457),
#  ('albanezen', 0.8103578090667725),
#  ('dorpelingen', 0.8075652122497559),
#  ('gijzelaars', 0.8063466548919678),
#  ('rebellen', 0.805906355381012),
#  ('iraniers', 0.8053694367408752),
#  ('cubanen', 0.8050891160964966),
#  ('tibetanen', 0.8041776418685913),
#  ('militairen', 0.8019424676895142),
#  ('soldaten', 0.7993664145469666),
#  ('opstandelingen', 0.799116849899292),
#  ('russen', 0.7988176345825195),
#  ('nigerianen', 0.7889626026153564),
#  ('sunnieten', 0.7866311073303223),
# ...

# %%
mnrc.wv.most_similar(positive='afghaan', topn=100)
# Out:
# [('pakistaan', 0.826935887336731),
#  ('israelier', 0.8234284520149231),
#  ('irakees', 0.8167983293533325),
#  ('palestijn', 0.8125176429748535),
#  ('politieagent', 0.8115022778511047),
#  ('arabier', 0.8074549436569214),
#  ('politieman', 0.8037799596786499),
#  ('egyptenaar', 0.7995939254760742),
#  ('hulpverlener', 0.7857656478881836),
#  ('syrier', 0.7779731750488281),
#  ('jihadist', 0.7754814624786377),
#  ('asielzoeker', 0.7750731110572815),
#  ('demonstrant', 0.7739505767822266),
#  ('koerd', 0.7715266942977905),
#  ('legerofficier', 0.7703534364700317),
#  ('korporaal', 0.7669616937637329),
#  ('terrorist', 0.7630356550216675),
#  ('algerijn', 0.7602041959762573),
#  ('gedetineerde', 0.7598518133163452),
#  ('migrant', 0.7550894021987915),
#  ('taxichauffeur', 0.7529460191726685),
#  ('marokkaan', 0.7511872053146362),
#  ('schutter', 0.7504174113273621),
#  ('drugsdealer', 0.7502127885818481),
#  ('misdadiger', 0.7498989105224609),
#  ('kolonist', 0.7496029734611511),
# ...

# %%
mnrc.wv.most_similar(positive='afghanen', topn=100)
# Out:
# [('irakezen', 0.944133460521698),
#  ('pakistanen', 0.895315408706665),
#  ('libanezen', 0.8880311250686646),
#  ('kenianen', 0.8424601554870605),
#  ('tsjetsjenen', 0.8422495126724243),
#  ('nigerianen', 0.8383475542068481),
#  ('koerden', 0.8381728529930115),
#  ('egyptenaren', 0.8375815153121948),
#  ('israeliers', 0.8355075716972351),
#  ('iraniers', 0.8301334977149963),
#  ('tibetanen', 0.81776362657547),
#  ('cubanen', 0.8177191019058228),
#  ('ontheemden', 0.816512942314148),
#  ('buitenlanders', 0.8137409090995789),
#  ('dorpelingen', 0.807979166507721),
#  ('arabieren', 0.8052763342857361),
#  ('strijders', 0.7986602783203125),
#  ('zimbabweanen', 0.7976210117340088),
#  ('amerikanen', 0.796633780002594),
#  ('chinezen', 0.7943685054779053),
#  ('mexicanen', 0.7908949851989746),
#  ('congolezen', 0.7882739305496216),
#  ('venezolanen', 0.7859748601913452),
#  ('japanners', 0.7841998338699341),
#  ('jihadisten', 0.7837315797805786),
#  ('gijzelaars', 0.7836935520172119),
# ...

# %%
mnrc.wv.most_similar(positive='syrier', topn=100)
# Out:
# [('pakistaan', 0.8490091562271118),
#  ('algerijn', 0.8325221538543701),
#  ('mensenrechtenadvocaat', 0.8235284090042114),
#  ('jemeniet', 0.8226816058158875),
#  ('tarek', 0.8109862804412842),
#  ('tsjetsjeen', 0.8102844953536987),
#  ('sayed', 0.8097677230834961),
#  ('yousef', 0.8096535205841064),
#  ('nidal', 0.809454619884491),
#  ('verzetsstrijder', 0.8079895973205566),
#  ('saoedier', 0.8042802214622498),
#  ('yasin', 0.7993467450141907),
#  ('kickbokser', 0.796869158744812),
#  ('deserteur', 0.7957949638366699),
#  ('egyptenaar', 0.7957828044891357),
#  ('dienstweigeraar', 0.7949684262275696),
#  ('sherif', 0.7946754693984985),
#  ('massamoordenaar', 0.7931718826293945),
#  ('drugshandelaar', 0.7911390066146851),
#  ('alaa', 0.790477991104126),
#  ('stamleider', 0.7904475927352905),
#  ('zaid', 0.7894213199615479),
#  ('tadzjiek', 0.7858533263206482),
#  ('terreurverdachte', 0.7858030796051025),
#  ('nizar', 0.7827775478363037),
#  ('radiojournalist', 0.7826083302497864),
# ...

# %%
mnrc.wv.most_similar(positive='syriers', topn=100)
# Out:
# [('malinezen', 0.853204607963562),
#  ('iraniers', 0.81580650806427),
#  ('libanezen', 0.811887800693512),
#  ('chilenen', 0.8115490674972534),
#  ('saoediers', 0.8051790595054626),
#  ('liberianen', 0.8031944036483765),
#  ('ivorianen', 0.7978843450546265),
#  ('oegandezen', 0.7955237627029419),
#  ('jemenieten', 0.7868102788925171),
#  ('ethiopiers', 0.7822011709213257),
#  ('tsjetsjenen', 0.7739097476005554),
#  ('nigerianen', 0.7678055763244629),
#  ('colombianen', 0.7668524384498596),
#  ('atjehers', 0.7650710344314575),
#  ('algerijnen', 0.7634724974632263),
#  ('peruanen', 0.7625160217285156),
#  ('congolezen', 0.7596369385719299),
#  ('druzen', 0.7579616904258728),
#  ('oppositieaanhangers', 0.7574630975723267),
#  ('indonesiers', 0.7559483051300049),
#  ('pakistanen', 0.7535959482192993),
#  ('rwandezen', 0.7480671405792236),
#  ('tibetanen', 0.7479238510131836),
#  ('pakistani', 0.7470600605010986),
#  ('verzetsmensen', 0.7451258897781372),
# ...

# %%
mnrc.wv.most_similar(positive='somalier', topn=100)
# Out:
# [('ambulancebroeder', 0.8102883100509644),
#  ('mongool', 0.7969034910202026),
#  ('tasmanie', 0.7809252142906189),
#  ('stoffeerder', 0.7804745435714722),
#  ('roodborstje', 0.7787269353866577),
#  ('parkeerwachter', 0.7758569121360779),
#  ('bruiloftsfeest', 0.774996280670166),
#  ('kinderpartijtje', 0.7748994827270508),
#  ('selman', 0.7709392309188843),
#  ('zwartrijder', 0.7699189186096191),
#  ('friettent', 0.7693703174591064),
#  ('toverbal', 0.7692122459411621),
#  ('kitesurfer', 0.7691525220870972),
#  ('anca', 0.7679352164268494),
#  ('productiemedewerker', 0.7676476240158081),
#  ('kudelstaart', 0.767102837562561),
#  ('kolibrie', 0.7659931182861328),
#  ('raketbeschieting', 0.7658993601799011),
#  ('tangetje', 0.7657114267349243),
#  ('goj', 0.7655788660049438),
#  ('reuzenschildpad', 0.7652122974395752),
#  ('stoelpoot', 0.7650887966156006),
#  ('marmot', 0.7646192312240601),
#  ('tsjetsjeen', 0.76458340883255),
#  ('soloseks', 0.7638633251190186),
# ...

# %%
mnrc.wv.most_similar(positive='somaliers', topn=100)
# Out:
# [('oeigoeren', 0.848091721534729),
#  ('indiers', 0.8431713581085205),
#  ('molukkers', 0.8265773057937622),
#  ('libanezen', 0.8253375291824341),
#  ('iraniers', 0.8230411410331726),
#  ('tibetanen', 0.8230026960372925),
#  ('landarbeiders', 0.8216902017593384),
#  ('nigerianen', 0.8096531629562378),
#  ('pakistanen', 0.7975904941558838),
#  ('jemenieten', 0.7919104099273682),
#  ('ghanezen', 0.7836095094680786),
#  ('indonesiers', 0.7797688841819763),
#  ('ivorianen', 0.7726101875305176),
#  ('algerijnen', 0.7721755504608154),
#  ('afghanen', 0.7679011821746826),
#  ('nomaden', 0.766587495803833),
#  ('congolezen', 0.765903115272522),
#  ('weduwen', 0.7653001546859741),
#  ('surinamers', 0.7648994326591492),
#  ('oezbeken', 0.7602370977401733),
#  ('zuiderlingen', 0.7577798366546631),
#  ('dorpsbewoners', 0.7561094760894775),
#  ('hindoestanen', 0.7549647092819214),
#  ('egyptenaren', 0.7546197175979614),
#  ('venezolanen', 0.753917932510376),
#  ('zwarten', 0.7501150369644165),
# ...

# %%
mnrc.wv.most_similar(positive='pool', topn=100)
# Out:
# [('japanner', 0.8620107173919678),
#  ('engelsman', 0.8425124287605286),
#  ('debutant', 0.8026087880134583),
#  ('keniaan', 0.7978399991989136),
#  ('roemeen', 0.7963098287582397),
#  ('hongaar', 0.7911373972892761),
#  ('pitcher', 0.7903420925140381),
#  ('brit', 0.7867895364761353),
#  ('tsjech', 0.7783514857292175),
#  ('zweed', 0.7772809267044067),
#  ('griek', 0.7772339582443237),
#  ('zeiler', 0.776695966720581),
#  ('colombiaan', 0.7759954929351807),
#  ('honkballer', 0.7758288383483887),
#  ('klimmer', 0.7651411890983582),
#  ('evans', 0.7639893293380737),
#  ('amerikaan', 0.7630627751350403),
#  ('duitser', 0.7619214057922363),
#  ('belg', 0.7616068720817566),
#  ('skier', 0.7609388828277588),
#  ('zwitser', 0.7595537900924683),
#  ('noor', 0.7575734257698059),
#  ('basketballer', 0.7556829452514648),
#  ('cubaan', 0.754314124584198),
#  ('australier', 0.7504402995109558),
#  ('oostenrijker', 0.7502565383911133),
#  ('werper', 0.7495162487030029),
# ...

# %%
mnrc.wv.most_similar(positive='polen', topn=100)
# Out:
# [('hongarije', 0.8991031050682068),
#  ('duitsland', 0.8734533786773682),
#  ('bulgarije', 0.85575932264328),
#  ('spanje', 0.8552737236022949),
#  ('turkije', 0.846946120262146),
#  ('frankrijk', 0.8454064130783081),
#  ('roemeni', 0.8453662395477295),
#  ('oostenrijk', 0.8380672931671143),
#  ('slowakije', 0.8213403224945068),
#  ('roemenie', 0.82053542137146),
#  ('itali', 0.8198051452636719),
#  ('litouwen', 0.8098522424697876),
#  ('italie', 0.8047393560409546),
#  ('griekenland', 0.80404132604599),
#  ('rusland', 0.8035396337509155),
#  ('portugal', 0.7946844100952148),
#  ('estland', 0.7913364171981812),
#  ('denemarken', 0.7874573469161987),
#  ('ijsland', 0.7873441576957703),
#  ('oekraine', 0.7846777439117432),
#  ('tsjechi', 0.7827608585357666),
#  ('zweden', 0.776471734046936),
#  ('noorwegen', 0.7758126258850098),
#  ('letland', 0.7710053324699402),
#  ('finland', 0.7513015270233154),
#  ('tsjechie', 0.7495903968811035),
#  ('marokko', 0.7495150566101074),
# ...

# %% [markdown]
# ## 1b. Target categories:
# ### Immigranten groups // labels.

# %%
mnrc.wv.most_similar(positive='arabier', topn=100)
# Out:
# [('terrorist', 0.8548558950424194),
#  ('jood', 0.8325117826461792),
#  ('afghaan', 0.8074548244476318),
#  ('turk', 0.8064546585083008),
#  ('palestijn', 0.8024384379386902),
#  ('israelier', 0.7848974466323853),
#  ('misdadiger', 0.7737953662872314),
#  ('extremist', 0.7713629603385925),
#  ('marokkaan', 0.7698253393173218),
#  ('strijder', 0.7665091753005981),
#  ('fundamentalist', 0.7636682391166687),
#  ('politieagent', 0.755522608757019),
#  ('moslim', 0.7511754035949707),
#  ('pakistaan', 0.7361283302307129),
#  ('tiran', 0.7347219586372375),
#  ('koerd', 0.7325055599212646),
#  ('politieman', 0.7307997941970825),
#  ('verrader', 0.7301915884017944),
#  ('fascist', 0.7246049642562866),
#  ('moordenaar', 0.7207539081573486),
#  ('racist', 0.7156423330307007),
#  ('martelaar', 0.7149437665939331),
#  ('soldaat', 0.7133466601371765),
#  ('monnik', 0.7108033299446106),
#  ('jihadist', 0.7103838920593262),
#  ('irakees', 0.7099078893661499),
#  ('klootzak', 0.7095350027084351),
# ...

# %%
mnrc.wv.most_similar(positive='arabieren', topn=100)
# Out:
# [('christenen', 0.9014179706573486),
#  ('israeliers', 0.8747663497924805),
#  ('koerden', 0.8651376962661743),
#  ('joden', 0.8463274836540222),
#  ('moslims', 0.8453050255775452),
#  ('westerlingen', 0.8320525288581848),
#  ('turken', 0.8256015181541443),
#  ('egyptenaren', 0.8168992400169373),
#  ('kolonisten', 0.814775824546814),
#  ('irakezen', 0.8137710094451904),
#  ('hindoes', 0.8091452121734619),
#  ('afghanen', 0.8052763342857361),
#  ('sunnieten', 0.8042714595794678),
#  ('libanezen', 0.7976029515266418),
#  ('fundamentalisten', 0.7974156141281128),
#  ('islamieten', 0.7942160367965698),
#  ('palestijnen', 0.7869195342063904),
#  ('zwarten', 0.7810494899749756),
#  ('iraniers', 0.778681755065918),
#  ('tsjetsjenen', 0.7775166034698486),
#  ('kroaten', 0.7768369913101196),
#  ('gelovigen', 0.7762556672096252),
#  ('jihadisten', 0.7761094570159912),
#  ('blanken', 0.7701220512390137),
#  ('russen', 0.7658429145812988),
#  ('indianen', 0.7633180022239685),
# ...

# %%
mnrc.wv.most_similar(positive='moslim', topn=100)
# Out:
# [('jood', 0.8050310015678406),
#  ('gelovige', 0.781962513923645),
#  ('extremist', 0.7687451243400574),
#  ('arabier', 0.7511754035949707),
#  ('fundamentalist', 0.7380673289299011),
#  ('vluchteling', 0.7366513013839722),
#  ('terrorist', 0.7304328680038452),
#  ('ongelovige', 0.7177356481552124),
#  ('seculiere', 0.7076863050460815),
#  ('imam', 0.7058384418487549),
#  ('christenen', 0.7016832828521729),
#  ('marokkaan', 0.6993880271911621),
#  ('turk', 0.6960501074790955),
#  ('palestijn', 0.695052981376648),
#  ('fanatici', 0.6950119137763977),
#  ('moslims', 0.6934664249420166),
#  ('strijder', 0.6925317049026489),
#  ('nationalist', 0.691625714302063),
#  ('martelaar', 0.6899288296699524),
#  ('koerd', 0.6884833574295044),
#  ('jihad', 0.6883494853973389),
#  ('fundamentalisten', 0.6871182918548584),
#  ('allochtoon', 0.6870322227478027),
#  ('verraders', 0.6864514350891113),
#  ('minderheid', 0.6838133335113525),
#  ('orthodox', 0.6836029291152954),
# ...

# %%
mnrc.wv.most_similar(positive='moslims', topn=100)
# Out:
# [('christenen', 0.9013806581497192),
#  ('joden', 0.8582013249397278),
#  ('gelovigen', 0.8563387393951416),
#  ('arabieren', 0.8453050255775452),
#  ('turken', 0.8363794088363647),
#  ('moslimjongeren', 0.834773600101471),
#  ('islamieten', 0.8108539581298828),
#  ('koerden', 0.8101180791854858),
#  ('imams', 0.7960221171379089),
#  ('fundamentalisten', 0.7829625606536865),
#  ('katholieken', 0.7829546928405762),
#  ('buitenlanders', 0.766617476940155),
#  ('marokkanen', 0.7659000158309937),
#  ('homoseksuelen', 0.7607164978981018),
#  ('jihadisten', 0.7596396207809448),
#  ('immigranten', 0.758054792881012),
#  ('westerlingen', 0.7554815411567688),
#  ('sunnieten', 0.7549285888671875),
#  ('israeliers', 0.7473785877227783),
#  ('burgers', 0.7468467950820923),
#  ('palestijnen', 0.7456904053688049),
#  ('hindoes', 0.7425681352615356),
#  ('kolonisten', 0.7424854040145874),
#  ('extremisten', 0.736573338508606),
#  ('irakezen', 0.7354048490524292),
# ...

# %%
mnrc.wv.most_similar(positive='vluchteling', topn=100)
# Out:
# [('asielzoeker', 0.8337665796279907),
#  ('strijder', 0.7651283740997314),
#  ('migrant', 0.7556628584861755),
#  ('jood', 0.7452671527862549),
#  ('immigrant', 0.743683934211731),
#  ('afghaan', 0.7422990798950195),
#  ('jihadist', 0.7375539541244507),
#  ('moslim', 0.7366513013839722),
#  ('hulpverlener', 0.7341736555099487),
#  ('terrorist', 0.7328561544418335),
#  ('gevangene', 0.7305057048797607),
#  ('koerd', 0.7281274795532227),
#  ('palestijn', 0.7274570465087891),
#  ('balling', 0.7159655094146729),
#  ('krijgsgevangene', 0.705108642578125),
#  ('spion', 0.6973670721054077),
#  ('activist', 0.6966750025749207),
#  ('gijzelaar', 0.6910564303398132),
#  ('gedetineerde', 0.6894618272781372),
#  ('priester', 0.6845916509628296),
#  ('politieagent', 0.6784809231758118),
#  ('imam', 0.6750902533531189),
#  ('monnik', 0.6699916124343872),
#  ('politieman', 0.6674844026565552),
#  ('arabier', 0.6665852069854736),
#  ('dissident', 0.664156436920166),
# ...

# %%
mnrc.wv.most_similar(positive='vluchtelingen', topn=100)
# Out:
# [('migranten', 0.8760569095611572),
#  ('asielzoekers', 0.8758165836334229),
#  ('illegalen', 0.8725942373275757),
#  ('ontheemden', 0.8359012603759766),
#  ('immigranten', 0.8037509918212891),
#  ('arbeidsmigranten', 0.7943148016929626),
#  ('vreemdelingen', 0.7864377498626709),
#  ('irakezen', 0.7819293141365051),
#  ('bootvluchtelingen', 0.772832989692688),
#  ('afghanen', 0.7725589275360107),
#  ('buitenlanders', 0.7713606953620911),
#  ('koerden', 0.7434583902359009),
#  ('gevangenen', 0.7278644442558289),
#  ('gedetineerden', 0.7244464755058289),
#  ('gastarbeiders', 0.7240362763404846),
#  ('militairen', 0.7173877954483032),
#  ('jihadisten', 0.7149756550788879),
#  ('moslims', 0.7058759331703186),
#  ('inwoners', 0.7023458480834961),
#  ('burgers', 0.701433002948761),
#  ('blauwhelmen', 0.6991733312606812),
#  ('palestijnen', 0.697554349899292),
#  ('toeristen', 0.6959881782531738),
#  ('albanezen', 0.6935312747955322),
#  ('pelgrims', 0.6904381513595581),
# ...

# %%
mnrc.wv.most_similar(positive='allochtoon', topn=100)
# Out:
# [('autochtoon', 0.864412248134613),
#  ('moslim', 0.6870323419570923),
#  ('analfabeet', 0.6831355094909668),
#  ('autochtone', 0.642570972442627),
#  ('marokkaans', 0.6390705108642578),
#  ('gelovige', 0.637554943561554),
#  ('katholiek', 0.6213499307632446),
#  ('marokkaan', 0.6195493936538696),
#  ('jood', 0.6004611849784851),
#  ('laagopgeleide', 0.5956623554229736),
#  ('migrant', 0.5918803215026855),
#  ('turk', 0.5871450304985046),
#  ('homoseksueel', 0.581710696220398),
#  ('marokkanen', 0.5811368227005005),
#  ('mannelijk', 0.5806940793991089),
#  ('gelovig', 0.5800479650497437),
#  ('protestant', 0.5767048597335815),
#  ('orthodox', 0.5763185024261475),
#  ('allochtone', 0.5746450424194336),
#  ('hoogopgeleid', 0.5720658302307129),
#  ('scheldwoord', 0.5708341598510742),
#  ('hoogopgeleide', 0.5669642686843872),
#  ('protestants', 0.5628200769424438),
#  ('kostwinner', 0.5619871616363525),
#  ('ras', 0.557998538017273),
#  ('allochtonen', 0.5559554696083069),
# ...

# %%
mnrc.wv.most_similar(positive='allochtonen', topn=100)
# Out:
# [('autochtonen', 0.8684471845626831),
#  ('marokkanen', 0.8207099437713623),
#  ('nieuwkomers', 0.8085070252418518),
#  ('ouderen', 0.8069862127304077),
#  ('antillianen', 0.8068958520889282),
#  ('jongeren', 0.8026739954948425),
#  ('hoogopgeleiden', 0.7979291677474976),
#  ('allochtone', 0.787304699420929),
#  ('migranten', 0.7552108764648438),
#  ('surinamers', 0.7537382245063782),
#  ('immigranten', 0.753627598285675),
#  ('turken', 0.7422630190849304),
#  ('gezinnen', 0.7287538051605225),
#  ('kansarmen', 0.7229465246200562),
#  ('moslims', 0.7186786532402039),
#  ('buitenlanders', 0.7096564769744873),
#  ('moslimjongeren', 0.708534836769104),
#  ('nederlanders', 0.7079930305480957),
#  ('achterstandsleerlingen', 0.7075284719467163),
#  ('plussers', 0.7059719562530518),
#  ('minderheden', 0.7049590349197388),
#  ('rokers', 0.7026410102844238),
#  ('autochtone', 0.7019959688186646),
#  ('scholen', 0.6962573528289795),
#  ('vrouwen', 0.69504714012146),
# ...

# %%
mnrc.wv.most_similar(positive='immigrant', topn=100)
# Out:
# [('migrant', 0.827220618724823),
#  ('arbeider', 0.7891939878463745),
#  ('jood', 0.7730429768562317),
#  ('monnik', 0.7666237354278564),
#  ('emigrant', 0.7596951723098755),
#  ('aristocraat', 0.7538012862205505),
#  ('vluchteling', 0.743683934211731),
#  ('asielzoeker', 0.7391846179962158),
#  ('vluchtelinge', 0.7391030192375183),
#  ('spion', 0.7389081716537476),
#  ('missionaris', 0.7367242574691772),
#  ('jihadist', 0.7355486154556274),
#  ('toerist', 0.7336937189102173),
#  ('krijgsgevangene', 0.7333351373672485),
#  ('turk', 0.7288028001785278),
#  ('vrijheidsstrijder', 0.7273261547088623),
#  ('balling', 0.7233214974403381),
#  ('immigrantenzoon', 0.7173781394958496),
#  ('gijzelaar', 0.7146533727645874),
#  ('indiaan', 0.7069149017333984),
#  ('strijder', 0.7065149545669556),
#  ('gangster', 0.7050556540489197),
#  ('tiener', 0.7050517797470093),
#  ('avonturier', 0.7048733234405518),
#  ('marokkaan', 0.7037464380264282),
#  ('soldaat', 0.7031129598617554),
# ...

# %%
mnrc.wv.most_similar(positive='immigranten', topn=100)
# Out:
# [('migranten', 0.94642174243927),
#  ('arbeidsmigranten', 0.8700319528579712),
#  ('gastarbeiders', 0.8187091946601868),
#  ('buitenlanders', 0.8070858716964722),
#  ('vluchtelingen', 0.8037509918212891),
#  ('illegalen', 0.7792669534683228),
#  ('turken', 0.7785422801971436),
#  ('emigranten', 0.7690871357917786),
#  ('arbeiders', 0.7684530019760132),
#  ('vreemdelingen', 0.7597553730010986),
#  ('moslims', 0.758054792881012),
#  ('allochtonen', 0.753627598285675),
#  ('chinezen', 0.7485543489456177),
#  ('gezinnen', 0.7412713766098022),
#  ('asielzoekers', 0.7275069952011108),
#  ('jihadisten', 0.72630774974823),
#  ('expats', 0.7251868844032288),
#  ('nieuwkomers', 0.7243664264678955),
#  ('boeren', 0.7227029204368591),
#  ('joden', 0.7214140892028809),
#  ('marokkanen', 0.7170025706291199),
#  ('jongeren', 0.7164357900619507),
#  ('westerlingen', 0.7135337591171265),
#  ('arbeidskrachten', 0.7125928401947021),
#  ('antillianen', 0.7114118337631226),
# ...

# %%
mnrc.wv.most_similar(positive='migrant', topn=100)
# Out:
# [('immigrant', 0.827220618724823),
#  ('asielzoeker', 0.7927099466323853),
#  ('hulpverlener', 0.7623646259307861),
#  ('vluchteling', 0.7556628584861755),
#  ('afghaan', 0.7550894021987915),
#  ('prostituee', 0.7326276302337646),
#  ('jihadist', 0.730526864528656),
#  ('vreemdeling', 0.7277946472167969),
#  ('gedetineerde', 0.7243421673774719),
#  ('arbeider', 0.718529224395752),
#  ('marokkaan', 0.7173547744750977),
#  ('buitenlander', 0.7169267535209656),
#  ('jood', 0.7138737440109253),
#  ('moslimvrouw', 0.7034611701965332),
#  ('politieagent', 0.7001785039901733),
#  ('turk', 0.6999696493148804),
#  ('volwassene', 0.6976940631866455),
#  ('arabier', 0.6963768601417542),
#  ('politieman', 0.693634033203125),
#  ('monnik', 0.6918483972549438),
#  ('taxichauffeur', 0.6864914894104004),
#  ('academicus', 0.6857166290283203),
#  ('surinamer', 0.6852166056632996),
#  ('toerist', 0.6841202974319458),
#  ('westerling', 0.680206298828125),
#  ('moslim', 0.6701433062553406),
# ...

# %%
mnrc.wv.most_similar(positive='migranten', topn=100)
# Out:
# [('immigranten', 0.94642174243927),
#  ('arbeidsmigranten', 0.8806429505348206),
#  ('vluchtelingen', 0.8760569095611572),
#  ('illegalen', 0.8519799709320068),
#  ('buitenlanders', 0.8236743211746216),
#  ('asielzoekers', 0.8144205808639526),
#  ('vreemdelingen', 0.8036269545555115),
#  ('gastarbeiders', 0.7908940315246582),
#  ('turken', 0.7668745517730713),
#  ('chinezen', 0.7587913870811462),
#  ('allochtonen', 0.7552108764648438),
#  ('nieuwkomers', 0.7533475160598755),
#  ('emigranten', 0.7445155382156372),
#  ('jongeren', 0.7444968819618225),
#  ('arbeiders', 0.7421451210975647),
#  ('bootvluchtelingen', 0.741148829460144),
#  ('gezinnen', 0.7396376132965088),
#  ('nederlanders', 0.7318141460418701),
#  ('moslims', 0.7281274795532227),
#  ('antillianen', 0.7259334921836853),
#  ('boeren', 0.723111629486084),
#  ('toeristen', 0.7219980359077454),
#  ('afghanen', 0.7210787534713745),
#  ('ontheemden', 0.7140276432037354),
#  ('burgers', 0.7081159353256226),
# ...

# %%
mnrc.wv.most_similar(positive='expat', topn=100)
# Out:
# [('tropenarts', 0.7005353569984436),
#  ('lasser', 0.6972088813781738),
#  ('schoonmaakster', 0.6951664686203003),
#  ('gastarbeider', 0.6805623769760132),
#  ('loodgieter', 0.6736845374107361),
#  ('wijnboer', 0.6678217649459839),
#  ('pornoster', 0.6630159020423889),
#  ('immigrant', 0.6627359390258789),
#  ('prostituee', 0.6508952379226685),
#  ('onderwijzeres', 0.6504277586936951),
#  ('academicus', 0.6499427556991577),
#  ('ingenieur', 0.6489448547363281),
#  ('rechtenstudent', 0.643466591835022),
#  ('werkstudent', 0.6409364938735962),
#  ('ontwikkelingswerker', 0.6408889889717102),
#  ('freelancer', 0.6386263370513916),
#  ('neurochirurg', 0.6375876665115356),
#  ('missionaris', 0.6364510655403137),
#  ('fabrieksarbeider', 0.6363353729248047),
#  ('arbeider', 0.6359003782272339),
#  ('schoonmaker', 0.6358727216720581),
#  ('beroepsmilitair', 0.6354489922523499),
#  ('bibliothecaris', 0.6323059797286987),
#  ('ondernemer', 0.6321924924850464),
# ...

# %%
mnrc.wv.most_similar(positive='expats', topn=100)
# Out:
# [('emigranten', 0.8502817153930664),
#  ('gastarbeiders', 0.8174038529396057),
#  ('arbeidsmigranten', 0.8000423908233643),
#  ('vakantiegangers', 0.7897218465805054),
#  ('zakenmensen', 0.7815107703208923),
#  ('toeristen', 0.7599343657493591),
#  ('miljonairs', 0.759475588798523),
#  ('yuppen', 0.7500152587890625),
#  ('landbouwers', 0.743165135383606),
#  ('arbeiders', 0.7372992038726807),
#  ('zakenlieden', 0.7350629568099976),
#  ('miljardairs', 0.72962486743927),
#  ('immigranten', 0.7251868844032288),
#  ('surinamers', 0.7246350049972534),
#  ('kwekers', 0.7242336273193359),
#  ('verzamelaars', 0.7240043878555298),
#  ('somaliers', 0.7226683497428894),
#  ('kunstliefhebbers', 0.7224111557006836),
#  ('zakenlui', 0.7156770825386047),
#  ('bouwvakkers', 0.7151642441749573),
#  ('dierentuinen', 0.7098516225814819),
#  ('migranten', 0.7065283060073853),
#  ('kolonies', 0.7036155462265015),
#  ('families', 0.7011483311653137),
#  ('vissers', 0.700221061706543),
# ...

# %% [markdown]
# # 1a. Reference categories
# Selected on the basis of in-groups ('nederlander (s)' and 'wester(s)' as well as the largest west-european migrant groups living in the Netherlands, according to Statistics Netherlands:  https://www.cbs.nl/nl-nl/achtergrond/2016/47/bevolking-naar-migratieachtergrond)

# %%
mnrc.wv.most_similar(positive='nederlander', topn=100)
# Out:
# [('belg', 0.7929008603096008),
#  ('duitser', 0.7576650381088257),
#  ('rotterdammer', 0.7565874457359314),
#  ('buitenlander', 0.7485108375549316),
#  ('renner', 0.7477827072143555),
#  ('schaatser', 0.7455259561538696),
#  ('atleet', 0.7449600696563721),
#  ('griek', 0.7312935590744019),
#  ('zwemmer', 0.7251381874084473),
#  ('speelster', 0.723126232624054),
#  ('hagenaar', 0.7160847783088684),
#  ('tennisser', 0.7127094268798828),
#  ('hongaar', 0.7109836339950562),
#  ('sprinter', 0.7088466882705688),
#  ('klimmer', 0.7081667184829712),
#  ('voetballer', 0.7031644582748413),
#  ('debutant', 0.6923040151596069),
#  ('zwitser', 0.6891517639160156),
#  ('europeaan', 0.6884850263595581),
#  ('wielrenner', 0.6878176331520081),
#  ('hockeyer', 0.6873116493225098),
#  ('speler', 0.6872408986091614),
#  ('keniaan', 0.6836227774620056),
#  ('brabander', 0.682931661605835),
#  ('zeiler', 0.6824798583984375),
#  ('amerikaan', 0.681400716304779),
#  ('topper', 0.6804303526878357),
# ...

# %%
mnrc.wv.most_similar(positive='nederlanders', topn=100)
# Out:
# [('turken', 0.8343538641929626),
#  ('amsterdammers', 0.8174549341201782),
#  ('buitenlanders', 0.8160184621810913),
#  ('chinezen', 0.7824571132659912),
#  ('vlamingen', 0.7788259387016296),
#  ('rotterdammers', 0.7778620719909668),
#  ('mensen', 0.7767255306243896),
#  ('marokkanen', 0.7739876508712769),
#  ('belgen', 0.766194760799408),
#  ('kenianen', 0.7641699910163879),
#  ('japanners', 0.7609302997589111),
#  ('fransen', 0.75684654712677),
#  ('mexicanen', 0.7561980485916138),
#  ('italianen', 0.753539502620697),
#  ('egyptenaren', 0.7473217844963074),
#  ('europeanen', 0.7450120449066162),
#  ('hongaren', 0.7435470819473267),
#  ('duitsers', 0.7428767681121826),
#  ('brazilianen', 0.7415407299995422),
#  ('argentijnen', 0.7397763133049011),
#  ('surinamers', 0.7363702058792114),
#  ('denen', 0.7349295616149902),
#  ('ijslanders', 0.7318469882011414),
#  ('migranten', 0.7318141460418701),
#  ('jongeren', 0.728478193283081),
#  ('oostenrijkers', 0.7272911071777344),
# ...

# %%
mnrc.wv.most_similar(positive='belg', topn=100)
# Out:
# [('duitser', 0.9158243536949158),
#  ('zweed', 0.9077240228652954),
#  ('zwitser', 0.8918397426605225),
#  ('oostenrijker', 0.8802697658538818),
#  ('fransman', 0.8727439641952515),
#  ('deen', 0.8702412843704224),
#  ('italiaan', 0.8627536296844482),
#  ('routinier', 0.8559494018554688),
#  ('tsjech', 0.853853702545166),
#  ('debutant', 0.8497797846794128),
#  ('noor', 0.8488548994064331),
#  ('ploegleider', 0.8471487760543823),
#  ('spanjaard', 0.8328745365142822),
#  ('keniaan', 0.8312801122665405),
#  ('slowaak', 0.831260085105896),
#  ('sprinter', 0.8306658864021301),
#  ('spelverdeler', 0.8279480934143066),
#  ('nooijer', 0.8265950679779053),
#  ('zabel', 0.8264391422271729),
#  ('engelsman', 0.8253726959228516),
#  ('wielrenner', 0.8212653398513794),
#  ('braziliaan', 0.820655107498169),
#  ('australier', 0.8153121471405029),
#  ('roeier', 0.8134676218032837),
#  ('luxemburger', 0.8106606006622314),
#  ('sagan', 0.809005081653595),
#  ('roemeen', 0.8088515400886536),
# ...

# %%
mnrc.wv.most_similar(positive='belgen', topn=100)
# Out:
# [('denen', 0.898198127746582),
#  ('italianen', 0.8921308517456055),
#  ('fransen', 0.882189154624939),
#  ('spanjaarden', 0.8821828961372375),
#  ('oostenrijkers', 0.8645952939987183),
#  ('noren', 0.8590890765190125),
#  ('tsjechen', 0.8403348922729492),
#  ('engelsen', 0.8399358987808228),
#  ('portugezen', 0.8340704441070557),
#  ('duitsers', 0.8298233151435852),
#  ('vlamingen', 0.8295497298240662),
#  ('grieken', 0.8092663288116455),
#  ('brazilianen', 0.8034703731536865),
#  ('argentijnen', 0.7970718741416931),
#  ('ijslanders', 0.7967775464057922),
#  ('ieren', 0.7892456650733948),
#  ('hongaren', 0.7800224423408508),
#  ('schotten', 0.7778003215789795),
#  ('britten', 0.7737413048744202),
#  ('friezen', 0.7730319499969482),
#  ('russen', 0.7712715864181519),
#  ('canadezen', 0.7672082781791687),
#  ('slowaken', 0.7665256261825562),
#  ('nederlanders', 0.7661948204040527),
#  ('japanners', 0.7501564621925354),
#  ('turken', 0.7499642968177795),
# ...

# %%
mnrc.wv.most_similar(positive='duitser', topn=100)
# Out:
# [('belg', 0.9158244132995605),
#  ('zweed', 0.903274655342102),
#  ('zwitser', 0.9010220170021057),
#  ('fransman', 0.9004011750221252),
#  ('oostenrijker', 0.8948574662208557),
#  ('italiaan', 0.8856009244918823),
#  ('tsjech', 0.8579351902008057),
#  ('australier', 0.846082329750061),
#  ('noor', 0.8446568250656128),
#  ('spanjaard', 0.8390777111053467),
#  ('engelsman', 0.8354079127311707),
#  ('slowaak', 0.829967737197876),
#  ('colombiaan', 0.8216266632080078),
#  ('braziliaan', 0.8174028396606445),
#  ('argentijn', 0.8116487860679626),
#  ('griek', 0.8082563281059265),
#  ('sprinter', 0.8057606220245361),
#  ('roemeen', 0.8044599294662476),
#  ('japanner', 0.8041534423828125),
#  ('deen', 0.8029254674911499),
#  ('hongaar', 0.8025105595588684),
#  ('debutant', 0.8024066686630249),
#  ('brit', 0.8016504049301147),
#  ('kroaat', 0.8012789487838745),
#  ('keniaan', 0.8003490567207336),
#  ('amerikaan', 0.7868324518203735),
#  ('wielrenner', 0.7818940877914429),
# ...

# %%
mnrc.wv.most_similar(positive='duitsers', topn=100)
# Out:
# [('fransen', 0.9246596693992615),
#  ('russen', 0.9028880596160889),
#  ('spanjaarden', 0.8880139589309692),
#  ('italianen', 0.8837131261825562),
#  ('portugezen', 0.8837101459503174),
#  ('grieken', 0.8746325373649597),
#  ('engelsen', 0.8678621053695679),
#  ('oostenrijkers', 0.8650943040847778),
#  ('britten', 0.8517391085624695),
#  ('denen', 0.8488494157791138),
#  ('tsjechen', 0.8347935676574707),
#  ('belgen', 0.8298232555389404),
#  ('ieren', 0.8288507461547852),
#  ('hongaren', 0.8241894841194153),
#  ('japanners', 0.8136112689971924),
#  ('europeanen', 0.8103227615356445),
#  ('turken', 0.8054801225662231),
#  ('argentijnen', 0.8042867183685303),
#  ('noren', 0.7771165370941162),
#  ('amerikanen', 0.777000904083252),
#  ('brazilianen', 0.7756803035736084),
#  ('joden', 0.7684082984924316),
#  ('chinezen', 0.7646111845970154),
#  ('canadezen', 0.7606983184814453),
#  ('romeinen', 0.7589102983474731),
#  ('schotten', 0.7585108280181885),
#  ('finnen', 0.7429128885269165),
# ...

# %%
mnrc.wv.most_similar(positive='westers', topn=100)
# Out:
# [('religieus', 0.7788999080657959),
#  ('nationalistisch', 0.7691956162452698),
#  ('seculier', 0.7678393125534058),
#  ('autoritair', 0.7505114078521729),
#  ('islamitisch', 0.7499353289604187),
#  ('kapitalistisch', 0.7317640781402588),
#  ('communistisch', 0.7203378677368164),
#  ('godsdienstig', 0.7124409675598145),
#  ('homogeen', 0.7012643814086914),
#  ('socialistisch', 0.6950634717941284),
#  ('etnisch', 0.6912111639976501),
#  ('democratisch', 0.6885115504264832),
#  ('angelsaksisch', 0.6883825063705444),
#  ('aziatisch', 0.6841962337493896),
#  ('totalitair', 0.6838521957397461),
#  ('amerikaans', 0.6819007396697998),
#  ('hedendaags', 0.679061770439148),
#  ('revolutionair', 0.671661376953125),
#  ('institutioneel', 0.6682113409042358),
#  ('russisch', 0.6670275330543518),
#  ('spiritueel', 0.6662396192550659),
#  ('multicultureel', 0.6646839380264282),
#  ('christelijk', 0.6626466512680054),
#  ('progressief', 0.6617758274078369),
#  ('zionistisch', 0.6600977182388306),
# ...

# %%
mnrc.wv.most_similar(positive='christen', topn=100)
# Out:
# [('liberaal', 0.816621720790863),
#  ('fdp', 0.7718981504440308),
#  ('groenen', 0.7594737410545349),
#  ('socialisten', 0.7558226585388184),
#  ('liberale', 0.7452051639556885),
#  ('liberalen', 0.7405116558074951),
#  ('vrijzinnig', 0.7333601117134094),
#  ('pasok', 0.7273483872413635),
#  ('csu', 0.714077889919281),
#  ('conservatieven', 0.7140165567398071),
#  ('spd', 0.7128323912620544),
#  ('volkspartij', 0.7103977203369141),
#  ('centrumpartij', 0.7078869938850403),
#  ('democraat', 0.7041122913360596),
#  ('ovp', 0.6991758346557617),
#  ('syriza', 0.694227397441864),
#  ('conservatief', 0.6785733699798584),
#  ('minderheidsregering', 0.6769666075706482),
#  ('socialist', 0.672941267490387),
#  ('kanselierskandidaat', 0.6717957854270935),
#  ('cdu', 0.6713311076164246),
#  ('evp', 0.6672869920730591),
#  ('socialistische', 0.6662313938140869),
#  ('linke', 0.6624690890312195),
#  ('pds', 0.6608776450157166),
#  ('progressieve', 0.6600888967514038),
# ...

# %%
mnrc.wv.most_similar(positive='christenen', topn=100)
# Out:
# [('arabieren', 0.9014179110527039),
#  ('moslims', 0.9013805985450745),
#  ('hindoes', 0.8920165300369263),
#  ('joden', 0.8659502267837524),
#  ('islamieten', 0.8635963797569275),
#  ('katholieken', 0.8556215167045593),
#  ('gelovigen', 0.8473342657089233),
#  ('koerden', 0.8380497097969055),
#  ('fundamentalisten', 0.837628960609436),
#  ('protestanten', 0.8353571891784668),
#  ('sunnieten', 0.8335779905319214),
#  ('turken', 0.8271116614341736),
#  ('boeddhisten', 0.8225488662719727),
#  ('zwarten', 0.8119189739227295),
#  ('ongelovigen', 0.8051554560661316),
#  ('salafisten', 0.8050442934036255),
#  ('kolonisten', 0.7986180186271667),
#  ('blanken', 0.7886906862258911),
#  ('westerlingen', 0.7881653308868408),
#  ('israeliers', 0.7862243056297302),
#  ('islamisten', 0.7823224067687988),
#  ('kroaten', 0.7790867686271667),
#  ('homoseksuelen', 0.7686499953269958),
#  ('moslimbroeders', 0.7648717761039734),
#  ('extremisten', 0.7642784118652344),
# ...
