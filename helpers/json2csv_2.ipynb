# %%
import json
import pandas as pd

# %%
rawjson = json.load(open('/Users/admin/gitprojects/mediabias/wordfreqs/final/output.json'))

# %%
# df = pd.DataFrame.from_dict({'doctype':[], 'publication_date':[],'distance_criminal':[], 'distance_low':[]})

# %%
df = pd.DataFrame()
for item in rawjson[:-1]:
    
    publication_date =  item['publication_date']
    doctype = item['doctype']
    
    crim_distance=[]
    crim_length = []
    crim_pair = []
    crim_position_w1 = []
    crim_position_w2 = []
    crim_type = []
    crim_publication_date = []
    crim_doctype = []
    low_distance=[]
    low_length = []
    low_pair = []
    low_position_w1 = []
    low_position_w2 = []
    low_type = []
    low_publication_date = []
    low_doctype = []    
    if 'distance_criminal' in item:
        for d in item['distance_criminal']:
            crim_distance.append(d['distance'])
            crim_length.append(d['length'])
            crim_pair.append(d['pair'])
            crim_position_w1.append(d['position_w1'])
            crim_position_w2.append(d['position_w2'])
            crim_type.append('criminal')
            crim_publication_date.append(publication_date)
            crim_doctype.append(doctype)
        extrarows = pd.DataFrame.from_records(zip(crim_doctype,crim_publication_date, crim_type,crim_distance,crim_length,crim_pair,crim_position_w1,crim_position_w2))
        df = pd.concat([df,extrarows])
    if 'distance_low' in item:
        for d in item['distance_low']:
            low_distance.append(d['distance'])
            low_length.append(d['length'])
            low_pair.append(d['pair'])
            low_position_w1.append(d['position_w1'])
            low_position_w2.append(d['position_w2'])
            low_type.append('low')
            low_publication_date.append(publication_date)
            low_doctype.append(doctype)
        extrarows = pd.DataFrame.from_records(zip(low_doctype, low_publication_date, low_type,low_distance,low_length,low_pair,low_position_w1,low_position_w2))
        df = pd.concat([df,extrarows])
df.rename_axis({0:'doctype',1:'publication_date',2:'type',3:'distance', 4:'length_article',5:'word_pairs',6: 'position_w1', 7: 'position_w2'},axis=1, inplace=True)

# %%
df.rename_axis({0:'doctype',1:'publication_date',2:'type',3:'distance', 4:'length_article',5:'word_pairs',6: 'position_w1', 7: 'position_w2'},axis=1, inplace = True)

# %%
df['id_binnen_artikel'] = df.index

# %%
df
# Out:
#         doctype     publication_date      type  distance  length_article  \
# 0   nrc (print)  2005-07-08T00:00:00  criminal       281             485
# 1   nrc (print)  2005-07-08T00:00:00  criminal        73             485
# 0   nrc (print)  2009-12-10T00:00:00  criminal        85            1036
# 1   nrc (print)  2009-12-10T00:00:00  criminal       367            1036
# 2   nrc (print)  2009-12-10T00:00:00  criminal       659            1036
# 0   nrc (print)  2009-12-10T00:00:00  criminal        94             298
# 1   nrc (print)  2009-12-10T00:00:00  criminal       103             298
# 0   nrc (print)  2009-12-09T00:00:00  criminal       331             628
# 0   nrc (print)  2001-02-26T00:00:00       low       433             812
# 0   nrc (print)  2006-11-30T00:00:00  criminal        77             382
# 0   nrc (print)  2009-06-27T00:00:00       low       362            1022
# 1   nrc (print)  2009-06-27T00:00:00       low       825            1022
# ...

# %%
df['word1'] = df.word_pairs.map(lambda x: x[0])
df['word2'] = df.word_pairs.map(lambda x: x[1])

# %%
df.to_csv('/Users/admin/gitprojects/mediabias/wordfreqs/final/output_wordfreqs.csv')

# %%
df
# Out:
#         doctype     publication_date      type  distance  length_article  \
# 0   nrc (print)  2005-07-08T00:00:00  criminal       281             485
# 1   nrc (print)  2005-07-08T00:00:00  criminal        73             485
# 0   nrc (print)  2009-12-10T00:00:00  criminal        85            1036
# 1   nrc (print)  2009-12-10T00:00:00  criminal       367            1036
# 2   nrc (print)  2009-12-10T00:00:00  criminal       659            1036
# 0   nrc (print)  2009-12-10T00:00:00  criminal        94             298
# 1   nrc (print)  2009-12-10T00:00:00  criminal       103             298
# 0   nrc (print)  2009-12-09T00:00:00  criminal       331             628
# 0   nrc (print)  2001-02-26T00:00:00       low       433             812
# 0   nrc (print)  2006-11-30T00:00:00  criminal        77             382
# 0   nrc (print)  2009-06-27T00:00:00       low       362            1022
# 1   nrc (print)  2009-06-27T00:00:00       low       825            1022
# ...

# %%
'distance_criminal' in rawjson[0]
# Out:
# True

# %%
df = pd.DataFrame()
for item in rawjson:
    try:
        doctype = item['publication_date']
    except:
        print("what?")
    #doctype = item['doctype']
print(doc)
# Out:
# what?

# %%
pd.DataFrame.from_dict({'publication_date': [item['publication_date']], 
                      'doctype':[item['doctype']],
                       ''})
# Out:
#        doctype     publication_date
# 0  nrc (print)  2005-07-08T00:00:00

# %%
x = [subitem.items() for subitem in item['distance_criminal']]

# %%
# Out:
# [dict_items([('length', 485), ('pair', ['daders', 'moslims']), ('position_w2', 181), ('position_w1', 462), ('distance', 281)]),
#  dict_items([('length', 485), ('pair', ['daders', 'burgers']), ('position_w2', 389), ('position_w1', 462), ('distance', 73)])]

# %%
pd.concat([df,row1,row2])
# Out:
#                                    distance_criminal  distance_low  \
# 0  {'position_w1': 462, 'distance': 281, 'positio...           NaN
# 1  {'position_w1': 462, 'distance': 73, 'position...           NaN
# 0  {'position_w1': 667, 'distance': 85, 'position...           NaN
# 1  {'position_w1': 667, 'distance': 367, 'positio...           NaN
# 2  {'position_w1': 667, 'distance': 659, 'positio...           NaN
#
#        doctype     publication_date
# 0  nrc (print)  2005-07-08T00:00:00
# 1  nrc (print)  2005-07-08T00:00:00
# 0  nrc (print)  2009-12-10T00:00:00
# 1  nrc (print)  2009-12-10T00:00:00
# 2  nrc (print)  2009-12-10T00:00:00

# %%
for item in rawjson:
    extrarows = pd.DataFrame.from_records(item)
    try:
        df = pd.concat([df,extrarows])
    except:
        print('BOEH!')
        print(extrarows)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-aa3895679713> in <module>()
#       1 for item in rawjson:
# ----> 2     extrarows = pd.DataFrame.from_records(item)
#       3     try:
#       4         df = pd.concat([df,extrarows])
#       5     except:
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/core/frame.py in from_records(cls, data, index, exclude, columns, coerce_float, nrows)
#    1079             columns = columns.drop(exclude)
#    1080
# -> 1081         mgr = _arrays_to_mgr(arrays, arr_columns, result_index, columns)
#    1082
#    1083         return cls(mgr)
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5494     # figure out the index, if necessary
#    5495     if index is None:
# ...

# %%
for item in rawjson:
    try:
        extrarows = pd.DataFrame.from_records(item)
    except:
        print(item)
# Out:
# {'distance_low': [{'length': 3316, 'pair': ['alcoholist', 'nederlanders'], 'position_w2': 316, 'position_w1': 2559, 'distance': 2243}, {'length': 3316, 'pair': ['alcoholist', 'belg'], 'position_w2': 1161, 'position_w1': 2559, 'distance': 1398}, {'length': 3316, 'pair': ['alcoholist', 'belgen'], 'position_w2': 314, 'position_w1': 2559, 'distance': 2245}, {'length': 3316, 'pair': ['alcoholist', 'burgers'], 'position_w2': 23, 'position_w1': 2559, 'distance': 2536}, {'length': 3316, 'pair': ['alcoholist', 'christen'], 'position_w2': 1762, 'position_w1': 2559, 'distance': 797}, {'length': 3316, 'pair': ['alcoholist', 'burger'], 'position_w2': 1181, 'position_w1': 2559, 'distance': 1378}], 'publication_date': '2002-06-22T00:00:00', 'distance_criminal': [{'length': 3316, 'pair': ['agent', 'nederlanders'], 'position_w2': 316, 'position_w1': 2063, 'distance': 1747}, {'length': 3316, 'pair': ['agent', 'belg'], 'position_w2': 1161, 'position_w1': 2063, 'distance': 902}, {'length': 3316, 'pair':
# ...

# %%
test = {'distance_low': [{'length': 3316, 'pair': ['alcoholist', 'nederlanders'], 'position_w2': 316, 'position_w1': 2559, 'distance': 2243}, {'length': 3316, 'pair': ['alcoholist', 'belg'], 'position_w2': 1161, 'position_w1': 2559, 'distance': 1398}, {'length': 3316, 'pair': ['alcoholist', 'belgen'], 'position_w2': 314, 'position_w1': 2559, 'distance': 2245}, {'length': 3316, 'pair': ['alcoholist', 'burgers'], 'position_w2': 23, 'position_w1': 2559, 'distance': 2536}, {'length': 3316, 'pair': ['alcoholist', 'christen'], 'position_w2': 1762, 'position_w1': 2559, 'distance': 797}, {'length': 3316, 'pair': ['alcoholist', 'burger'], 'position_w2': 1181, 'position_w1': 2559, 'distance': 1378}], 'publication_date': '2002-06-22T00:00:00', 'distance_criminal': [{'length': 3316, 'pair': ['agent', 'nederlanders'], 'position_w2': 316, 'position_w1': 2063, 'distance': 1747}, {'length': 3316, 'pair': ['agent', 'belg'], 'position_w2': 1161, 'position_w1': 2063, 'distance': 902}, {'length': 3316, 'pair': ['agent', 'belgen'], 'position_w2': 314, 'position_w1': 2063, 'distance': 1749}, {'length': 3316, 'pair': ['agent', 'burgers'], 'position_w2': 23, 'position_w1': 2063, 'distance': 2040}, {'length': 3316, 'pair': ['agent', 'christen'], 'position_w2': 1762, 'position_w1': 2063, 'distance': 301}, {'length': 3316, 'pair': ['agent', 'burger'], 'position_w2': 1181, 'position_w1': 2063, 'distance': 882}, {'length': 3316, 'pair': ['criminaliteit', 'nederlanders'], 'position_w2': 316, 'position_w1': 3303, 'distance': 2987}, {'length': 3316, 'pair': ['criminaliteit', 'belg'], 'position_w2': 1161, 'position_w1': 3303, 'distance': 2142}, {'length': 3316, 'pair': ['criminaliteit', 'belgen'], 'position_w2': 314, 'position_w1': 3303, 'distance': 2989}, {'length': 3316, 'pair': ['criminaliteit', 'burgers
037, 'distance': 144}, {'length': 3316, 'pair': ['verdachte', 'nederlanders'], 'position_w2': 316, 'position_w1': 1252, 'distance': 936}, {'length': 3316, 'pair': ['verdachte', 'belg'], 'position_w2': 1161, 'position_w1': 1252, 'distance': 91}, {'length': 3316, 'pair': ['verdachte', 'belgen'], 'position_w2': 314, 'position_w1': 1252, 'distance': 938}, {'length': 3316, 'pair': ['verdachte', 'burgers'], 'position_w2': 23, 'position_w1': 1252, 'distance': 1229}, {'length': 3316, 'pair': ['verdachte', 'christen'], 'position_w2': 1762, 'position_w1': 1252, 'distance': 510}, {'length': 3316, 'pair': ['verdachte', 'burger'], 'position_w2': 1181, 'position_w1': 1252, 'distance': 71}], 'doctype': 'nrc (print)'}

# %%
pd.DataFrame.from_dict(test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-13d787b20c38> in <module>()
# ----> 1 pd.DataFrame.from_dict(test)
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/core/frame.py in from_dict(cls, data, orient, dtype)
#     849             raise ValueError('only recognize index or columns for orient')
#     850
# --> 851         return cls(data, index=index, columns=columns, dtype=dtype)
#     852
#     853     def to_dict(self, orient='dict'):
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     273                                  dtype=dtype, copy=copy)
#     274         elif isinstance(data, dict):
# --> 275             mgr = self._init_dict(data, index, columns, dtype=dtype)
# ...

# %%
pd.concat?

# %%
file = '/Users/admin/gitprojects/mediabias/wordfreqs/final/output.json'
with open(file) as train_file:
    data = json.load(train_file)

# %%
type(data)
data
# Out:
# [{'distance_criminal': [{'distance': 281,
#     'length': 485,
#     'pair': ['daders', 'moslims'],
#     'position_w1': 462,
#     'position_w2': 181},
#    {'distance': 73,
#     'length': 485,
#     'pair': ['daders', 'burgers'],
#     'position_w1': 462,
#     'position_w2': 389}],
#   'doctype': 'nrc (print)',
#   'publication_date': '2005-07-08T00:00:00'},
#  {'distance_criminal': [{'distance': 85,
#     'length': 1036,
#     'pair': ['aanhangers', 'moslims'],
#     'position_w1': 667,
#     'position_w2': 582},
#    {'distance': 367,
#     'length': 1036,
#     'pair': ['aanhangers', 'duitsers'],
#     'position_w1': 667,
#     'position_w2': 300},
#    {'distance': 659,
#     'length': 1036,
#     'pair': ['aanhangers', 'migranten'],
#     'position_w1': 667,
#     'position_w2': 8}],
#   'doctype': 'nrc (print)',
#   'publication_date': '2009-12-10T00:00:00'},
#  {'distance_criminal': [{'distance': 94,
#     'length': 298,
#     'pair': ['daders', 'burgers'],
# ...

# %%
distance_criminal= []
distance = []
for result in data['distance_criminal']:
    distance.append(result[u'distance_criminal'][u'distance'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-f2bec179eed9> in <module>()
#       1 distance_criminal= []
#       2 distance = []
# ----> 3 for result in data['distance_criminal']:
#       4     distance.append(result[u'distance_criminal'][u'distance'])
#
# TypeError: list indices must be integers, not str

# %%
#print(len(data))
#df = pd.DataFrame.from_dict([data]).T
# Out:
# 34471

# %%
keys = list(df.head(2)['distance_criminal'][0].keys())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item (pandas/_libs/hashtable.c:14010)()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# ...

# %%
print(len(df))
df.to_csv('/Users/admin/gitprojects/mediabias/wordfreqs/final/output.csv')
# Out:
# 34471
